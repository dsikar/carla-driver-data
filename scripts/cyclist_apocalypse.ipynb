# %% [markdown]
# # The Cyclist Apocalypse

# %%
# Boilerplate code
import carla 
import math 
import random 
import time 

# Connect to the client and get the world object
client = carla.Client('localhost', 2000) 
world = client.get_world() 

world = client.load_world('Town10HD')

# Get the blueprint library and the spawn points for the map
bp_lib = world.get_blueprint_library() 
spawn_points = world.get_map().get_spawn_points()

# %%
num_spawn_points = len(spawn_points)
print(f"Number of spawn points: {num_spawn_points}")
# Out:
# Number of spawn points: 155

# %%
# get spectator location
spectator = world.get_spectator()

# Get spectator transform and print coordinates
transform = spectator.get_transform()
print(f"Spectator coordinates: x={transform.location.x:.2f}, y={transform.location.y:.2f}, z={transform.location.z:.2f}")
# Spectator coordinates: x=-172.20, y=183.86, z=27.64
# Coordinates by the museum in Town10HD: Spectator coordinates: x=106.97, y=63.30, z=4.37
# Out:
# Spectator coordinates: x=-172.20, y=183.86, z=27.64

# %%
# Get the blueprint for the vehicle you want
vehicle_bp = bp_lib.find('vehicle.bh.crossbike') 

# Try spawning the vehicle at a randomly chosen spawn point
vehicle = world.try_spawn_actor(vehicle_bp, random.choice(spawn_points))

# %%
# Set spawn point
spawn_point = carla.Transform(
    carla.Location(x=106.97, y=63.30, z=0),
    carla.Rotation(pitch=0.0, yaw=0.0, roll=0.0)
)

# Get blueprint library
blueprint_library = world.get_blueprint_library()
vehicle_blueprints = blueprint_library.filter('vehicle.*')

# Spawn each vehicle type for 1 second
spawned_vehicles = []
for blueprint in vehicle_blueprints:
    try:
        # Spawn vehicle
        vehicle = world.spawn_actor(blueprint, spawn_point)
        spawned_vehicles.append(vehicle)
        print(f"Spawned: {blueprint.id}")
        
        # Wait 1 second
        time.sleep(2)
        
        # Destroy vehicle
        vehicle.destroy()
        
    except RuntimeError as e:
        print(f"Failed to spawn {blueprint.id}: {e}")

# Cleanup any remaining vehicles
for vehicle in spawned_vehicles:
    if vehicle.is_alive:
        vehicle.destroy()
# Out:
# Spawned: vehicle.audi.a2
# Failed to spawn vehicle.chevrolet.impala: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.citroen.c3: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.micro.microlino: Spawn failed because of collision at spawn position
# Spawned: vehicle.dodge.charger_police
# Failed to spawn vehicle.audi.tt: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.jeep.wrangler_rubicon: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.mercedes.coupe: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.mercedes.coupe_2020: Spawn failed because of collision at spawn position
# Spawned: vehicle.harley-davidson.low_rider
# Failed to spawn vehicle.dodge.charger_2020: Spawn failed because of collision at spawn position
# Failed to spawn vehicle.ford.ambulance: Spawn failed because of collision at spawn position
# ...

# %%
# Example usage:
spawn_point = carla.Transform(
    carla.Location(x=109, y=42.30, z=10),
    carla.Rotation(pitch=0.0, yaw=-90.0, roll=0.0)
)
    
#vehicle_id = spawn_vehicle('vehicle.gazelle.omafiets', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.bh.crossbike', spawn_point)
#vehicle_id = spawn_vehicle('vehicle.diamondback.century', spawn_point)

# delete_vehicle(vehicle_id)

# vehicle_id = spawn_vehicle('vehicle.audi.a2', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.chevrolet.impala', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.citroen.c3', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.micro.microlino', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.dodge.charger_police', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.audi.tt', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.jeep.wrangler_rubicon', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.mercedes.coupe', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.mercedes.coupe_2020', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.harley-davidson.low_rider', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.dodge.charger_2020', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.ford.ambulance', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.lincoln.mkz_2020', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.mini.cooper_s_2021', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.toyota.prius', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.ford.crown', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.carlamotors.carlacola', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.vespa.zx125', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.nissan.patrol_2021', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.dodge.charger_police_2020', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.mercedes.sprinter', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.audi.etron', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.seat.leon', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.volkswagen.t2_2021', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.tesla.cybertruck', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.lincoln.mkz_2017', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.ford.mustang', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.carlamotors.firetruck', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.volkswagen.t2', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.tesla.model3', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.diamondback.century', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.gazelle.omafiets', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.bmw.grandtourer', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.bh.crossbike', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.kawasaki.ninja', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.yamaha.yzf', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.nissan.patrol', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.nissan.micra', spawn_point)
# vehicle_id = spawn_vehicle('vehicle.mini.cooper_s', spawn_point)

"""vehicle.audi.a2
vehicle.chevrolet.impala
vehicle.citroen.c3
vehicle.micro.microlino
vehicle.dodge.charger_police
vehicle.audi.tt
vehicle.jeep.wrangler_rubicon
vehicle.mercedes.coupe
vehicle.mercedes.coupe_2020 # failed to spawn this one
vehicle.harley-davidson.low_rider
vehicle.dodge.charger_2020
vehicle.ford.ambulance
vehicle.lincoln.mkz_2020
vehicle.mini.cooper_s_2021
vehicle.toyota.prius
vehicle.ford.crown
vehicle.carlamotors.carlacola
vehicle.vespa.zx125
vehicle.nissan.patrol_2021
vehicle.dodge.charger_police_2020
vehicle.mercedes.sprinter
vehicle.audi.etron
vehicle.seat.leon
vehicle.volkswagen.t2_2021
vehicle.tesla.cybertruck
vehicle.lincoln.mkz_2017
vehicle.ford.mustang
vehicle.carlamotors.firetruck
vehicle.volkswagen.t2
vehicle.tesla.model3
vehicle.diamondback.century
vehicle.gazelle.omafiets
vehicle.bmw.grandtourer
vehicle.bh.crossbike
vehicle.kawasaki.ninja
vehicle.yamaha.yzf
vehicle.nissan.patrol
vehicle.nissan.micra
vehicle.mini.cooper_s
"""
# Out:
# 'vehicle.audi.a2\nvehicle.chevrolet.impala\nvehicle.citroen.c3\nvehicle.micro.microlino\nvehicle.dodge.charger_police\nvehicle.audi.tt\nvehicle.jeep.wrangler_rubicon\nvehicle.mercedes.coupe\nvehicle.mercedes.coupe_2020 # failed to spawn this one\nvehicle.harley-davidson.low_rider\nvehicle.dodge.charger_2020\nvehicle.ford.ambulance\nvehicle.lincoln.mkz_2020\nvehicle.mini.cooper_s_2021\nvehicle.toyota.prius\nvehicle.ford.crown\nvehicle.carlamotors.carlacola\nvehicle.vespa.zx125\nvehicle.nissan.patrol_2021\nvehicle.dodge.charger_police_2020\nvehicle.mercedes.sprinter\nvehicle.audi.etron\nvehicle.seat.leon\nvehicle.volkswagen.t2_2021\nvehicle.tesla.cybertruck\nvehicle.lincoln.mkz_2017\nvehicle.ford.mustang\nvehicle.carlamotors.firetruck\nvehicle.volkswagen.t2\nvehicle.tesla.model3\nvehicle.diamondback.century\nvehicle.gazelle.omafiets\nvehicle.bmw.grandtourer\nvehicle.bh.crossbike\nvehicle.kawasaki.ninja\nvehicle.yamaha.yzf\nvehicle.nissan.patrol\nvehicle.nissan.micra\nvehicle.mini.coope
# ...

# %%
vehicle_ids = get_vehicle_ids()
for vehicle in vehicle_ids:
    print(vehicle)
    delete_vehicle(vehicle)
    #print(vehicle)

# %% [markdown]
# # set all vehicles on autopilot

# %%
def set_vehicles_autopilot(vehicle_ids):
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    
    for vehicle_id in vehicle_ids:
        try:
            vehicle = world.get_actor(vehicle_id)
            if vehicle is not None:
                vehicle.set_autopilot(True)
        except:
            print(f"Failed to set autopilot for vehicle {vehicle_id}")

# Example usage:
vehicle_ids = get_vehicle_ids()
set_vehicles_autopilot(vehicle_ids)

# %%
delete_vehicle(vehicle_id)
# Out:
# True

# %%
import carla

def spawn_vehicle(blueprint_name, spawn_point=carla.Transform(carla.Location(x=106.97, y=63.30, z=4.37), carla.Rotation(pitch=0.0, yaw=0.0, roll=0.0))):
    """
    Spawns a vehicle at predefined location and returns its ID
    """
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    
    # Get blueprint
    blueprint_library = world.get_blueprint_library()
    blueprint = blueprint_library.find(blueprint_name)
    
    # Set spawn location
    # spawn_point = carla.Transform(
    #     carla.Location(x=106.97, y=63.30, z=4.37),
    #     carla.Rotation(pitch=0.0, yaw=0.0, roll=0.0)
    # )
    
    # Spawn vehicle
    vehicle = world.spawn_actor(blueprint, spawn_point)
    return vehicle.id

def delete_vehicle(vehicle_id):
    """
    Deletes vehicle given its ID
    """
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    
    # Find and destroy vehicle
    actor = world.get_actor(vehicle_id)
    if actor is not None:
        actor.destroy()
        return True
    return False

# Example usage:
# vehicle_id = spawn_vehicle('vehicle.bh.crossbike')
# delete_vehicle(vehicle_id)

# %%
def get_vehicle_ids():
    """
    Returns a list of all vehicle IDs in the current world
    """
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    
    # Get all actors and filter for vehicles
    all_actors = world.get_actors()
    vehicles = all_actors.filter('vehicle.*')
    
    # Return list of vehicle IDs
    return [vehicle.id for vehicle in vehicles]

# Example usage:
vehicle_ids = get_vehicle_ids()
for vehicle in vehicle_ids:
    print(vehicle)
# Out:
# 7343

# %% [markdown]
# # Place all vehicles

# %%
def get_all_vehicle_blueprints():
    """
    Returns list of all available vehicle blueprint names
    """
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    
    blueprint_library = world.get_blueprint_library()
    vehicle_blueprints = blueprint_library.filter('vehicle.*')
    
    return [blueprint.id for blueprint in vehicle_blueprints]

# Example usage:
vehicle_blueprints = get_all_vehicle_blueprints()
# print(blueprints)  # Displays all available vehicle types

def spawn_vehicles_in_row(vehicle_blueprints, start_y=63.30):
    """
    Spawns multiple vehicles along Y axis with 3 unit spacing
    Returns list of vehicle IDs
    """
    client = carla.Client('localhost', 2000)
    client.set_timeout(2.0)
    world = client.get_world()
    blueprint_library = world.get_blueprint_library()
    vehicle_ids = []
    
    for i, blueprint_name in enumerate(vehicle_blueprints):
        # Calculate new y position
        y_position = start_y + (i * 5)
        
        # Create spawn point
        spawn_point = carla.Transform(
            carla.Location(x=106.97, y=y_position, z=4.37),
            carla.Rotation(pitch=0.0, yaw=0.0, roll=0.0)
        )
        
        # Get vehicle blueprint and spawn
        blueprint = blueprint_library.find(blueprint_name)
        print(blueprint_name)
        vehicle = world.spawn_actor(blueprint, spawn_point)
        vehicle_ids.append(vehicle.id)
    
    return vehicle_ids

spawn_vehicles_in_row(vehicle_blueprints, 0)
# Out:
# vehicle.audi.a2
# vehicle.chevrolet.impala
# vehicle.citroen.c3
# vehicle.micro.microlino
# vehicle.dodge.charger_police
# vehicle.audi.tt
# vehicle.jeep.wrangler_rubicon
# vehicle.mercedes.coupe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-134-bae04febf131> in <module>
#      45     return vehicle_ids
#      46
# ---> 47 spawn_vehicles_in_row(vehicle_blueprints, 0)
#
# <ipython-input-134-bae04febf131> in spawn_vehicles_in_row(vehicle_blueprints, start_y)
#      40         blueprint = blueprint_library.find(blueprint_name)
#      41         print(blueprint_name)
# ---> 42         vehicle = world.spawn_actor(blueprint, spawn_point)
#      43         vehicle_ids.append(vehicle.id)
#      44
#
# RuntimeError: Spawn failed because of collision at spawn position

# %%
vehicle_ids = get_vehicle_ids()
for vehicle in vehicle_ids:
    delete_vehicle(vehicle)
    #print(vehicle)
# spawn_vehicles_in_row(vehicle_blueprints, 0)

# %% [markdown]
# # Cycling apocalypse

# %%
import random

# Get the blueprint for the vehicle you want
#vehicle_bp = bp_lib.find('vehicle.gazelle.omafiets') 

# Try spawning the vehicle at a randomly chosen spawn point
#vehicle = world.try_spawn_actor(vehicle_bp, random.choice(spawn_points))

def spawn_random_vehicles(total_vehicles=50):
    # client = carla.Client('localhost', 2000)
    # client.set_timeout(2.0)
    # world = client.get_world()
    
    # spawn_points = world.get_map().get_spawn_points()
    
    vehicles = [
        'vehicle.gazelle.omafiets',
        'vehicle.bh.crossbike',
        'vehicle.diamondback.century'
    ]
    
    blueprint_library = world.get_blueprint_library()
    vehicle_ids = []
    
    for i in range(total_vehicles):
        if i < len(spawn_points):
            try:
                vehicle_type = random.choice(vehicles)
                blueprint = blueprint_library.find(vehicle_type)
                vehicle = world.try_spawn_actor(blueprint, random.choice(spawn_points))
                vehicle_ids.append(vehicle.id)
            except:
                print(f"Failed to spawn vehicle at point {i}")
        
    
    return vehicle_ids

# Example usage:
spawned_vehicles = spawn_multiple_vehicles()
# Out:
# Failed to spawn vehicle.gazelle.omafiets at point 0
# Failed to spawn vehicle.gazelle.omafiets at point 1
# Failed to spawn vehicle.gazelle.omafiets at point 2
# Failed to spawn vehicle.gazelle.omafiets at point 3
# Failed to spawn vehicle.gazelle.omafiets at point 4
# Failed to spawn vehicle.gazelle.omafiets at point 5
# Failed to spawn vehicle.gazelle.omafiets at point 6
# Failed to spawn vehicle.gazelle.omafiets at point 7
# Failed to spawn vehicle.gazelle.omafiets at point 8
# Failed to spawn vehicle.gazelle.omafiets at point 9
# Failed to spawn vehicle.gazelle.omafiets at point 10
# Failed to spawn vehicle.gazelle.omafiets at point 11
# Failed to spawn vehicle.gazelle.omafiets at point 12
# Failed to spawn vehicle.gazelle.omafiets at point 13
# Failed to spawn vehicle.gazelle.omafiets at point 14
# Failed to spawn vehicle.gazelle.omafiets at point 15
# Failed to spawn vehicle.gazelle.omafiets at point 16
# Failed to spawn vehicle.gazelle.omafiets at point 17
# ...

# %%
random.choice(spawn_points)

# %%
vehicles = [
    'vehicle.gazelle.omafiets',
    'vehicle.bh.crossbike',
    'vehicle.diamondback.century'
]

blueprint_library = world.get_blueprint_library()
vehicle_ids = []

# for i in range(total_vehicles):
#     if i < len(spawn_points):
#         try:
vehicle_type = random.choice(vehicles)
#vehicle_type
blueprint = blueprint_library.find(vehicle_type)
# for method in dir(blueprint):
#     print(method)
type(spawn_points[0])
#blueprint.driver_id     
world.try_spawn_actor(blueprint, random.choice(spawn_points))
# vehicle_ids.append(vehicle.id)

# %%
# mysp = random.choice(spawn_points)
spawn_points

# %%
type(mysp)
print(mysp.location.x)
for method in dir(mysp):
    if not method.startswith("_"):
        print(method)
# Out:
# -111.120361328125
# get_forward_vector
# get_inverse_matrix
# get_matrix
# get_right_vector
# get_up_vector
# location
# rotation
# transform
# transform_vector

# %%
# Get the blueprint for the vehicle you want
vehicle_bp = bp_lib.find('vehicle.gazelle.omafiets') 
# for method in dir(vehicle_bp):
#     print(method)
# Try spawning the vehicle at a randomly chosen spawn point
vehicle = world.try_spawn_actor(vehicle_bp, random.choice(spawn_points))
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_attribute
# has_attribute
# has_tag
# id
# match_tags
# set_attribute
# tags

# %%
spawn_points[0].location.y
print(spawn_points[0].location.y,
# Out:
# 24.471010208129883

# %%
# Get the blueprint for the vehicle you want
vehicle_bp = bp_lib.find('vehicle.gazelle.omafiets') 

# Try spawning the vehicle at a randomly chosen spawn point
vehicle = world.try_spawn_actor(vehicle_bp, spawn_points[0])

# %% [markdown]
# ## Get Actor

# %%
vehicle_id = 139
vehicle = world.get_actor(vehicle_id)
spectator = world.get_spectator()
vehicle = world.get_actor(vehicle_id)  # Get vehicle actor from ID
transform = carla.Transform(vehicle.get_transform().transform(carla.Location(x=-4,z=2.5)),vehicle.get_transform().rotation)
spectator.set_transform(transform)

# %%
vehicle_ids = get_vehicle_ids()
vehicle_ids
vehicle_ids[0]
# Out:
# 139

# %%
import carla
import time
import math

# Global camera configuration
class CameraConfig:
    def __init__(self):
        # Default to rear view
        self.x_offset = -4.0  # negative is behind, positive is in front
        self.y_offset = 0.0   # negative is left, positive is right
        self.z_offset = 2.5   # height above vehicle
        self.rotation_offset = carla.Rotation(0, 0, 0)  # pitch, yaw, roll offsets

# Create global instance
camera_config = CameraConfig()

# Preset view configurations
def set_rear_view():
    camera_config.x_offset = -4.0
    camera_config.y_offset = 0.0
    camera_config.z_offset = 2.5
    camera_config.rotation_offset = carla.Rotation(0, 0, 0)

def set_front_view():
    #camera_config.x_offset = 4.0
    camera_config.x_offset = 1.5
    camera_config.y_offset = 0.0
    #camera_config.z_offset = 2.5
    camera_config.z_offset = 1.5
    camera_config.rotation_offset = carla.Rotation(0, 180, 0)  # Rotate 180° to face vehicle

def set_right_profile():
    camera_config.x_offset = 0.0
    camera_config.y_offset = 4.0
    camera_config.z_offset = 2.5
    camera_config.rotation_offset = carla.Rotation(0, 90, 0)  # Rotate 90° to face vehicle

def set_left_profile():
    camera_config.x_offset = 0.0
    camera_config.y_offset = -4.0
    #camera_config.y_offset = -4.0
    camera_config.z_offset = 2.5
    camera_config.rotation_offset = carla.Rotation(0, -90, 0)  # Rotate -90° to face vehicle

def set_top_down():
    camera_config.x_offset = 0.0
    camera_config.y_offset = 0.0
    camera_config.z_offset = 8.0
    camera_config.rotation_offset = carla.Rotation(-90, 0, 0)  # Look straight down

def set_custom_view(x, y, z, pitch=0, yaw=0, roll=0):
    camera_config.x_offset = x
    camera_config.y_offset = y
    camera_config.z_offset = z
    camera_config.rotation_offset = carla.Rotation(pitch, yaw, roll)

def follow_vehicle_with_camera(world, vehicle, spectator):
    """
    Creates a configurable following camera that tracks a vehicle.
    Camera position can be modified in real-time using the camera_config global.
    """
    try:
        while True:
            # Get vehicle's transform
            vehicle_transform = vehicle.get_transform()
            
            # Create relative location based on current camera configuration
            relative_location = carla.Location(
                x=camera_config.x_offset,
                y=camera_config.y_offset,
                z=camera_config.z_offset
            )
            
            # Get world location for camera
            camera_world_loc = vehicle_transform.transform(relative_location)
            
            # Combine vehicle's rotation with camera rotation offset
            camera_rotation = carla.Rotation(
                pitch=vehicle_transform.rotation.pitch + camera_config.rotation_offset.pitch,
                yaw=vehicle_transform.rotation.yaw + camera_config.rotation_offset.yaw,
                roll=vehicle_transform.rotation.roll + camera_config.rotation_offset.roll
            )
            
            # Create and set the new transform
            transform = carla.Transform(camera_world_loc, camera_rotation)
            spectator.set_transform(transform)
            
            time.sleep(0.01)
            
    except KeyboardInterrupt:
        print("\nCamera following stopped by user")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
"""
# Start the following camera in a separate thread
import threading
camera_thread = threading.Thread(target=follow_vehicle_with_camera, args=(world, vehicle, spectator))
camera_thread.start()

# Now you can modify the view at any time:
set_front_view()  # Switch to front view
time.sleep(5)     # Watch from front for 5 seconds
set_right_profile()  # Switch to right side view
time.sleep(5)     # Watch from right for 5 seconds
set_custom_view(x=3, y=3, z=5, pitch=-15, yaw=45)  # Switch to custom angle
"""
# Out:
# '\n# Start the following camera in a separate thread\nimport threading\ncamera_thread = threading.Thread(target=follow_vehicle_with_camera, args=(world, vehicle, spectator))\ncamera_thread.start()\n\n# Now you can modify the view at any time:\nset_front_view()  # Switch to front view\ntime.sleep(5)     # Watch from front for 5 seconds\nset_right_profile()  # Switch to right side view\ntime.sleep(5)     # Watch from right for 5 seconds\nset_custom_view(x=3, y=3, z=5, pitch=-15, yaw=45)  # Switch to custom angle\n'

# %%
# Start the camera following in a separate thread
import threading
camera_thread = threading.Thread(target=follow_vehicle_with_camera, args=(world, vehicle, spectator))
camera_thread.start()

# Then you can modify the view at any time from your main program:
while True:
    command = input("Enter view (rear/front/right/left/top): ")
    if command == "rear":
        set_rear_view()
    elif command == "front":
        set_front_view()
    elif command == "right":
        set_right_profile()
    elif command == "left":
        set_left_profile()
    elif command == "top":
        set_top_down()
    elif command == "quit":
        break
