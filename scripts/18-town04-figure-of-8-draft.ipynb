# %% [markdown]
# # Figure of 8 to be followed

# %%
# 1. Run on prompt
# daniel@simbox /opt/carla-simulator $ ./CarlaUE4.sh 

# 2. boilerplate code
import carla 
import math 
import random 
import time 
import carla_helpers as helpers

# Connect to the client and get the world object
client = carla.Client('localhost', 2000) 
world = client.get_world() 

# load Town04 map
world = client.load_world('Town04')

# %% [markdown]
# ## Set spectator position

# %%
import carla_helpers as helpers
# get view
# transform = helpers.get_spectator_transform(world)
# set view
transform = helpers.set_spectator_transform(world, (-56.26, 4.20, 554.04), (-87.06, 54.52, 0))
# Out:
# === Spectator Transform Set ===
# Location: x=-56.26, y=4.20, z=554.04
# Rotation: pitch=-87.06, yaw=54.52, roll=0.00
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Show all waypoints
# Used to generate image for report

# %%
## Orientation study
## the "figure of 8 view"
#transform = helpers.set_spectator_transform(world, (-56.26, 4.20, 554.04), (-87.06, 54.52, 0))
## Running line by line, we adjust to get a view of the town, then get the transform
# location, rotation = helpers.get_spectator_transform(world)

# === Spectator Transform ===
# Location: x=242.53, y=-164.60, z=8.80
# Rotation: pitch=-25.08, yaw=-30.64, roll=0.00
# (242.53, -164.60, 8.80), (-25.08, -30.64, 0.00)
# Keep it for future reference
## transform = helpers.set_spectator_transform((242.53, -164.60, 8.80), (-25.08, -30.64, 0.00))

# helpers.show_all_waypoints(world, point_distance=1.0, marker_life_time=40.0)
show_all_waypoints(world, point_distance=1.0, marker_life_time=40.0)
# Out:
# Displayed 33670 waypoints with neon cyan markers.
# ([None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   ...],
#  [<carla.libcarla.Waypoint at 0x7ff840700450>,
#   <carla.libcarla.Waypoint at 0x7ff815b56030>,
#   <carla.libcarla.Waypoint at 0x7ff815b56088>,
#   <carla.libcarla.Waypoint at 0x7ff815b560e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56138>,
#   <carla.libcarla.Waypoint at 0x7ff815b56190>,
#   <carla.libcarla.Waypoint at 0x7ff815b561e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56240>,
#   <carla.libcarla.Waypoint at 0x7ff815b56298>,
#   <carla.libcarla.Waypoint at 0x7ff815b562f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56348>,
#   <carla.libcarla.Waypoint at 0x7ff815b563a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b563f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56450>,
#   <carla.libcarla.Waypoint at 0x7ff815b564a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56500>,
#   <carla.libcarla.Waypoint at 0x7ff815b56558>,
#   <carla.libcarla.Waypoint at 0x7ff815b565b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56608>,
#   <carla.libcarla.Waypoint at 0x7ff815b56660>,
#   <carla.libcarla.Waypoint at 0x7ff815b566b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56710>,
#   <carla.libcarla.Waypoint at 0x7ff815b56768>,
#   <carla.libcarla.Waypoint at 0x7ff815b567c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56818>,
#   <carla.libcarla.Waypoint at 0x7ff815b56870>,
#   <carla.libcarla.Waypoint at 0x7ff815b568c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56920>,
#   <carla.libcarla.Waypoint at 0x7ff815b56978>,
#   <carla.libcarla.Waypoint at 0x7ff815b569d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b56a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b56ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b56b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b56be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b56c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b56ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b56d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b56df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b56ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b56ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b56f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b56fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58030>,
#   <carla.libcarla.Waypoint at 0x7ff815b58088>,
#   <carla.libcarla.Waypoint at 0x7ff815b580e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58138>,
#   <carla.libcarla.Waypoint at 0x7ff815b58190>,
#   <carla.libcarla.Waypoint at 0x7ff815b581e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58240>,
#   <carla.libcarla.Waypoint at 0x7ff815b58298>,
#   <carla.libcarla.Waypoint at 0x7ff815b582f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58348>,
#   <carla.libcarla.Waypoint at 0x7ff815b583a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b583f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58450>,
#   <carla.libcarla.Waypoint at 0x7ff815b584a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58500>,
#   <carla.libcarla.Waypoint at 0x7ff815b58558>,
#   <carla.libcarla.Waypoint at 0x7ff815b585b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58608>,
#   <carla.libcarla.Waypoint at 0x7ff815b58660>,
#   <carla.libcarla.Waypoint at 0x7ff815b586b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58710>,
#   <carla.libcarla.Waypoint at 0x7ff815b58768>,
#   <carla.libcarla.Waypoint at 0x7ff815b587c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58818>,
#   <carla.libcarla.Waypoint at 0x7ff815b58870>,
#   <carla.libcarla.Waypoint at 0x7ff815b588c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58920>,
#   <carla.libcarla.Waypoint at 0x7ff815b58978>,
#   <carla.libcarla.Waypoint at 0x7ff815b589d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b58a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b58ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b58b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b58be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b58c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b58ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b58d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b58df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b58ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b58ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b58f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b58fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59030>,
#   <carla.libcarla.Waypoint at 0x7ff815b59088>,
#   <carla.libcarla.Waypoint at 0x7ff815b590e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59138>,
#   <carla.libcarla.Waypoint at 0x7ff815b59190>,
#   <carla.libcarla.Waypoint at 0x7ff815b591e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59240>,
#   <carla.libcarla.Waypoint at 0x7ff815b59298>,
#   <carla.libcarla.Waypoint at 0x7ff815b592f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59348>,
#   <carla.libcarla.Waypoint at 0x7ff815b593a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b593f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59450>,
#   <carla.libcarla.Waypoint at 0x7ff815b594a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59500>,
#   <carla.libcarla.Waypoint at 0x7ff815b59558>,
#   <carla.libcarla.Waypoint at 0x7ff815b595b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59608>,
#   <carla.libcarla.Waypoint at 0x7ff815b59660>,
#   <carla.libcarla.Waypoint at 0x7ff815b596b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59710>,
#   <carla.libcarla.Waypoint at 0x7ff815b59768>,
#   <carla.libcarla.Waypoint at 0x7ff815b597c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59818>,
#   <carla.libcarla.Waypoint at 0x7ff815b59870>,
#   <carla.libcarla.Waypoint at 0x7ff815b598c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59920>,
#   <carla.libcarla.Waypoint at 0x7ff815b59978>,
#   <carla.libcarla.Waypoint at 0x7ff815b599d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b59a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b59ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b59b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b59be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b59c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b59ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b59d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b59df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b59ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b59ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b59f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b59fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5a9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5aa28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5aa80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5aad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ab30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ab88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5abe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ac38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ac90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ace8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ad40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ad98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5adf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ae48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5aea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5aef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5af50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5afa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5b9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ba28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ba80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bb30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bb88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bbe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bc38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bc90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bd40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bd98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bdf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5be48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bf50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5bfa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5c9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ca28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ca80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cb30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cb88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cbe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cc38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cc90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cd40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cd98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cdf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ce48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cf50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5cfa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5d9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5da28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5da80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5db30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5db88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dbe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dc38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dc90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dd40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dd98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ddf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5de48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5def8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5df50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5dfa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5e9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ea28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ea80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ead8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5eb30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5eb88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ebe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ec38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ec90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ece8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ed40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ed98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5edf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ee48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5eea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5eef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ef50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5efa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f030>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f088>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f138>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f190>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f240>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f298>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f348>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f450>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f500>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f558>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f608>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f660>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f710>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f768>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f818>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f870>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f920>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f978>,
#   <carla.libcarla.Waypoint at 0x7ff815b5f9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fa28>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fa80>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fb30>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fb88>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fbe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fc38>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fc90>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fd40>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fd98>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fdf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fe48>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b5fef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ff50>,
#   <carla.libcarla.Waypoint at 0x7ff815b5ffa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60030>,
#   <carla.libcarla.Waypoint at 0x7ff815b60088>,
#   <carla.libcarla.Waypoint at 0x7ff815b600e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60138>,
#   <carla.libcarla.Waypoint at 0x7ff815b60190>,
#   <carla.libcarla.Waypoint at 0x7ff815b601e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60240>,
#   <carla.libcarla.Waypoint at 0x7ff815b60298>,
#   <carla.libcarla.Waypoint at 0x7ff815b602f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60348>,
#   <carla.libcarla.Waypoint at 0x7ff815b603a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b603f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60450>,
#   <carla.libcarla.Waypoint at 0x7ff815b604a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60500>,
#   <carla.libcarla.Waypoint at 0x7ff815b60558>,
#   <carla.libcarla.Waypoint at 0x7ff815b605b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60608>,
#   <carla.libcarla.Waypoint at 0x7ff815b60660>,
#   <carla.libcarla.Waypoint at 0x7ff815b606b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60710>,
#   <carla.libcarla.Waypoint at 0x7ff815b60768>,
#   <carla.libcarla.Waypoint at 0x7ff815b607c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60818>,
#   <carla.libcarla.Waypoint at 0x7ff815b60870>,
#   <carla.libcarla.Waypoint at 0x7ff815b608c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60920>,
#   <carla.libcarla.Waypoint at 0x7ff815b60978>,
#   <carla.libcarla.Waypoint at 0x7ff815b609d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b60a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b60ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b60b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b60be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b60c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b60ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b60d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b60df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b60ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b60ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b60f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b60fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61030>,
#   <carla.libcarla.Waypoint at 0x7ff815b61088>,
#   <carla.libcarla.Waypoint at 0x7ff815b610e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61138>,
#   <carla.libcarla.Waypoint at 0x7ff815b61190>,
#   <carla.libcarla.Waypoint at 0x7ff815b611e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61240>,
#   <carla.libcarla.Waypoint at 0x7ff815b61298>,
#   <carla.libcarla.Waypoint at 0x7ff815b612f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61348>,
#   <carla.libcarla.Waypoint at 0x7ff815b613a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b613f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61450>,
#   <carla.libcarla.Waypoint at 0x7ff815b614a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61500>,
#   <carla.libcarla.Waypoint at 0x7ff815b61558>,
#   <carla.libcarla.Waypoint at 0x7ff815b615b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61608>,
#   <carla.libcarla.Waypoint at 0x7ff815b61660>,
#   <carla.libcarla.Waypoint at 0x7ff815b616b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61710>,
#   <carla.libcarla.Waypoint at 0x7ff815b61768>,
#   <carla.libcarla.Waypoint at 0x7ff815b617c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61818>,
#   <carla.libcarla.Waypoint at 0x7ff815b61870>,
#   <carla.libcarla.Waypoint at 0x7ff815b618c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61920>,
#   <carla.libcarla.Waypoint at 0x7ff815b61978>,
#   <carla.libcarla.Waypoint at 0x7ff815b619d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b61a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b61ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b61b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b61be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b61c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b61ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b61d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b61df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b61ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b61ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b61f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b61fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62030>,
#   <carla.libcarla.Waypoint at 0x7ff815b62088>,
#   <carla.libcarla.Waypoint at 0x7ff815b620e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62138>,
#   <carla.libcarla.Waypoint at 0x7ff815b62190>,
#   <carla.libcarla.Waypoint at 0x7ff815b621e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62240>,
#   <carla.libcarla.Waypoint at 0x7ff815b62298>,
#   <carla.libcarla.Waypoint at 0x7ff815b622f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62348>,
#   <carla.libcarla.Waypoint at 0x7ff815b623a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b623f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62450>,
#   <carla.libcarla.Waypoint at 0x7ff815b624a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62500>,
#   <carla.libcarla.Waypoint at 0x7ff815b62558>,
#   <carla.libcarla.Waypoint at 0x7ff815b625b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62608>,
#   <carla.libcarla.Waypoint at 0x7ff815b62660>,
#   <carla.libcarla.Waypoint at 0x7ff815b626b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62710>,
#   <carla.libcarla.Waypoint at 0x7ff815b62768>,
#   <carla.libcarla.Waypoint at 0x7ff815b627c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62818>,
#   <carla.libcarla.Waypoint at 0x7ff815b62870>,
#   <carla.libcarla.Waypoint at 0x7ff815b628c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62920>,
#   <carla.libcarla.Waypoint at 0x7ff815b62978>,
#   <carla.libcarla.Waypoint at 0x7ff815b629d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b62a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b62ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b62b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b62be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b62c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b62ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b62d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b62df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b62ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b62ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b62f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b62fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63030>,
#   <carla.libcarla.Waypoint at 0x7ff815b63088>,
#   <carla.libcarla.Waypoint at 0x7ff815b630e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63138>,
#   <carla.libcarla.Waypoint at 0x7ff815b63190>,
#   <carla.libcarla.Waypoint at 0x7ff815b631e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63240>,
#   <carla.libcarla.Waypoint at 0x7ff815b63298>,
#   <carla.libcarla.Waypoint at 0x7ff815b632f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63348>,
#   <carla.libcarla.Waypoint at 0x7ff815b633a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b633f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63450>,
#   <carla.libcarla.Waypoint at 0x7ff815b634a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63500>,
#   <carla.libcarla.Waypoint at 0x7ff815b63558>,
#   <carla.libcarla.Waypoint at 0x7ff815b635b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63608>,
#   <carla.libcarla.Waypoint at 0x7ff815b63660>,
#   <carla.libcarla.Waypoint at 0x7ff815b636b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63710>,
#   <carla.libcarla.Waypoint at 0x7ff815b63768>,
#   <carla.libcarla.Waypoint at 0x7ff815b637c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63818>,
#   <carla.libcarla.Waypoint at 0x7ff815b63870>,
#   <carla.libcarla.Waypoint at 0x7ff815b638c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63920>,
#   <carla.libcarla.Waypoint at 0x7ff815b63978>,
#   <carla.libcarla.Waypoint at 0x7ff815b639d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b63a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b63ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b63b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b63be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b63c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b63ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b63d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b63df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b63ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b63ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b63f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b63fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64030>,
#   <carla.libcarla.Waypoint at 0x7ff815b64088>,
#   <carla.libcarla.Waypoint at 0x7ff815b640e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64138>,
#   <carla.libcarla.Waypoint at 0x7ff815b64190>,
#   <carla.libcarla.Waypoint at 0x7ff815b641e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64240>,
#   <carla.libcarla.Waypoint at 0x7ff815b64298>,
#   <carla.libcarla.Waypoint at 0x7ff815b642f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64348>,
#   <carla.libcarla.Waypoint at 0x7ff815b643a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b643f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64450>,
#   <carla.libcarla.Waypoint at 0x7ff815b644a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64500>,
#   <carla.libcarla.Waypoint at 0x7ff815b64558>,
#   <carla.libcarla.Waypoint at 0x7ff815b645b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64608>,
#   <carla.libcarla.Waypoint at 0x7ff815b64660>,
#   <carla.libcarla.Waypoint at 0x7ff815b646b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64710>,
#   <carla.libcarla.Waypoint at 0x7ff815b64768>,
#   <carla.libcarla.Waypoint at 0x7ff815b647c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64818>,
#   <carla.libcarla.Waypoint at 0x7ff815b64870>,
#   <carla.libcarla.Waypoint at 0x7ff815b648c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64920>,
#   <carla.libcarla.Waypoint at 0x7ff815b64978>,
#   <carla.libcarla.Waypoint at 0x7ff815b649d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b64a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b64ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b64b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b64be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b64c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b64ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b64d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b64df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b64ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b64ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b64f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b64fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65030>,
#   <carla.libcarla.Waypoint at 0x7ff815b65088>,
#   <carla.libcarla.Waypoint at 0x7ff815b650e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65138>,
#   <carla.libcarla.Waypoint at 0x7ff815b65190>,
#   <carla.libcarla.Waypoint at 0x7ff815b651e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65240>,
#   <carla.libcarla.Waypoint at 0x7ff815b65298>,
#   <carla.libcarla.Waypoint at 0x7ff815b652f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65348>,
#   <carla.libcarla.Waypoint at 0x7ff815b653a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b653f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65450>,
#   <carla.libcarla.Waypoint at 0x7ff815b654a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65500>,
#   <carla.libcarla.Waypoint at 0x7ff815b65558>,
#   <carla.libcarla.Waypoint at 0x7ff815b655b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65608>,
#   <carla.libcarla.Waypoint at 0x7ff815b65660>,
#   <carla.libcarla.Waypoint at 0x7ff815b656b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65710>,
#   <carla.libcarla.Waypoint at 0x7ff815b65768>,
#   <carla.libcarla.Waypoint at 0x7ff815b657c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65818>,
#   <carla.libcarla.Waypoint at 0x7ff815b65870>,
#   <carla.libcarla.Waypoint at 0x7ff815b658c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65920>,
#   <carla.libcarla.Waypoint at 0x7ff815b65978>,
#   <carla.libcarla.Waypoint at 0x7ff815b659d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b65a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b65ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b65b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b65be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b65c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b65ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b65d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b65df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b65ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b65ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b65f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b65fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66030>,
#   <carla.libcarla.Waypoint at 0x7ff815b66088>,
#   <carla.libcarla.Waypoint at 0x7ff815b660e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66138>,
#   <carla.libcarla.Waypoint at 0x7ff815b66190>,
#   <carla.libcarla.Waypoint at 0x7ff815b661e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66240>,
#   <carla.libcarla.Waypoint at 0x7ff815b66298>,
#   <carla.libcarla.Waypoint at 0x7ff815b662f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66348>,
#   <carla.libcarla.Waypoint at 0x7ff815b663a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b663f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66450>,
#   <carla.libcarla.Waypoint at 0x7ff815b664a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66500>,
#   <carla.libcarla.Waypoint at 0x7ff815b66558>,
#   <carla.libcarla.Waypoint at 0x7ff815b665b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66608>,
#   <carla.libcarla.Waypoint at 0x7ff815b66660>,
#   <carla.libcarla.Waypoint at 0x7ff815b666b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66710>,
#   <carla.libcarla.Waypoint at 0x7ff815b66768>,
#   <carla.libcarla.Waypoint at 0x7ff815b667c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66818>,
#   <carla.libcarla.Waypoint at 0x7ff815b66870>,
#   <carla.libcarla.Waypoint at 0x7ff815b668c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66920>,
#   <carla.libcarla.Waypoint at 0x7ff815b66978>,
#   <carla.libcarla.Waypoint at 0x7ff815b669d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b66a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b66ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b66b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b66be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b66c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b66ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b66d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b66df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b66ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b66ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b66f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b66fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67030>,
#   <carla.libcarla.Waypoint at 0x7ff815b67088>,
#   <carla.libcarla.Waypoint at 0x7ff815b670e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67138>,
#   <carla.libcarla.Waypoint at 0x7ff815b67190>,
#   <carla.libcarla.Waypoint at 0x7ff815b671e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67240>,
#   <carla.libcarla.Waypoint at 0x7ff815b67298>,
#   <carla.libcarla.Waypoint at 0x7ff815b672f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67348>,
#   <carla.libcarla.Waypoint at 0x7ff815b673a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b673f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67450>,
#   <carla.libcarla.Waypoint at 0x7ff815b674a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67500>,
#   <carla.libcarla.Waypoint at 0x7ff815b67558>,
#   <carla.libcarla.Waypoint at 0x7ff815b675b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67608>,
#   <carla.libcarla.Waypoint at 0x7ff815b67660>,
#   <carla.libcarla.Waypoint at 0x7ff815b676b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67710>,
#   <carla.libcarla.Waypoint at 0x7ff815b67768>,
#   <carla.libcarla.Waypoint at 0x7ff815b677c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67818>,
#   <carla.libcarla.Waypoint at 0x7ff815b67870>,
#   <carla.libcarla.Waypoint at 0x7ff815b678c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67920>,
#   <carla.libcarla.Waypoint at 0x7ff815b67978>,
#   <carla.libcarla.Waypoint at 0x7ff815b679d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b67a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b67ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b67b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b67be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b67c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b67ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b67d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b67df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b67ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b67ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b67f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b67fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68030>,
#   <carla.libcarla.Waypoint at 0x7ff815b68088>,
#   <carla.libcarla.Waypoint at 0x7ff815b680e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68138>,
#   <carla.libcarla.Waypoint at 0x7ff815b68190>,
#   <carla.libcarla.Waypoint at 0x7ff815b681e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68240>,
#   <carla.libcarla.Waypoint at 0x7ff815b68298>,
#   <carla.libcarla.Waypoint at 0x7ff815b682f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68348>,
#   <carla.libcarla.Waypoint at 0x7ff815b683a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b683f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68450>,
#   <carla.libcarla.Waypoint at 0x7ff815b684a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68500>,
#   <carla.libcarla.Waypoint at 0x7ff815b68558>,
#   <carla.libcarla.Waypoint at 0x7ff815b685b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68608>,
#   <carla.libcarla.Waypoint at 0x7ff815b68660>,
#   <carla.libcarla.Waypoint at 0x7ff815b686b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68710>,
#   <carla.libcarla.Waypoint at 0x7ff815b68768>,
#   <carla.libcarla.Waypoint at 0x7ff815b687c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68818>,
#   <carla.libcarla.Waypoint at 0x7ff815b68870>,
#   <carla.libcarla.Waypoint at 0x7ff815b688c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68920>,
#   <carla.libcarla.Waypoint at 0x7ff815b68978>,
#   <carla.libcarla.Waypoint at 0x7ff815b689d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b68a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b68ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b68b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b68be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b68c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b68ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b68d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b68df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b68ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b68ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b68f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b68fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69030>,
#   <carla.libcarla.Waypoint at 0x7ff815b69088>,
#   <carla.libcarla.Waypoint at 0x7ff815b690e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69138>,
#   <carla.libcarla.Waypoint at 0x7ff815b69190>,
#   <carla.libcarla.Waypoint at 0x7ff815b691e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69240>,
#   <carla.libcarla.Waypoint at 0x7ff815b69298>,
#   <carla.libcarla.Waypoint at 0x7ff815b692f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69348>,
#   <carla.libcarla.Waypoint at 0x7ff815b693a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b693f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69450>,
#   <carla.libcarla.Waypoint at 0x7ff815b694a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69500>,
#   <carla.libcarla.Waypoint at 0x7ff815b69558>,
#   <carla.libcarla.Waypoint at 0x7ff815b695b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69608>,
#   <carla.libcarla.Waypoint at 0x7ff815b69660>,
#   <carla.libcarla.Waypoint at 0x7ff815b696b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69710>,
#   <carla.libcarla.Waypoint at 0x7ff815b69768>,
#   <carla.libcarla.Waypoint at 0x7ff815b697c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69818>,
#   <carla.libcarla.Waypoint at 0x7ff815b69870>,
#   <carla.libcarla.Waypoint at 0x7ff815b698c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69920>,
#   <carla.libcarla.Waypoint at 0x7ff815b69978>,
#   <carla.libcarla.Waypoint at 0x7ff815b699d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69a28>,
#   <carla.libcarla.Waypoint at 0x7ff815b69a80>,
#   <carla.libcarla.Waypoint at 0x7ff815b69ad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69b30>,
#   <carla.libcarla.Waypoint at 0x7ff815b69b88>,
#   <carla.libcarla.Waypoint at 0x7ff815b69be0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69c38>,
#   <carla.libcarla.Waypoint at 0x7ff815b69c90>,
#   <carla.libcarla.Waypoint at 0x7ff815b69ce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69d40>,
#   <carla.libcarla.Waypoint at 0x7ff815b69d98>,
#   <carla.libcarla.Waypoint at 0x7ff815b69df0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69e48>,
#   <carla.libcarla.Waypoint at 0x7ff815b69ea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b69ef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b69f50>,
#   <carla.libcarla.Waypoint at 0x7ff815b69fa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a030>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a088>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a138>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a190>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a240>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a298>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a348>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a450>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a500>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a558>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a608>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a660>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a710>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a768>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a818>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a870>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a920>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a978>,
#   <carla.libcarla.Waypoint at 0x7ff815b6a9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6aa28>,
#   <carla.libcarla.Waypoint at 0x7ff815b6aa80>,
#   <carla.libcarla.Waypoint at 0x7ff815b6aad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ab30>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ab88>,
#   <carla.libcarla.Waypoint at 0x7ff815b6abe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ac38>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ac90>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ace8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ad40>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ad98>,
#   <carla.libcarla.Waypoint at 0x7ff815b6adf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ae48>,
#   <carla.libcarla.Waypoint at 0x7ff815b6aea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6aef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6af50>,
#   <carla.libcarla.Waypoint at 0x7ff815b6afa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b030>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b088>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b138>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b190>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b240>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b298>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b348>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b450>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b500>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b558>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b608>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b660>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b710>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b768>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b818>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b870>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b920>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b978>,
#   <carla.libcarla.Waypoint at 0x7ff815b6b9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ba28>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ba80>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bb30>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bb88>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bbe0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bc38>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bc90>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bce8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bd40>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bd98>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bdf0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6be48>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bea0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bef8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bf50>,
#   <carla.libcarla.Waypoint at 0x7ff815b6bfa8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c030>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c088>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c0e0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c138>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c190>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c1e8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c240>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c298>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c2f0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c348>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c3a0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c3f8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c450>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c4a8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c500>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c558>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c5b0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c608>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c660>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c6b8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c710>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c768>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c7c0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c818>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c870>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c8c8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c920>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c978>,
#   <carla.libcarla.Waypoint at 0x7ff815b6c9d0>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ca28>,
#   <carla.libcarla.Waypoint at 0x7ff815b6ca80>,
#   <carla.libcarla.Waypoint at 0x7ff815b6cad8>,
#   <carla.libcarla.Waypoint at 0x7ff815b6cb30>,
#   ...])

# %% [markdown]
# # Waypoints stats

# %%
import carla

def analyze_waypoints(world):
    """
    Analyzes waypoints in the CARLA world and prints statistics.

    Args:
        world: The CARLA world object.

    Returns:
        A dictionary containing waypoint statistics.
    """

    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(1.0)  # Adjust density as needed

    num_waypoints = len(waypoints)

    # Gather waypoint properties (example: road ID, lane ID, location)
    waypoint_properties = []
    for wp in waypoints:
        waypoint_properties.append({
            "road_id": wp.road_id,
            "lane_id": wp.lane_id,
            "location": wp.transform.location,
            "transform": wp.transform,  # You can add the full transform
            "is_intersection": wp.is_intersection, # Check if the waypoint is at an intersection
            # Add other properties as needed (e.g., lane width, curvature)
        })

    # Basic Statistics
    print("\n--- Waypoint Statistics ---")
    print(f"Total number of waypoints: {num_waypoints}")

    # Example: Distribution of waypoints by road ID (optional)
    road_id_counts = {}
    for wp_prop in waypoint_properties:
        road_id = wp_prop["road_id"]
        road_id_counts[road_id] = road_id_counts.get(road_id, 0) + 1

    print("\nWaypoint distribution by Road ID:")
    for road_id, count in road_id_counts.items():
        print(f"Road ID {road_id}: {count} waypoints")

    # Example: Accessing and printing specific waypoint properties:
    if num_waypoints > 0:
        first_waypoint = waypoint_properties[0]
        print("\nExample: Properties of the first waypoint:")
        print(f"  Road ID: {first_waypoint['road_id']}")
        print(f"  Lane ID: {first_waypoint['lane_id']}")
        print(f"  Location: {first_waypoint['location']}")
        print(f"  Is Intersection: {first_waypoint['is_intersection']}")



    return {"num_waypoints": num_waypoints, "waypoint_properties": waypoint_properties}


# Example usage:
# stats = analyze_waypoints(world)
# print(stats["num_waypoints"])  # Access the number of waypoints
# print(stats["waypoint_properties"][0]["road_id"]) # Access the road id of the first waypoint.
# Out:
# --- Waypoint Statistics ---
# Total number of waypoints: 33670
#
# Waypoint distribution by Road ID:
# Road ID 1602: 168 waypoints
# Road ID 1601: 168 waypoints
# Road ID 1595: 55 waypoints
# Road ID 1594: 55 waypoints
# Road ID 1568: 19 waypoints
# Road ID 1567: 19 waypoints
# Road ID 1546: 16 waypoints
# Road ID 1531: 16 waypoints
# Road ID 1507: 16 waypoints
# Road ID 1497: 16 waypoints
# Road ID 1488: 16 waypoints
# Road ID 1479: 15 waypoints
# Road ID 1466: 20 waypoints
# Road ID 1465: 20 waypoints
# Road ID 497: 19 waypoints
# Road ID 996: 21 waypoints
# Road ID 1239: 21 waypoints
# Road ID 467: 52 waypoints
# Road ID 210: 22 waypoints
# Road ID 1522: 16 waypoints
# Road ID 981: 16 waypoints
# Road ID 458: 19 waypoints
# Road ID 372: 16 waypoints
# Road ID 115: 16 waypoints
# Road ID 886: 19 waypoints
# Road ID 1400: 220 waypoints
# Road ID 351: 19 waypoints
# Road ID 477: 51 waypoints
# Road ID 1539: 17 waypoints
# Road ID 457: 19 waypoints
# Road ID 844: 20 waypoints
# Road ID 314: 16 waypoints
# Road ID 828: 16 waypoints
# Road ID 247: 19 waypoints
# Road ID 761: 88 waypoints
# Road ID 1012: 16 waypoints
# Road ID 496: 19 waypoints
# Road ID 231: 20 waypoints
# Road ID 209: 22 waypoints
# Road ID 189: 22 waypoints
# Road ID 381: 16 waypoints
# Road ID 119: 16 waypoints
# Road ID 108: 20 waypoints
# Road ID 879: 15 waypoints
# Road ID 89: 19 waypoints
# Road ID 88: 19 waypoints
# Road ID 799: 16 waypoints
# Road ID 27: 68 waypoints
# Road ID 798: 20 waypoints
# Road ID 1312: 16 waypoints
# Road ID 407: 16 waypoints
# Road ID 26: 78 waypoints
# Road ID 540: 16 waypoints
# Road ID 797: 20 waypoints
# Road ID 24: 38 waypoints
# Road ID 23: 860 waypoints
# Road ID 149: 19 waypoints
# Road ID 22: 938 waypoints
# Road ID 225: 20 waypoints
# Road ID 1307: 16 waypoints
# Road ID 18: 144 waypoints
# Road ID 21: 1 waypoints
# Road ID 528: 16 waypoints
# Road ID 271: 21 waypoints
# Road ID 14: 26 waypoints
# Road ID 13: 8 waypoints
# Road ID 1101: 66 waypoints
# Road ID 19: 70 waypoints
# Road ID 145: 288 waypoints
# Road ID 1173: 296 waypoints
# Road ID 144: 288 waypoints
# Road ID 17: 116 waypoints
# Road ID 16: 82 waypoints
# Road ID 1044: 21 waypoints
# Road ID 1043: 21 waypoints
# Road ID 0: 70 waypoints
# Road ID 1028: 17 waypoints
# Road ID 1: 170 waypoints
# Road ID 510: 16 waypoints
# Road ID 1024: 17 waypoints
# Road ID 1281: 16 waypoints
# Road ID 2: 12 waypoints
# Road ID 61: 16 waypoints
# Road ID 3: 6 waypoints
# Road ID 774: 208 waypoints
# Road ID 1288: 16 waypoints
# Road ID 4: 62 waypoints
# Road ID 518: 16 waypoints
# Road ID 775: 208 waypoints
# Road ID 63: 15 waypoints
# Road ID 5: 192 waypoints
# Road ID 6: 512 waypoints
# Road ID 65: 15 waypoints
# Road ID 1217: 23 waypoints
# Road ID 135: 79 waypoints
# Road ID 8: 88 waypoints
# Road ID 779: 52 waypoints
# Road ID 136: 79 waypoints
# Road ID 393: 15 waypoints
# Road ID 907: 20 waypoints
# Road ID 880: 15 waypoints
# Road ID 1421: 55 waypoints
# Road ID 1091: 252 waypoints
# Road ID 9: 100 waypoints
# Road ID 11: 76 waypoints
# Road ID 241: 19 waypoints
# Road ID 782: 54 waypoints
# Road ID 12: 4 waypoints
# Road ID 1297: 16 waypoints
# Road ID 29: 116 waypoints
# Road ID 30: 88 waypoints
# Road ID 158: 19 waypoints
# Road ID 31: 178 waypoints
# Road ID 413: 16 waypoints
# Road ID 927: 21 waypoints
# Road ID 1184: 216 waypoints
# Road ID 1318: 16 waypoints
# Road ID 34: 187 waypoints
# Road ID 291: 19 waypoints
# Road ID 7: 46 waypoints
# Road ID 35: 2288 waypoints
# Road ID 36: 656 waypoints
# Road ID 266: 88 waypoints
# Road ID 807: 16 waypoints
# Road ID 37: 328 waypoints
# Road ID 1092: 252 waypoints
# Road ID 10: 74 waypoints
# Road ID 267: 66 waypoints
# Road ID 808: 16 waypoints
# Road ID 419: 16 waypoints
# Road ID 38: 1968 waypoints
# Road ID 39: 1072 waypoints
# Road ID 1122: 20 waypoints
# Road ID 40: 1896 waypoints
# Road ID 41: 1680 waypoints
# Road ID 42: 272 waypoints
# Road ID 15: 68 waypoints
# Road ID 1097: 65 waypoints
# Road ID 556: 16 waypoints
# Road ID 1327: 16 waypoints
# Road ID 170: 19 waypoints
# Road ID 43: 264 waypoints
# Road ID 44: 180 waypoints
# Road ID 1072: 304 waypoints
# Road ID 45: 4688 waypoints
# Road ID 275: 21 waypoints
# Road ID 816: 16 waypoints
# Road ID 1073: 304 waypoints
# Road ID 46: 1112 waypoints
# Road ID 428: 15 waypoints
# Road ID 47: 912 waypoints
# Road ID 20: 20 waypoints
# Road ID 561: 16 waypoints
# Road ID 48: 504 waypoints
# Road ID 1076: 77 waypoints
# Road ID 49: 320 waypoints
# Road ID 306: 16 waypoints
# Road ID 50: 1424 waypoints
# Road ID 179: 22 waypoints
# Road ID 25: 184 waypoints
# Road ID 1080: 77 waypoints
# Road ID 1337: 16 waypoints
# Road ID 54: 16 waypoints
# Road ID 28: 62 waypoints
# Road ID 569: 16 waypoints
# Road ID 826: 16 waypoints
# Road ID 52: 202 waypoints
# Road ID 593: 19 waypoints
# Road ID 594: 19 waypoints
# Road ID 634: 20 waypoints
# Road ID 1148: 19 waypoints
# Road ID 661: 18 waypoints
# Road ID 350: 19 waypoints
# Road ID 1432: 59 waypoints
# Road ID 124: 15 waypoints
# Road ID 666: 20 waypoints
# Road ID 674: 20 waypoints
# Road ID 695: 17 waypoints
# Road ID 1209: 27 waypoints
# Road ID 161: 18 waypoints
# Road ID 702: 19 waypoints
# Road ID 708: 19 waypoints
# Road ID 731: 23 waypoints
# Road ID 988: 16 waypoints
# Road ID 732: 23 waypoints
# Road ID 746: 21 waypoints
# Road ID 1003: 21 waypoints
# Road ID 749: 21 waypoints
# Road ID 1263: 19 waypoints
# Road ID 760: 66 waypoints
# Road ID 829: 16 waypoints
# Road ID 290: 19 waypoints
# Road ID 845: 20 waypoints
# Road ID 861: 66 waypoints
# Road ID 321: 16 waypoints
# Road ID 862: 88 waypoints
# Road ID 863: 21 waypoints
# Road ID 867: 20 waypoints
# Road ID 902: 88 waypoints
# Road ID 912: 21 waypoints
# Road ID 385: 16 waypoints
# Road ID 926: 21 waypoints
# Road ID 943: 18 waypoints
# Road ID 949: 18 waypoints
# Road ID 955: 19 waypoints
# Road ID 962: 19 waypoints
# Road ID 968: 18 waypoints
# Road ID 684: 17 waypoints
# Road ID 1225: 23 waypoints
# Road ID 974: 18 waypoints
# Road ID 468: 52 waypoints
# Road ID 1015: 17 waypoints
# Road ID 32: 68 waypoints
# Road ID 573: 15 waypoints
# Road ID 1114: 23 waypoints
# Road ID 33: 168 waypoints
# Road ID 1115: 23 waypoints
# Road ID 51: 428 waypoints
# Road ID 1133: 21 waypoints
# Road ID 1141: 19 waypoints
# Road ID 330: 16 waypoints
# Road ID 1412: 51 waypoints
# Road ID 1161: 82 waypoints
# Road ID 1162: 82 waypoints
# Road ID 633: 20 waypoints
# Road ID 1174: 296 waypoints
# Road ID 1185: 216 waypoints
# Road ID 901: 66 waypoints
# Road ID 1442: 62 waypoints
# Road ID 109: 20 waypoints
# Road ID 1191: 52 waypoints
# Road ID 653: 18 waypoints
# Road ID 1194: 55 waypoints
# Road ID 128: 15 waypoints
# Road ID 1210: 27 waypoints
# Road ID 1232: 21 waypoints
# Road ID 1264: 19 waypoints
# Road ID 819: 16 waypoints
# Road ID 1360: 19 waypoints
# Road ID 1361: 19 waypoints
# Road ID 1401: 220 waypoints
# Road ID 1450: 45 waypoints
#
# Example: Properties of the first waypoint:
#   Road ID: 1602
#   Lane ID: -4
#   Location: Location(x=379.693237, y=-19.074064, z=0.000000)
#   Is Intersection: True
# 33670
# 1602

# %%
carla_map = world.get_map()
waypoints = carla_map.generate_waypoints(1.0)  # Adjust density as needed
waypoint_properties = []
for wp in waypoints:
    # Use dir(wp) to get all attributes/properties of the wp object
    all_properties = dir(wp)  # Get all attribute names

    wp_data = {} # Dictionary to store property names and values.
    for prop_name in all_properties:
        try:
            prop_value = getattr(wp, prop_name) # Get the value of the attribute
            wp_data[prop_name] = prop_value # Store name and value
        except AttributeError: # Some properties may raise errors.
            pass # Ignore them.
        except Exception as e: # Catch any other exceptions.
            print(f"Error getting property {prop_name}: {e}") # Print out error.

# %%
wp_data
# Out:
# {'__class__': carla.libcarla.Waypoint,
#  '__delattr__': <method-wrapper '__delattr__' of Waypoint object at 0x7ff84068c0e0>,
#  '__dict__': {},
#  '__dir__': <function Waypoint.__dir__>,
#  '__doc__': None,
#  '__eq__': <method-wrapper '__eq__' of Waypoint object at 0x7ff84068c0e0>,
#  '__format__': <function Waypoint.__format__>,
#  '__ge__': <method-wrapper '__ge__' of Waypoint object at 0x7ff84068c0e0>,
#  '__getattribute__': <method-wrapper '__getattribute__' of Waypoint object at 0x7ff84068c0e0>,
#  '__gt__': <method-wrapper '__gt__' of Waypoint object at 0x7ff84068c0e0>,
#  '__hash__': <method-wrapper '__hash__' of Waypoint object at 0x7ff84068c0e0>,
#  '__init__': <function __init__>,
#  '__init_subclass__': <function Waypoint.__init_subclass__>,
#  '__le__': <method-wrapper '__le__' of Waypoint object at 0x7ff84068c0e0>,
#  '__lt__': <method-wrapper '__lt__' of Waypoint object at 0x7ff84068c0e0>,
#  '__module__': 'carla.libcarla',
#  '__ne__': <method-wrapper '__ne__' of Waypoint object at 0x7ff84068c0e0>,
#  '__new__': <function instance.__new__(*args, **kwargs)>,
#  '__reduce__': <bound method <unnamed Boost.Python function> of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  '__reduce_ex__': <function Waypoint.__reduce_ex__>,
#  '__repr__': <method-wrapper '__repr__' of Waypoint object at 0x7ff84068c0e0>,
#  '__setattr__': <method-wrapper '__setattr__' of Waypoint object at 0x7ff84068c0e0>,
#  '__sizeof__': <function Waypoint.__sizeof__>,
#  '__str__': <bound method __str__ of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  '__subclasshook__': <function Waypoint.__subclasshook__>,
#  '__weakref__': None,
#  'get_junction': <bound method get_junction of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'get_landmarks': <bound method get_landmarks of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'get_landmarks_of_type': <bound method get_landmarks_of_type of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'get_left_lane': <bound method get_left_lane of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'get_right_lane': <bound method get_right_lane of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'id': 16652337276301294135,
#  'is_intersection': True,
#  'is_junction': True,
#  'junction_id': 1368,
#  'lane_change': carla.libcarla.LaneChange.NONE,
#  'lane_id': -1,
#  'lane_type': carla.libcarla.LaneType.Driving,
#  'lane_width': 3.5,
#  'left_lane_marking': <carla.libcarla.LaneMarking at 0x7ff8407003a0>,
#  'next': <bound method next of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'next_until_lane_end': <bound method next_until_lane_end of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'previous': <bound method previous of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'previous_until_lane_start': <bound method previous_until_lane_start of <carla.libcarla.Waypoint object at 0x7ff84068c0e0>>,
#  'right_lane_marking': <carla.libcarla.LaneMarking at 0x7ff840700608>,
#  'road_id': 1450,
#  's': 44.0,
#  'section_id': 0,
#  'transform': <carla.libcarla.Transform at 0x7ff853a24e10>}

# %%
transform = helpers.set_spectator_transform(world, (-56.26, 4.20, 554.04), (-87.06, 54.52, 0))

# %% [markdown]
# ## Get figure of 8 for town 04

# %%
# helper functions
def validate_figure8_waypoints(world):
    """Get and validate waypoints for figure-8 track."""
    #road_sequence = [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    # road_sequence = [35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    road_sequence = [42, 35, 36, 37, 38, 39, 40, 41, 43, 45, 46, 47, 48, 49, 50]
    target_lane_id = -3
    waypoint_spacing = 1.0
    
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(waypoint_spacing)
    
    # Filter and sort waypoints
    road_waypoints = {}
    for road_id in road_sequence:
        road_waypoints[road_id] = [wp for wp in waypoints 
                                 if wp.road_id == road_id and wp.lane_id == target_lane_id]
        road_waypoints[road_id].sort(key=lambda x: x.s)
        
        print(f"Road {road_id}: {len(road_waypoints[road_id])} waypoints")
        
        # Validate waypoint spacing
        if len(road_waypoints[road_id]) > 1:
            first = road_waypoints[road_id][0].transform.location
            last = road_waypoints[road_id][-1].transform.location
            distance = ((last.x - first.x)**2 + 
                       (last.y - first.y)**2 + 
                       (last.z - first.z)**2)**0.5
            print(f"Road length: {distance:.1f}m")
    
    return road_waypoints

# Usage:
eight_lane_roads = validate_figure8_waypoints(world)
# eight_lane_roads

def place_markers_on_lane(world, eight_lane_roads, target_lane_id=-3):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Filter waypoints for target roads and lane
    target_waypoints = [wp for wp in waypoints 
                       if wp.road_id in eight_lane_roads 
                       and wp.lane_id == target_lane_id]
    
    # Place markers
    markers = []
    marker_color = carla.Color(r=255, g=0, b=0)  # Red markers
    marker_life_time = 20.0  # Markers will persist for 20 seconds
    
    for wp in target_waypoints:
        location = wp.transform.location
        # Draw a sphere at each waypoint
        marker = world.debug.draw_point(
            location,
            size=0.1,  # 10cm sphere
            color=marker_color,
            life_time=marker_life_time
        )
        markers.append(marker)
    
    print(f"Placed {len(markers)} markers on lane {target_lane_id} "
          f"across {len(eight_lane_roads)} roads")
    
    return markers, target_waypoints

# Usage:
markers, target_waypoints = place_markers_on_lane(world, eight_lane_roads)
# Out:
# Road 42: 34 waypoints
# Road length: 33.0m
# Road 35: 286 waypoints
# Road length: 231.0m
# Road 36: 82 waypoints
# Road length: 81.0m
# Road 37: 41 waypoints
# Road length: 37.3m
# Road 38: 246 waypoints
# Road length: 236.5m
# Road 39: 134 waypoints
# Road length: 133.0m
# Road 40: 237 waypoints
# Road length: 236.3m
# Road 41: 210 waypoints
# Road length: 194.3m
# Road 43: 33 waypoints
# Road length: 32.2m
# Road 45: 586 waypoints
# Road length: 492.9m
# Road 46: 139 waypoints
# Road length: 141.1m
# Road 47: 114 waypoints
# Road length: 113.0m
# Road 48: 63 waypoints
# Road length: 62.0m
# Road 49: 40 waypoints
# Road length: 38.8m
# Road 50: 178 waypoints
# Road length: 155.3m
# Placed 1214 markers on lane -3 across 15 roads

# %% [markdown]
# ## Set spectator at first figure-of-eight waypoint

# %%
#type(target_waypoints) # list
#target_waypoints[0] # carla.Waypoint object
#dir(target_waypoints[0])
new_spectator_transfrom = target_waypoints[0].transform
x = new_spectator_transfrom.location.x
y = new_spectator_transfrom.location.y
z = new_spectator_transfrom.location.z
pitch = new_spectator_transfrom.rotation.pitch
yaw = new_spectator_transfrom.rotation.yaw
roll = new_spectator_transfrom.rotation.roll
transform = helpers.set_spectator_transform(world, (x, y, z), (pitch, yaw, roll))
# Out:
# === Spectator Transform Set ===
# Location: x=248.67, y=-367.73, z=0.00
# Rotation: pitch=0.00, yaw=-0.30, roll=0.00

# %% [markdown]
# ## Visualise roads one at a time

# %%
import time

def visualize_roads_one_by_one(world, eight_lane_roads, target_lane_id=-3, delay=5):
    """
    Visualize roads one by one by placing markers on each road sequentially.
    
    Parameters:
    - world: CARLA world object.
    - eight_lane_roads: Dictionary containing waypoints for each road.
    - target_lane_id: Lane ID to visualize (default is -3).
    - delay: Time delay (in seconds) between visualizing each road.
    """
    marker_color = carla.Color(r=255, g=0, b=0)  # Red markers
    marker_life_time = delay + 2  # Markers will persist slightly longer than the delay
    
    for road_id, waypoints in eight_lane_roads.items():
        print(f"Visualizing Road {road_id}...")
        
        # Place markers on the current road
        markers = []
        for wp in waypoints:
            location = wp.transform.location
            marker = world.debug.draw_point(
                location,
                size=0.2,  # Slightly larger sphere for better visibility
                color=marker_color,
                life_time=marker_life_time
            )
            markers.append(marker)
        
        print(f"Placed {len(markers)} markers on Road {road_id}.")
        
        # Wait for the specified delay before moving to the next road
        time.sleep(delay)
        
        # Clear markers (optional, as they will disappear after life_time)
        # markers.clear()  # Not strictly necessary due to life_time
        
    print("Finished visualizing all roads.")

visualize_roads_one_by_one(world, eight_lane_roads, delay=5)
# Out:
# Visualizing Road 42...
# Placed 34 markers on Road 42.
# Visualizing Road 35...
# Placed 286 markers on Road 35.
# Visualizing Road 36...
# Placed 82 markers on Road 36.
# Visualizing Road 37...
# Placed 41 markers on Road 37.
# Visualizing Road 38...
# Placed 246 markers on Road 38.
# Visualizing Road 39...
# Placed 134 markers on Road 39.
# Visualizing Road 40...
# Placed 237 markers on Road 40.
# Visualizing Road 41...
# Placed 210 markers on Road 41.
# Visualizing Road 43...
# Placed 33 markers on Road 43.
# Visualizing Road 45...
# Placed 586 markers on Road 45.
# Visualizing Road 46...
# Placed 139 markers on Road 46.
# Visualizing Road 47...
# Placed 114 markers on Road 47.
# Visualizing Road 48...
# Placed 63 markers on Road 48.
# Visualizing Road 49...
# Placed 40 markers on Road 49.
# Visualizing Road 50...
# Placed 178 markers on Road 50.
# Finished visualizing all roads.

# %% [markdown]
# ## Inspect Road ID 42
# To make sure it should be on the route.

# %%
import carla

def inspect_road_and_place_spectator(world, eight_lane_roads, road_id=42, waypoint_index=0):
    """
    Inspect a specific road by placing the spectator near or at a waypoint of that road.
    
    Parameters:
    - world: CARLA world object.
    - eight_lane_roads: Dictionary containing waypoints for each road.
    - road_id: The road ID to inspect (default is 42).
    - waypoint_index: Index of the waypoint to place the spectator at (default is 0).
    """
    # Get the spectator object
    spectator = world.get_spectator()
    
    # Check if the road_id exists in the dictionary
    if road_id not in eight_lane_roads:
        print(f"Road ID {road_id} not found in the provided waypoints.")
        return
    
    # Get the waypoints for the specified road
    waypoints = eight_lane_roads[road_id]
    
    # Check if the waypoint_index is valid
    if waypoint_index >= len(waypoints):
        print(f"Waypoint index {waypoint_index} is out of range for Road ID {road_id}.")
        return
    
    # Get the target waypoint
    target_waypoint = waypoints[waypoint_index]
    target_location = target_waypoint.transform.location
    
    # Set the spectator's transform to the waypoint's transform
    spectator_transform = carla.Transform(
        target_location + carla.Location(z=20),  # Move the spectator 20 meters above the waypoint
        carla.Rotation(pitch=-90)  # Look directly down
    )
    spectator.set_transform(spectator_transform)
    
    print(f"Spectator placed at Waypoint {waypoint_index} on Road ID {road_id}.")
    
    # Optional: Visualize the road with markers
    marker_color = carla.Color(r=0, g=255, b=0)  # Green markers for better visibility
    marker_life_time = 30.0  # Markers will persist for 30 seconds
    
    for wp in waypoints:
        world.debug.draw_point(
            wp.transform.location,
            size=0.2,  # 20cm sphere
            color=marker_color,
            life_time=marker_life_time
        )
    
    print(f"Placed {len(waypoints)} markers on Road ID {road_id} for inspection.")

# road_sequence = [35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
# Assuming `world` and `eight_lane_roads` are already defined
#inspect_road_and_place_spectator(world, eight_lane_roads, road_id=42, waypoint_index=0)    
# inspect_road_and_place_spectator(world, eight_lane_roads, road_id=35, waypoint_index=0)    
inspect_road_and_place_spectator(world, eight_lane_roads, road_id=50, waypoint_index=0)  
inspect_road_and_place_spectator(world, eight_lane_roads, road_id=42, waypoint_index=0)
# Out:
# Spectator placed at Waypoint 0 on Road ID 50.
# Placed 178 markers on Road ID 50 for inspection.
# Spectator placed at Waypoint 0 on Road ID 42.
# Placed 34 markers on Road ID 42 for inspection.

# %% [markdown]
# ## Helper functions

# %%
def get_figure8_waypoints(world):
    # road_sequence = [42, 35, 36, 37, 38, 39, 40, 41, 45, 46, 47, 48, 49, 50]
    road_sequence = [35, 36, 37, 38, 39, 40, 41, 45, 46, 47, 48, 49, 50]
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(1.0)
    
    all_waypoints = []
    for road_id in road_sequence:
        road_waypoints = [wp for wp in waypoints if wp.road_id == road_id and wp.lane_id == -3]
        road_waypoints.sort(key=lambda x: x.s)
        all_waypoints.extend(road_waypoints)
        
    return all_waypoints

def set_spectator_camera_following_car(world, vehicle):
    """
    Position the spectator 3 meters above and 5 meters behind the vehicle.
    
    Parameters:
    - world: CARLA world object.
    - vehicle: CARLA vehicle object.
    
    Returns:
    - spectator: CARLA spectator object.
    """
    spectator = world.get_spectator()
    vehicle_transform = vehicle.get_transform()

    # Get the vehicle's forward vector (direction it's facing)
    forward_vector = vehicle_transform.get_forward_vector()

    # Calculate the offset position: 5 meters behind and 3 meters above the vehicle
    offset_location = vehicle_transform.location + carla.Location(
        x=-5 * forward_vector.x,  # 5 meters behind along the forward axis
        y=-5 * forward_vector.y,  # 5 meters behind along the forward axis
        z=3  # 3 meters above
    )

    # Set the spectator transform with a fixed pitch for a better view
    spectator.set_transform(carla.Transform(
        offset_location,
        carla.Rotation(pitch=-15, yaw=vehicle_transform.rotation.yaw, roll=0)  # Slightly tilted down
    ))
    return spectator

def compute_control(vehicle, target_wp, target_speed=10):  # Reduced target speed to 10 km/h
    """
    Compute vehicle control to reach the target waypoint at a specified speed.
    
    Parameters:
    - vehicle: CARLA vehicle object.
    - target_wp: Target waypoint.
    - target_speed: Desired speed in km/h (default is 10 km/h).
    
    Returns:
    - control: CARLA VehicleControl object.
    """
    control = carla.VehicleControl()

    # Get current state
    current_transform = vehicle.get_transform()
    current_velocity = vehicle.get_velocity()
    speed = 3.6 * math.sqrt(current_velocity.x**2 + current_velocity.y**2)  # Convert to km/h

    # Steering control
    forward = current_transform.get_forward_vector()
    target_vector = target_wp.transform.location - current_transform.location
    forward_dot = forward.x * target_vector.x + forward.y * target_vector.y
    right_dot = -forward.y * target_vector.x + forward.x * target_vector.y
    steering = math.atan2(right_dot, forward_dot) / math.pi
    control.steer = max(-1.0, min(1.0, steering))  # Clamp steering to [-1, 1]

    # Speed control
    speed_error = target_speed - speed
    if speed_error > 0:
        # If below target speed, apply throttle
        control.throttle = min(0.3, speed_error / target_speed)  # Reduced throttle limit to 0.3
        control.brake = 0.0
    else:
        # If above target speed, apply brake
        control.throttle = 0.0
        control.brake = min(0.3, -speed_error / target_speed)  # Reduced brake limit to 0.3

    return control

def drive_figure_eight(world, vehicle, waypoints, target_speed=10):
    """
    Drive the vehicle along the figure-8 track at a specified speed.
    
    Parameters:
    - world: CARLA world object.
    - vehicle: CARLA vehicle object.
    - waypoints: List of waypoints for the figure-8 track.
    - target_speed: Desired speed in km/h (default is 10 km/h).
    """
    try:
        for i, wp in enumerate(waypoints):
            print(f"Current target waypoint {i + 1}/{len(waypoints)}: {wp.transform.location}")
            
            # Draw the current target waypoint
            world.debug.draw_point(
                wp.transform.location,
                size=0.2,  # Size of the marker
                color=carla.Color(255, 0, 0),  # Red color
                life_time=5.0  # Persist for 5 seconds
            )
            
            # Drive toward the current waypoint
            while True:
                control = compute_control(vehicle, wp, target_speed)
                vehicle.apply_control(control)
                
                # Update spectator camera
                set_spectator_camera_following_car(world, vehicle)
                
                # Check if the vehicle is close to the current waypoint
                current_location = vehicle.get_transform().location
                distance_to_waypoint = current_location.distance(wp.transform.location)
                if distance_to_waypoint < 2.0:  # Proceed to the next waypoint if within 2 meters
                    break
                
                if world.get_settings().synchronous_mode:
                    world.tick()
                else:
                    time.sleep(0.1)  # Increased delay to 0.1 seconds
                    
    except KeyboardInterrupt:
        print("Simulation interrupted by user.")
        control = carla.VehicleControl(throttle=0, brake=1)
        vehicle.apply_control(control)

def draw_permanent_waypoint_lines(world, waypoints, color=carla.Color(0, 255, 0), thickness=0.01):
    """
    Draw permanent lines linking every waypoint on the road.
    
    Parameters:
    - world: CARLA world object.
    - waypoints: List of waypoints to link.
    - color: Color of the lines (default is neon green).
    - thickness: Thickness of the lines (default is 0.1 meters).
    """
    for i in range(len(waypoints) - 1):
        # Get the current and next waypoint
        wp1 = waypoints[i]
        wp2 = waypoints[i + 1]
        
        # Draw a line between the two waypoints
        world.debug.draw_line(
            wp1.transform.location,  # Start point
            wp2.transform.location,  # End point
            thickness=thickness,     # Line thickness
            color=color,             # Line color
            life_time=0             # Permanent line (life_time=0 means infinite)
        )

# %%
waypoints = get_figure8_waypoints(world)
draw_permanent_waypoint_lines(world, waypoints)

# %% [markdown]
# ## Instantiate vehicle and place on start of figure of 8

# %%
def main():
    # Connect to the CARLA server
    client = carla.Client("localhost", 2000)
    client.set_timeout(10.0)
    world = client.get_world()

    # Enable synchronous mode
    settings = world.get_settings()
    settings.synchronous_mode = True
    settings.fixed_delta_seconds = 0.05
    world.apply_settings(settings)

    try:
        # Get waypoints for the figure-8 track
        waypoints = get_figure8_waypoints(world)
        print(f"Number of waypoints retrieved: {len(waypoints)}")

        # Draw permanent lines linking the waypoints
        draw_permanent_waypoint_lines(world, waypoints, color=carla.Color(0, 255, 255))  # Neon cyan

        # Spawn vehicle at the first waypoint
        blueprint_library = world.get_blueprint_library()
        vehicle_bp = blueprint_library.filter("vehicle.tesla.model3")[0]  # Choose a vehicle blueprint
        spawn_point = waypoints[0].transform
        spawn_point.location.z += 2.0  # Adjust spawn height to avoid collisions
        print(f"Vehicle spawn point: {spawn_point.location}")

        try:
            vehicle = world.spawn_actor(vehicle_bp, spawn_point)
            print(f"Vehicle spawned at {spawn_point.location}")
        except Exception as e:
            print(f"Failed to spawn vehicle: {e}")
            return  # Exit the script if spawning fails

        # Drive the vehicle around the figure-8 track at 10 km/h
        try:
            drive_figure_eight(world, vehicle, waypoints, target_speed=10)
        except Exception as e:
            print(f"Error during driving: {e}")
    except KeyboardInterrupt:
        print("Simulation interrupted by user.")
    finally:
        # Clean up
        if 'vehicle' in locals():
            vehicle.destroy()
            print("Vehicle destroyed.")

main()
# Out:
# Number of waypoints retrieved: 2356
# Vehicle spawn point: Location(x=248.673141, y=-367.730164, z=2.000000)
# Vehicle spawned at Location(x=248.673141, y=-367.730164, z=2.000000)
# Current target waypoint 1/2356: Location(x=248.673141, y=-367.730164, z=0.000000)
# Current target waypoint 2/2356: Location(x=249.673126, y=-367.735321, z=0.000000)
# Current target waypoint 3/2356: Location(x=250.658020, y=-367.740265, z=0.000000)
# Current target waypoint 4/2356: Location(x=251.574799, y=-367.740753, z=0.000000)
# Current target waypoint 5/2356: Location(x=252.491562, y=-367.734985, z=0.000000)
# Current target waypoint 6/2356: Location(x=253.408264, y=-367.723053, z=0.000000)
# Current target waypoint 7/2356: Location(x=254.324875, y=-367.704834, z=0.000000)
# Current target waypoint 8/2356: Location(x=255.241333, y=-367.680389, z=0.000000)
# Current target waypoint 9/2356: Location(x=256.157593, y=-367.649780, z=0.000000)
# Current target waypoint 10/2356: Location(x=257.073669, y=-367.612885, z=0.000000)
# Current target waypoint 11/2356: Location(x=257.989410, y=-367.569763, z=0.000000)
# Current target waypoint 12/2356: Location(x=258.904877, y=-367.520477, z=0.000000)
# Current target waypoint 13/2356: Location(x=259.819977, y=-367.464935, z=0.000000)
# Current target waypoint 14/2356: Location(x=260.734680, y=-367.403168, z=0.000000)
# Current target waypoint 15/2356: Location(x=261.648926, y=-367.335205, z=0.000000)
# Current target waypoint 16/2356: Location(x=262.562714, y=-367.261047, z=0.000000)
# Current target waypoint 17/2356: Location(x=263.475952, y=-367.180664, z=0.000000)
# Current target waypoint 18/2356: Location(x=264.388672, y=-367.094086, z=0.000000)
# Current target waypoint 19/2356: Location(x=265.300720, y=-367.001312, z=0.000000)
# Current target waypoint 20/2356: Location(x=266.212158, y=-366.902344, z=0.000000)
# Current target waypoint 21/2356: Location(x=267.122894, y=-366.797180, z=0.000000)
# Current target waypoint 22/2356: Location(x=268.032898, y=-366.685822, z=0.000000)
# Current target waypoint 23/2356: Location(x=268.942108, y=-366.568329, z=0.000000)
# Current target waypoint 24/2356: Location(x=269.850494, y=-366.444641, z=0.000000)
# Current target waypoint 63/2356: Location(x=304.197632, y=-356.894470, z=0.000000)
# Current target waypoint 64/2356: Location(x=305.039520, y=-356.531525, z=0.000000)
# Current target waypoint 65/2356: Location(x=305.878906, y=-356.162842, z=0.000000)
# Current target waypoint 66/2356: Location(x=306.715759, y=-355.788483, z=0.000000)
# Current target waypoint 67/2356: Location(x=307.550049, y=-355.408417, z=0.000000)
# Current target waypoint 68/2356: Location(x=308.381744, y=-355.022736, z=0.000000)
# Current target waypoint 69/2356: Location(x=309.210846, y=-354.631378, z=0.000000)
# Current target waypoint 70/2356: Location(x=310.037170, y=-354.234406, z=0.000000)
# Current target waypoint 71/2356: Location(x=310.860840, y=-353.831848, z=0.000000)
# Current target waypoint 72/2356: Location(x=311.681793, y=-353.423676, z=0.000000)
# Current target waypoint 73/2356: Location(x=312.499878, y=-353.009979, z=0.000000)
# Current target waypoint 74/2356: Location(x=313.315216, y=-352.590698, z=0.000000)
# Current target waypoint 75/2356: Location(x=314.127625, y=-352.165894, z=0.000000)
# Current target waypoint 76/2356: Location(x=314.937134, y=-351.735596, z=0.000000)
# Current target waypoint 77/2356: Location(x=315.743744, y=-351.299774, z=0.000000)
# Current target waypoint 78/2356: Location(x=316.547302, y=-350.858521, z=0.000000)
# Current target waypoint 79/2356: Location(x=317.347931, y=-350.411804, z=0.000000)
# Current target waypoint 80/2356: Location(x=318.145447, y=-349.959656, z=0.000000)
# Current target waypoint 81/2356: Location(x=318.939880, y=-349.502106, z=0.000000)
# Current target waypoint 82/2356: Location(x=319.731171, y=-349.039154, z=0.000000)
# Current target waypoint 83/2356: Location(x=320.519348, y=-348.570862, z=0.000000)
# Current target waypoint 84/2356: Location(x=321.304260, y=-348.097229, z=0.000000)
# Current target waypoint 85/2356: Location(x=322.085999, y=-347.618256, z=0.000000)
# Current target waypoint 86/2356: Location(x=322.864471, y=-347.133972, z=0.000000)
# Current target waypoint 87/2356: Location(x=323.639618, y=-346.644409, z=0.000000)
# Current target waypoint 88/2356: Location(x=324.411377, y=-346.149658, z=0.000000)
# Current target waypoint 89/2356: Location(x=325.179810, y=-345.649628, z=0.000000)
# Current target waypoint 90/2356: Location(x=325.944794, y=-345.144348, z=0.000000)
# Current target waypoint 91/2356: Location(x=326.706390, y=-344.633972, z=0.000000)
# Current target waypoint 92/2356: Location(x=327.464447, y=-344.118378, z=0.000000)
# Current target waypoint 93/2356: Location(x=328.218964, y=-343.597626, z=0.000000)
# Current target waypoint 94/2356: Location(x=328.969971, y=-343.071777, z=0.000000)
# Current target waypoint 95/2356: Location(x=329.717377, y=-342.540863, z=0.000000)
# Current target waypoint 96/2356: Location(x=330.461151, y=-342.004883, z=0.000000)
# Current target waypoint 97/2356: Location(x=331.201263, y=-341.463898, z=0.000000)
# Current target waypoint 98/2356: Location(x=331.937714, y=-340.917847, z=0.000000)
# Current target waypoint 99/2356: Location(x=332.670410, y=-340.366760, z=0.000000)
# Current target waypoint 100/2356: Location(x=333.399323, y=-339.810791, z=0.000000)
# Current target waypoint 101/2356: Location(x=334.124512, y=-339.249847, z=0.000000)
# Current target waypoint 102/2356: Location(x=334.845795, y=-338.683990, z=0.000000)
# Current target waypoint 103/2356: Location(x=335.563263, y=-338.113251, z=0.000000)
# Current target waypoint 104/2356: Location(x=336.276855, y=-337.537659, z=0.000000)
# Current target waypoint 105/2356: Location(x=336.986481, y=-336.957214, z=0.000000)
# Current target waypoint 106/2356: Location(x=337.692139, y=-336.371979, z=0.000000)
# Current target waypoint 107/2356: Location(x=338.393829, y=-335.781952, z=0.000000)
# Current target waypoint 108/2356: Location(x=339.091492, y=-335.187195, z=0.000000)
# Current target waypoint 109/2356: Location(x=339.785126, y=-334.587677, z=0.000000)
# Current target waypoint 110/2356: Location(x=340.474640, y=-333.983490, z=0.000000)
# Current target waypoint 111/2356: Location(x=341.160034, y=-333.374634, z=0.000000)
# Current target waypoint 112/2356: Location(x=341.841278, y=-332.761139, z=0.000000)
# Current target waypoint 113/2356: Location(x=342.518372, y=-332.143036, z=0.000000)
# Current target waypoint 114/2356: Location(x=343.191193, y=-331.520325, z=0.000000)
# Current target waypoint 115/2356: Location(x=343.859802, y=-330.893036, z=0.000000)
# Current target waypoint 116/2356: Location(x=344.524139, y=-330.261261, z=0.000000)
# Current target waypoint 117/2356: Location(x=345.184143, y=-329.624939, z=0.000000)
# Current target waypoint 118/2356: Location(x=345.839813, y=-328.984192, z=0.000000)
# Current target waypoint 119/2356: Location(x=346.491180, y=-328.338989, z=0.000000)
# Current target waypoint 120/2356: Location(x=347.138062, y=-327.689362, z=0.000000)
# Current target waypoint 121/2356: Location(x=347.780548, y=-327.035400, z=0.000000)
# Current target waypoint 122/2356: Location(x=348.418610, y=-326.377045, z=0.000000)
# Current target waypoint 123/2356: Location(x=349.052124, y=-325.714417, z=0.000000)
# Current target waypoint 124/2356: Location(x=349.681152, y=-325.047455, z=0.000000)
# Current target waypoint 125/2356: Location(x=350.305664, y=-324.376282, z=0.000000)
# Current target waypoint 126/2356: Location(x=350.925568, y=-323.700867, z=0.000000)
# Current target waypoint 127/2356: Location(x=351.540863, y=-323.021210, z=0.000000)
# Current target waypoint 128/2356: Location(x=352.151520, y=-322.337433, z=0.000000)
# Current target waypoint 129/2356: Location(x=352.757568, y=-321.649506, z=0.000000)
# Current target waypoint 130/2356: Location(x=353.358887, y=-320.957489, z=0.000000)
# Current target waypoint 131/2356: Location(x=353.955505, y=-320.261383, z=0.000000)
# Current target waypoint 132/2356: Location(x=354.547363, y=-319.561279, z=0.000000)
# Current target waypoint 133/2356: Location(x=355.134521, y=-318.857178, z=0.000000)
# Current target waypoint 134/2356: Location(x=355.716797, y=-318.149078, z=0.000000)
# Current target waypoint 135/2356: Location(x=356.294281, y=-317.437042, z=0.000000)
# Current target waypoint 136/2356: Location(x=356.866882, y=-316.721069, z=0.000000)
# Current target waypoint 137/2356: Location(x=357.434692, y=-316.001251, z=0.000000)
# Current target waypoint 138/2356: Location(x=357.997528, y=-315.277557, z=0.000000)
# Current target waypoint 139/2356: Location(x=358.555450, y=-314.550110, z=0.000000)
# Current target waypoint 140/2356: Location(x=359.108398, y=-313.818848, z=0.000000)
# Current target waypoint 141/2356: Location(x=359.656433, y=-313.083893, z=0.000000)
# Current target waypoint 142/2356: Location(x=360.199371, y=-312.345184, z=0.000000)
# Current target waypoint 143/2356: Location(x=360.737366, y=-311.602844, z=0.000000)
# Current target waypoint 144/2356: Location(x=361.270233, y=-310.856842, z=0.000000)
# Current target waypoint 145/2356: Location(x=361.798096, y=-310.107269, z=0.000000)
# Current target waypoint 146/2356: Location(x=362.320801, y=-309.354095, z=0.000000)
# Current target waypoint 147/2356: Location(x=362.838379, y=-308.597412, z=0.000000)
# Current target waypoint 148/2356: Location(x=363.350800, y=-307.837219, z=0.000000)
# Current target waypoint 149/2356: Location(x=363.858063, y=-307.073517, z=0.000000)
# Current target waypoint 150/2356: Location(x=364.360138, y=-306.306427, z=0.000000)
# Current target waypoint 151/2356: Location(x=364.856964, y=-305.535950, z=0.000000)
# Current target waypoint 152/2356: Location(x=365.348572, y=-304.762146, z=0.000000)
# Current target waypoint 153/2356: Location(x=365.834869, y=-303.984955, z=0.000000)
# Current target waypoint 154/2356: Location(x=366.315948, y=-303.204498, z=0.000000)
# Current target waypoint 155/2356: Location(x=366.791626, y=-302.420807, z=0.000000)
# Current target waypoint 156/2356: Location(x=367.262054, y=-301.633911, z=0.000000)
# Current target waypoint 157/2356: Location(x=367.727051, y=-300.843811, z=0.000000)
# Current target waypoint 158/2356: Location(x=368.186707, y=-300.050568, z=0.000000)
# Current target waypoint 159/2356: Location(x=368.640961, y=-299.254242, z=0.000000)
# Current target waypoint 160/2356: Location(x=369.089783, y=-298.454834, z=0.000000)
# Current target waypoint 161/2356: Location(x=369.533203, y=-297.652405, z=0.000000)
# Current target waypoint 162/2356: Location(x=369.971100, y=-296.846985, z=0.000000)
# Current target waypoint 163/2356: Location(x=370.403595, y=-296.038635, z=0.000000)
# Current target waypoint 164/2356: Location(x=370.830536, y=-295.227325, z=0.000000)
# Current target waypoint 165/2356: Location(x=371.251923, y=-294.413116, z=0.000000)
# Current target waypoint 166/2356: Location(x=371.667816, y=-293.596130, z=0.000000)
# Current target waypoint 167/2356: Location(x=372.078156, y=-292.776276, z=0.000000)
# Current target waypoint 168/2356: Location(x=372.482910, y=-291.953644, z=0.000000)
# Current target waypoint 169/2356: Location(x=372.882050, y=-291.128357, z=0.000000)
# Current target waypoint 170/2356: Location(x=373.275574, y=-290.300323, z=0.000000)
# Current target waypoint 171/2356: Location(x=373.663513, y=-289.469635, z=0.000000)
# Current target waypoint 172/2356: Location(x=374.045776, y=-288.636383, z=0.000000)
# Current target waypoint 173/2356: Location(x=374.422333, y=-287.800507, z=0.000000)
# Current target waypoint 174/2356: Location(x=374.793243, y=-286.962067, z=0.000000)
# Current target waypoint 175/2356: Location(x=375.158386, y=-286.121155, z=0.000000)
# Current target waypoint 176/2356: Location(x=375.517883, y=-285.277802, z=0.000000)
# Current target waypoint 177/2356: Location(x=375.871613, y=-284.432007, z=0.000000)
# Current target waypoint 178/2356: Location(x=376.219604, y=-283.583832, z=0.000000)
# Current target waypoint 179/2356: Location(x=376.561798, y=-282.733307, z=0.000000)
# Current target waypoint 180/2356: Location(x=376.898254, y=-281.880493, z=0.000000)
# Current target waypoint 181/2356: Location(x=377.228821, y=-281.025360, z=0.000000)
# Current target waypoint 182/2356: Location(x=377.553650, y=-280.168091, z=0.000000)
# Current target waypoint 183/2356: Location(x=377.872620, y=-279.308563, z=0.000000)
# Current target waypoint 184/2356: Location(x=378.185730, y=-278.446930, z=0.000000)
# Current target waypoint 185/2356: Location(x=378.493011, y=-277.583160, z=0.000000)
# Current target waypoint 186/2356: Location(x=378.794403, y=-276.717346, z=0.000000)
# Current target waypoint 187/2356: Location(x=379.089905, y=-275.849518, z=0.000000)
# Current target waypoint 188/2356: Location(x=379.379486, y=-274.979675, z=0.000000)
# Current target waypoint 189/2356: Location(x=379.663208, y=-274.107880, z=0.000000)
# Current target waypoint 190/2356: Location(x=379.940948, y=-273.234161, z=0.000000)
# Current target waypoint 191/2356: Location(x=380.212799, y=-272.358612, z=0.000000)
# Current target waypoint 192/2356: Location(x=380.478638, y=-271.481232, z=0.000000)
# Current target waypoint 193/2356: Location(x=380.738556, y=-270.602051, z=0.000000)
# Current target waypoint 194/2356: Location(x=380.992432, y=-269.721130, z=0.000000)
# Current target waypoint 195/2356: Location(x=381.240387, y=-268.838501, z=0.000000)
# Current target waypoint 196/2356: Location(x=381.482330, y=-267.954224, z=0.000000)
# Current target waypoint 197/2356: Location(x=381.718262, y=-267.068298, z=0.000000)
# Current target waypoint 198/2356: Location(x=381.948090, y=-266.180817, z=0.000000)
# Current target waypoint 199/2356: Location(x=382.171997, y=-265.291779, z=0.000000)
# Current target waypoint 200/2356: Location(x=382.389771, y=-264.401245, z=0.000000)
# Current target waypoint 201/2356: Location(x=382.601562, y=-263.509277, z=0.000000)
# Current target waypoint 202/2356: Location(x=382.807251, y=-262.615845, z=0.000000)
# Current target waypoint 203/2356: Location(x=383.006866, y=-261.721039, z=0.000000)
# Current target waypoint 204/2356: Location(x=383.200409, y=-260.824951, z=0.000000)
# Current target waypoint 205/2356: Location(x=383.387878, y=-259.927521, z=0.000000)
# Current target waypoint 206/2356: Location(x=383.569183, y=-259.028870, z=0.000000)
# Current target waypoint 207/2356: Location(x=383.744415, y=-258.128998, z=0.000000)
# Current target waypoint 208/2356: Location(x=383.913574, y=-257.227905, z=0.000000)
# Current target waypoint 209/2356: Location(x=384.076538, y=-256.325745, z=0.000000)
# Current target waypoint 210/2356: Location(x=384.233398, y=-255.422516, z=0.000000)
# Current target waypoint 211/2356: Location(x=384.384125, y=-254.518188, z=0.000000)
# Current target waypoint 212/2356: Location(x=384.528687, y=-253.612869, z=0.000000)
# Current target waypoint 213/2356: Location(x=384.667145, y=-252.706589, z=0.000000)
# Current target waypoint 214/2356: Location(x=384.799408, y=-251.799393, z=0.000000)
# Current target waypoint 215/2356: Location(x=384.925476, y=-250.891357, z=0.000000)
# Current target waypoint 216/2356: Location(x=385.045410, y=-249.982422, z=0.000000)
# Current target waypoint 217/2356: Location(x=385.159149, y=-249.072739, z=0.000000)
# Current target waypoint 218/2356: Location(x=385.266724, y=-248.162277, z=0.000000)
# Current target waypoint 219/2356: Location(x=385.368073, y=-247.251129, z=0.000000)
# Current target waypoint 220/2356: Location(x=385.463287, y=-246.339279, z=0.000000)
# Current target waypoint 221/2356: Location(x=385.552277, y=-245.426834, z=0.000000)
# Current target waypoint 222/2356: Location(x=385.635071, y=-244.513809, z=0.000000)
# Current target waypoint 223/2356: Location(x=385.711670, y=-243.600220, z=0.000000)
# Current target waypoint 224/2356: Location(x=385.782043, y=-242.686142, z=0.000000)
# Current target waypoint 225/2356: Location(x=385.846252, y=-241.771622, z=0.000000)
# Current target waypoint 226/2356: Location(x=385.904175, y=-240.856674, z=0.000000)
# Current target waypoint 227/2356: Location(x=385.955902, y=-239.941330, z=0.000000)
# Current target waypoint 228/2356: Location(x=386.001434, y=-239.025696, z=0.000000)
# Current target waypoint 229/2356: Location(x=386.040710, y=-238.109756, z=0.000000)
# Current target waypoint 230/2356: Location(x=386.073792, y=-237.193558, z=0.000000)
# Current target waypoint 231/2356: Location(x=386.100647, y=-236.277176, z=0.000000)
# Current target waypoint 232/2356: Location(x=386.121246, y=-235.360626, z=0.000000)
# Current target waypoint 233/2356: Location(x=386.135681, y=-234.443970, z=0.000000)
# Current target waypoint 234/2356: Location(x=386.143860, y=-233.527206, z=0.000000)
# Current target waypoint 235/2356: Location(x=386.145752, y=-232.610428, z=0.000000)
# Current target waypoint 236/2356: Location(x=386.141510, y=-231.693649, z=0.000000)
# Current target waypoint 237/2356: Location(x=386.131744, y=-230.722824, z=0.000000)
# Current target waypoint 238/2356: Location(x=386.121307, y=-229.722885, z=0.000000)
# Current target waypoint 239/2356: Location(x=386.110870, y=-228.722931, z=0.000000)
# Current target waypoint 240/2356: Location(x=386.100403, y=-227.722992, z=0.000000)
# Current target waypoint 241/2356: Location(x=386.089966, y=-226.723038, z=0.000000)
# Current target waypoint 242/2356: Location(x=386.079529, y=-225.723099, z=0.000000)
# Current target waypoint 243/2356: Location(x=386.069061, y=-224.723145, z=0.000000)
# Current target waypoint 244/2356: Location(x=386.058624, y=-223.723206, z=0.000000)
# Current target waypoint 245/2356: Location(x=386.048187, y=-222.723267, z=0.000000)
# Current target waypoint 246/2356: Location(x=386.037720, y=-221.723312, z=0.000000)
# Current target waypoint 247/2356: Location(x=386.027283, y=-220.723373, z=0.000000)
# Current target waypoint 248/2356: Location(x=386.016846, y=-219.723419, z=0.000000)
# Current target waypoint 249/2356: Location(x=386.006378, y=-218.723480, z=0.000000)
# Current target waypoint 250/2356: Location(x=385.995941, y=-217.723526, z=0.000000)
# Current target waypoint 251/2356: Location(x=385.985504, y=-216.723587, z=0.000000)
# Current target waypoint 252/2356: Location(x=385.975037, y=-215.723648, z=0.000000)
# Current target waypoint 253/2356: Location(x=385.964600, y=-214.723694, z=0.000000)
# Current target waypoint 407/2356: Location(x=383.453674, y=-19.973120, z=0.000000)
# Current target waypoint 408/2356: Location(x=383.305115, y=-19.214325, z=0.000000)
# Current target waypoint 409/2356: Location(x=383.142487, y=-18.458408, z=0.000000)
# Current target waypoint 410/2356: Location(x=365.466034, y=7.195836, z=0.021045)
# Current target waypoint 411/2356: Location(x=364.817566, y=7.616990, z=0.025647)
# Current target waypoint 412/2356: Location(x=364.161438, y=8.026068, z=0.030703)
# Current target waypoint 413/2356: Location(x=363.497864, y=8.422929, z=0.036214)
# Current target waypoint 414/2356: Location(x=362.827026, y=8.807434, z=0.042180)
# Current target waypoint 415/2356: Location(x=362.149200, y=9.179461, z=0.048600)
# Current target waypoint 416/2356: Location(x=361.464630, y=9.538873, z=0.055474)
# Current target waypoint 417/2356: Location(x=360.773468, y=9.885553, z=0.062804)
# Current target waypoint 418/2356: Location(x=360.076050, y=10.219378, z=0.070588)
# Current target waypoint 419/2356: Location(x=359.372589, y=10.540234, z=0.078826)
# Current target waypoint 420/2356: Location(x=358.663269, y=10.848015, z=0.087519)
# Current target waypoint 421/2356: Location(x=357.948395, y=11.142611, z=0.096667)
# Current target waypoint 422/2356: Location(x=357.228149, y=11.423921, z=0.106270)
# Current target waypoint 423/2356: Location(x=356.502869, y=11.691850, z=0.116326)
# Current target waypoint 424/2356: Location(x=355.772736, y=11.946306, z=0.126838)
# Current target waypoint 425/2356: Location(x=355.037994, y=12.187204, z=0.137804)
# Current target waypoint 426/2356: Location(x=354.298950, y=12.414456, z=0.149225)
# Current target waypoint 427/2356: Location(x=353.555817, y=12.627994, z=0.161101)
# Current target waypoint 428/2356: Location(x=352.808868, y=12.827736, z=0.173431)
# Current target waypoint 429/2356: Location(x=352.058319, y=13.013615, z=0.186215)
# Current target waypoint 430/2356: Location(x=351.304474, y=13.185572, z=0.199454)
# Current target waypoint 431/2356: Location(x=350.547607, y=13.343538, z=0.213148)
# Current target waypoint 432/2356: Location(x=349.787903, y=13.487469, z=0.227297)
# Current target waypoint 433/2356: Location(x=349.025696, y=13.617313, z=0.241900)
# Current target waypoint 434/2356: Location(x=348.261169, y=13.733022, z=0.256958)
# Current target waypoint 435/2356: Location(x=347.494659, y=13.834562, z=0.272470)
# Current target waypoint 436/2356: Location(x=346.726410, y=13.921893, z=0.288437)
# Current target waypoint 437/2356: Location(x=345.956665, y=13.994986, z=0.304858)
# Current target waypoint 438/2356: Location(x=345.185699, y=14.053820, z=0.321734)
# Current target waypoint 439/2356: Location(x=344.413788, y=14.098369, z=0.339065)
# Current target waypoint 440/2356: Location(x=343.641205, y=14.128620, z=0.356851)
# Current target waypoint 441/2356: Location(x=342.868134, y=14.144567, z=0.375091)
# Current target waypoint 442/2356: Location(x=342.094940, y=14.146196, z=0.393785)
# Current target waypoint 443/2356: Location(x=341.216583, y=14.133262, z=0.412934)
# Current target waypoint 444/2356: Location(x=340.216736, y=14.116193, z=0.432538)
# Current target waypoint 445/2356: Location(x=339.216858, y=14.099126, z=0.452596)
# Current target waypoint 446/2356: Location(x=338.217010, y=14.082059, z=0.473110)
# Current target waypoint 447/2356: Location(x=337.217163, y=14.064992, z=0.494077)
# Current target waypoint 448/2356: Location(x=336.217316, y=14.047925, z=0.515499)
# Current target waypoint 449/2356: Location(x=335.217468, y=14.030858, z=0.537376)
# Current target waypoint 450/2356: Location(x=334.217590, y=14.013791, z=0.559708)
# Current target waypoint 451/2356: Location(x=333.217743, y=13.996724, z=0.582494)
# Current target waypoint 452/2356: Location(x=332.217896, y=13.979657, z=0.605734)
# Current target waypoint 453/2356: Location(x=331.218048, y=13.962588, z=0.629430)
# Current target waypoint 454/2356: Location(x=330.218170, y=13.945521, z=0.653580)
# Current target waypoint 455/2356: Location(x=329.218323, y=13.928454, z=0.678184)
# Current target waypoint 456/2356: Location(x=328.218475, y=13.911387, z=0.703243)
# Current target waypoint 457/2356: Location(x=327.218628, y=13.894320, z=0.728757)
# Current target waypoint 458/2356: Location(x=326.218750, y=13.877254, z=0.754725)
# Current target waypoint 459/2356: Location(x=325.218903, y=13.860187, z=0.781148)
# Current target waypoint 460/2356: Location(x=324.219055, y=13.843120, z=0.808026)
# Current target waypoint 461/2356: Location(x=323.219208, y=13.826053, z=0.835358)
# Current target waypoint 462/2356: Location(x=322.219360, y=13.808986, z=0.863145)
# Current target waypoint 463/2356: Location(x=321.219482, y=13.791917, z=0.891386)
# Current target waypoint 464/2356: Location(x=320.219635, y=13.774850, z=0.920082)
# Current target waypoint 465/2356: Location(x=319.219788, y=13.757783, z=0.949233)
# Current target waypoint 466/2356: Location(x=318.219940, y=13.740716, z=0.978838)
# Current target waypoint 467/2356: Location(x=317.220062, y=13.723649, z=1.008898)
# Current target waypoint 468/2356: Location(x=316.220215, y=13.706582, z=1.039412)
# Current target waypoint 469/2356: Location(x=315.220367, y=13.689515, z=1.070382)
# Current target waypoint 470/2356: Location(x=314.220520, y=13.672448, z=1.101805)
# Current target waypoint 471/2356: Location(x=313.220673, y=13.655381, z=1.133683)
# Current target waypoint 472/2356: Location(x=312.220795, y=13.638312, z=1.166016)
# Current target waypoint 473/2356: Location(x=311.220947, y=13.621245, z=1.198804)
# Current target waypoint 474/2356: Location(x=310.221100, y=13.604178, z=1.232046)
# Current target waypoint 475/2356: Location(x=309.221252, y=13.587111, z=1.265743)
# Current target waypoint 476/2356: Location(x=308.221375, y=13.570045, z=1.299894)
# Current target waypoint 477/2356: Location(x=307.221527, y=13.552978, z=1.334500)
# Current target waypoint 478/2356: Location(x=306.221680, y=13.535911, z=1.369560)
# Current target waypoint 479/2356: Location(x=305.221832, y=13.518844, z=1.405076)
# Current target waypoint 480/2356: Location(x=304.221954, y=13.501777, z=1.441046)
# Current target waypoint 481/2356: Location(x=303.222107, y=13.484710, z=1.477470)
# Current target waypoint 482/2356: Location(x=302.222260, y=13.467641, z=1.514349)
# Current target waypoint 483/2356: Location(x=301.222412, y=13.450574, z=1.551682)
# Current target waypoint 484/2356: Location(x=300.222565, y=13.433507, z=1.589471)
# Current target waypoint 485/2356: Location(x=299.222687, y=13.416440, z=1.627714)
# Current target waypoint 486/2356: Location(x=298.222839, y=13.399373, z=1.666411)
# Current target waypoint 487/2356: Location(x=297.222992, y=13.382306, z=1.705563)
# Current target waypoint 488/2356: Location(x=296.223145, y=13.365239, z=1.745170)
# Current target waypoint 489/2356: Location(x=295.223297, y=13.348172, z=1.785231)
# Current target waypoint 490/2356: Location(x=294.223419, y=13.331105, z=1.825747)
# Current target waypoint 491/2356: Location(x=293.223572, y=13.314036, z=1.866717)
# Current target waypoint 492/2356: Location(x=292.223724, y=13.296969, z=1.908142)
# Current target waypoint 493/2356: Location(x=291.223846, y=13.279902, z=1.950022)
# Current target waypoint 494/2356: Location(x=290.223999, y=13.262836, z=1.992356)
# Current target waypoint 495/2356: Location(x=289.224152, y=13.245769, z=2.035146)
# Current target waypoint 496/2356: Location(x=288.224304, y=13.228702, z=2.078389)
# Current target waypoint 497/2356: Location(x=287.224457, y=13.211635, z=2.122087)
# Current target waypoint 498/2356: Location(x=286.224579, y=13.194568, z=2.166240)
# Current target waypoint 499/2356: Location(x=285.224731, y=13.177501, z=2.210847)
# Current target waypoint 500/2356: Location(x=284.224884, y=13.160434, z=2.255909)
# Current target waypoint 501/2356: Location(x=283.225037, y=13.143365, z=2.301426)
# Current target waypoint 502/2356: Location(x=282.225189, y=13.126298, z=2.347397)
# Current target waypoint 503/2356: Location(x=281.225311, y=13.109231, z=2.393823)
# Current target waypoint 504/2356: Location(x=280.225464, y=13.092164, z=2.440703)
# Current target waypoint 505/2356: Location(x=279.225616, y=13.075097, z=2.488038)
# Current target waypoint 506/2356: Location(x=278.225769, y=13.058030, z=2.535828)
# Current target waypoint 507/2356: Location(x=277.225891, y=13.040963, z=2.584072)
# Current target waypoint 508/2356: Location(x=276.226044, y=13.023896, z=2.632771)
# Current target waypoint 509/2356: Location(x=275.226196, y=13.006829, z=2.681925)
# Current target waypoint 510/2356: Location(x=274.226349, y=12.989760, z=2.731533)
# Current target waypoint 511/2356: Location(x=273.226471, y=12.972693, z=2.781595)
# Current target waypoint 512/2356: Location(x=272.226624, y=12.955626, z=2.832113)
# Current target waypoint 513/2356: Location(x=271.226776, y=12.938560, z=2.883085)
# Current target waypoint 514/2356: Location(x=270.226929, y=12.921493, z=2.934511)
# Current target waypoint 515/2356: Location(x=269.227081, y=12.904426, z=2.986392)
# Current target waypoint 516/2356: Location(x=268.227203, y=12.887359, z=3.038728)
# Current target waypoint 517/2356: Location(x=267.227356, y=12.870292, z=3.091518)
# Current target waypoint 518/2356: Location(x=266.227509, y=12.853225, z=3.144763)
# Current target waypoint 519/2356: Location(x=265.227631, y=12.836158, z=3.198463)
# Current target waypoint 520/2356: Location(x=264.227814, y=12.819091, z=3.252617)
# Current target waypoint 521/2356: Location(x=263.227936, y=12.802022, z=3.307226)
# Current target waypoint 522/2356: Location(x=262.228088, y=12.784955, z=3.362289)
# Current target waypoint 523/2356: Location(x=261.228241, y=12.767888, z=3.417808)
# Current target waypoint 524/2356: Location(x=260.228363, y=12.750821, z=3.473780)
# Current target waypoint 564/2356: Location(x=220.234207, y=12.068135, z=5.859381)
# Current target waypoint 565/2356: Location(x=219.234344, y=12.051068, z=5.919428)
# Current target waypoint 566/2356: Location(x=218.234497, y=12.034001, z=5.979475)
# Current target waypoint 567/2356: Location(x=217.234650, y=12.016932, z=6.039522)
# Current target waypoint 568/2356: Location(x=216.234787, y=11.999866, z=6.099569)
# Current target waypoint 569/2356: Location(x=215.234924, y=11.982799, z=6.159616)
# Current target waypoint 570/2356: Location(x=214.235077, y=11.965732, z=6.219663)
# Current target waypoint 571/2356: Location(x=213.235229, y=11.948665, z=6.279710)
# Current target waypoint 572/2356: Location(x=212.235367, y=11.931598, z=6.339756)
# Current target waypoint 573/2356: Location(x=211.235519, y=11.914531, z=6.399804)
# Current target waypoint 574/2356: Location(x=210.235657, y=11.897464, z=6.459850)
# Current target waypoint 575/2356: Location(x=209.235809, y=11.880397, z=6.519867)
# Current target waypoint 576/2356: Location(x=208.235947, y=11.863330, z=6.579557)
# Current target waypoint 577/2356: Location(x=207.236099, y=11.846263, z=6.638848)
# Current target waypoint 578/2356: Location(x=206.236237, y=11.829194, z=6.697738)
# Current target waypoint 579/2356: Location(x=205.236389, y=11.812127, z=6.756227)
# Current target waypoint 580/2356: Location(x=204.236542, y=11.795060, z=6.814317)
# Current target waypoint 581/2356: Location(x=203.236679, y=11.777993, z=6.872006)
# Current target waypoint 582/2356: Location(x=202.236832, y=11.760926, z=6.929295)
# Current target waypoint 583/2356: Location(x=201.236969, y=11.743859, z=6.986184)
# Current target waypoint 584/2356: Location(x=200.237122, y=11.726792, z=7.042672)
# Current target waypoint 585/2356: Location(x=199.237259, y=11.709725, z=7.098760)
# Current target waypoint 586/2356: Location(x=198.237411, y=11.692658, z=7.154447)
# Current target waypoint 587/2356: Location(x=197.237549, y=11.675590, z=7.209734)
# Current target waypoint 588/2356: Location(x=196.237701, y=11.658523, z=7.264621)
# Current target waypoint 589/2356: Location(x=195.237839, y=11.641456, z=7.319108)
# Current target waypoint 590/2356: Location(x=194.237991, y=11.624389, z=7.373194)
# Current target waypoint 591/2356: Location(x=193.238144, y=11.607322, z=7.426880)
# Current target waypoint 592/2356: Location(x=192.238281, y=11.590255, z=7.480165)
# Current target waypoint 593/2356: Location(x=191.238434, y=11.573188, z=7.533051)
# Current target waypoint 594/2356: Location(x=190.238571, y=11.556121, z=7.585536)
# Current target waypoint 595/2356: Location(x=189.238724, y=11.539054, z=7.637621)
# Current target waypoint 596/2356: Location(x=188.238861, y=11.521987, z=7.689305)
# Current target waypoint 597/2356: Location(x=187.239014, y=11.504918, z=7.740589)
# Current target waypoint 598/2356: Location(x=186.239151, y=11.487851, z=7.791473)
# Current target waypoint 599/2356: Location(x=185.239304, y=11.470784, z=7.841957)
# Current target waypoint 600/2356: Location(x=184.239441, y=11.453717, z=7.892040)
# Current target waypoint 601/2356: Location(x=183.239594, y=11.436650, z=7.941722)
# Current target waypoint 602/2356: Location(x=182.239746, y=11.419583, z=7.991005)
# Current target waypoint 603/2356: Location(x=181.239883, y=11.402516, z=8.039887)
