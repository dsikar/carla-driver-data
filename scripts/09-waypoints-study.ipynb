# %% [markdown]
# # Waypoint study
# Place and visualise waypoints to select routes

# %%
# Boilerplate code
import carla

# Connect to the Carla Simulator
client = carla.Client('localhost', 2000)
world = client.get_world()

# %% [markdown]
# ## Gemini online

# %%
# import carla

# # Connect to the Carla Simulator
# client = carla.Client('localhost', 2000)
# world = client.get_world()

# Get a specific waypoint (you can replace this with your desired method)
waypoint = world.get_map().get_waypoint(carla.Location(x=100, y=100, z=0))

# Extract and print the properties
print("Waypoint Properties:")
print("  Position:", waypoint.transform.location)
print("  Orientation:", waypoint.transform.rotation)
print("  Road ID:", waypoint.road_id)
print("  Lane ID:", waypoint.lane_id)
# Out:
# Waypoint Properties:
#   Position: Location(x=125.445129, y=110.118446, z=6.451760)
#   Orientation: Rotation(pitch=355.345398, yaw=111.437843, roll=0.000000)
#   Road ID: 31
#   Lane ID: 2

# %% [markdown]
# ## Gemini API
# Gemini API (Formatted by Gemini browser app)

# %%
# import carla

# # Connect to the Carla simulator
# client = carla.Client('localhost', 2000)
# client.set_timeout(10.0)
# world = client.get_world()

# Get a map and spawn point
map = world.get_map()
spawn_points = map.get_spawn_points()

# Choose a spawn point (or define your own location)
spawn_point = spawn_points[0]

# Get the road segment and lane for spawn point
waypoint = map.get_waypoint(spawn_point.location)
print(f"Waypoint at spawn point: {waypoint}")
print(f"Road ID at spawn point: {waypoint.road_id}")
print(f"Lane ID at spawn point: {waypoint.lane_id}")
print(f"Is Junction at spawn point?: {waypoint.is_junction}")

# Generate waypoints along a route
waypoint_route = []
for i in range(0, 100, 10):  # Example: 10 waypoints spaced 10 meters apart. Adjust for more or less.
    wp = map.get_waypoint(spawn_point.location, project_to_road=True, lane_type=carla.LaneType.Driving)
    next_wp = wp.next(i)[0]
    waypoint_route.append(next_wp)
    spawn_point = next_wp.transform.location

# Analyze waypoint properties
for i, waypoint in enumerate(waypoint_route):
    print(f"\n--- Waypoint {i+1} ---")
    print(f"Location: {waypoint.transform.location}")
    print(f"Rotation: {waypoint.transform.rotation}")
    print(f"Road ID: {waypoint.road_id}")
    print(f"Lane ID: {waypoint.lane_id}")
    print(f"Lane type: {waypoint.lane_type}")
    print(f"Is junction: {waypoint.is_junction}")
    print(f"Speed limit: {waypoint.speed_limit}")
    try:  # Forward vector might not always be present
        print(f"Forward vector: {waypoint.transform.get_forward_vector()}")
    except:
        print("Could not get forward vector")

# Disconnect from the client
#client.apply_batch([carla.command.DestroyActor(x) for x in world.get_actors().filter('*vehicle*')])
# Out:
# Waypoint at spawn point: Waypoint(Transform(Location(x=225.313568, y=-364.129425, z=0.000000), Rotation(pitch=0.000000, yaw=0.204755, roll=0.000000)))
# Road ID at spawn point: 43
# Lane ID at spawn point: -4
# Is Junction at spawn point?: False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-d84c171fcac9> in <module>
#      24 for i in range(0, 100, 10):  # Example: 10 waypoints spaced 10 meters apart. Adjust for more or less.
#      25     wp = map.get_waypoint(spawn_point.location, project_to_road=True, lane_type=carla.LaneType.Driving)
# ---> 26     next_wp = wp.next(i)[0]
#      27     waypoint_route.append(next_wp)
#      28     spawn_point = next_wp.transform.location
#
# RuntimeError: distance > 0.0

# %% [markdown]
# ## Claude

# %%
def analyze_waypoint_properties(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    if not waypoints:
        print("No waypoints found")
        return
        
    wp = waypoints[0]
    
    # Print all properties of the waypoint object
    print("\nWaypoint Properties:")
    for attr in dir(wp):
        if not attr.startswith('_'):  # Skip private attributes
            try:
                value = getattr(wp, attr)
                if not callable(value):  # Skip methods
                    print(f"{attr}: {value}")
            except:
                print(f"{attr}: Unable to access")
                
    # Print all properties of the transform
    print("\nTransform Properties:")
    for attr in dir(wp.transform):
        if not attr.startswith('_'):
            try:
                value = getattr(wp.transform, attr)
                if not callable(value):
                    print(f"{attr}: {value}")
            except:
                print(f"{attr}: Unable to access")
                
    return waypoints[0]

mywaypoint = analyze_waypoint_properties(world)
# Out:
# Waypoint Properties:
# id: 11910987357902096025
# is_intersection: True
# is_junction: True
# junction_id: 1593
# lane_change: Left
# lane_id: -4
# lane_type: Driving
# lane_width: 3.5
# left_lane_marking: <carla.libcarla.LaneMarking object at 0x7feb619ef348>
# right_lane_marking: <carla.libcarla.LaneMarking object at 0x7feb619ef348>
# road_id: 1602
# s: 2.220446049250313e-15
# section_id: 0
# transform: Transform(Location(x=379.693237, y=-19.074064, z=0.000000), Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000))
#
# Transform Properties:
# location: Location(x=379.693237, y=-19.074064, z=0.000000)
# rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)

# %% [markdown]
# ## ChatGPT

# %%
import carla

def analyze_waypoints():
    # Connect to the Carla Simulator
    client = carla.Client('localhost', 2000)  # Update host and port if necessary
    client.set_timeout(10.0)

    # Get the world and map
    world = client.get_world()
    carla_map = world.get_map()

    # Get waypoints at a specific resolution
    resolution = 2.0  # You can adjust the resolution (meters)
    waypoints = carla_map.generate_waypoints(resolution)

    # Analyze waypoint properties
    waypoint_data = []
    for waypoint in waypoints:
        data = {
            "location": waypoint.transform.location,
            "rotation": waypoint.transform.rotation,
            "lane_type": waypoint.lane_type.name,
            "road_id": waypoint.road_id,
            "section_id": waypoint.section_id,
            "lane_id": waypoint.lane_id,
            "is_intersection": waypoint.is_intersection,
        }
        waypoint_data.append(data)

    # Output results for analysis
    for i, wp in enumerate(waypoint_data, 1):
        print(f"Waypoint {i}:")
        print(f"  Location: {wp['location']}")
        print(f"  Rotation: {wp['rotation']}")
        print(f"  Lane Type: {wp['lane_type']}")
        print(f"  Road ID: {wp['road_id']}, Section ID: {wp['section_id']}, Lane ID: {wp['lane_id']}")
        print(f"  Is Intersection: {wp['is_intersection']}")
        print("-" * 30)

#if __name__ == "__main__":
analyze_waypoints()
# Out:
# Waypoint 1:
#   Location: Location(x=379.693237, y=-19.074064, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 2:
#   Location: Location(x=383.104889, y=-18.292522, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 3:
#   Location: Location(x=386.516510, y=-17.510981, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 4:
#   Location: Location(x=389.928131, y=-16.729439, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 5:
#   Location: Location(x=379.351379, y=-17.699169, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=105.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 6:
#   Location: Location(x=382.731720, y=-16.791874, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=105.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 7:
#   Location: Location(x=386.112091, y=-15.884577, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=105.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 8:
#   Location: Location(x=389.492432, y=-14.977281, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=105.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 9:
#   Location: Location(x=378.958832, y=-16.337875, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=107.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 10:
#   Location: Location(x=382.303284, y=-15.306067, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=107.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 11:
#   Location: Location(x=385.647736, y=-14.274260, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=107.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 12:
#   Location: Location(x=388.992188, y=-13.242453, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=107.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 13:
#   Location: Location(x=378.516205, y=-14.992042, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=109.267097, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 14:
#   Location: Location(x=381.820160, y=-13.837138, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=109.267097, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 15:
#   Location: Location(x=385.124115, y=-12.682234, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=109.267097, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 16:
#   Location: Location(x=388.428101, y=-11.527330, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=109.267097, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 17:
#   Location: Location(x=378.024017, y=-13.663518, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=111.388535, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 18:
#   Location: Location(x=381.282990, y=-12.387100, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=111.388535, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 19:
#   Location: Location(x=384.541931, y=-11.110683, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=111.388535, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 20:
#   Location: Location(x=387.800873, y=-9.834267, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=111.388535, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 21:
#   Location: Location(x=377.483002, y=-12.354125, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=113.509972, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 22:
#   Location: Location(x=380.692444, y=-10.957944, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=113.509972, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 23:
#   Location: Location(x=383.901917, y=-9.561764, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=113.509972, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 24:
#   Location: Location(x=387.111389, y=-8.165583, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=113.509972, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 25:
#   Location: Location(x=376.893890, y=-11.065655, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=115.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 26:
#   Location: Location(x=380.049500, y=-9.551624, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=115.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 27:
#   Location: Location(x=383.205078, y=-8.037594, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=115.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 28:
#   Location: Location(x=386.360657, y=-6.523563, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=115.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 29:
#   Location: Location(x=376.257477, y=-9.799874, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=117.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 30:
#   Location: Location(x=379.354858, y=-8.170070, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=117.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 31:
#   Location: Location(x=382.452240, y=-6.540265, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=117.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 32:
#   Location: Location(x=385.549622, y=-4.910460, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=117.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 33:
#   Location: Location(x=375.574677, y=-8.558522, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=119.874283, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 34:
#   Location: Location(x=378.609589, y=-6.815177, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=119.874283, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 35:
#   Location: Location(x=381.644531, y=-5.071832, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=119.874283, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 36:
#   Location: Location(x=384.679443, y=-3.328486, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=119.874283, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 37:
#   Location: Location(x=374.846375, y=-7.343294, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=121.995712, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 38:
#   Location: Location(x=377.814667, y=-5.488798, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=121.995712, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 39:
#   Location: Location(x=380.782990, y=-3.634303, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=121.995712, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 40:
#   Location: Location(x=383.751282, y=-1.779807, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=121.995712, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 41:
#   Location: Location(x=374.073578, y=-6.155864, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=124.117149, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 42:
#   Location: Location(x=376.971222, y=-4.192760, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=124.117149, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 43:
#   Location: Location(x=379.868835, y=-2.229655, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=124.117149, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 44:
#   Location: Location(x=382.766449, y=-0.266550, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=124.117149, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 45:
#   Location: Location(x=373.257355, y=-4.997849, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=126.238579, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 46:
#   Location: Location(x=376.080322, y=-2.928828, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=126.238579, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 47:
#   Location: Location(x=378.903290, y=-0.859806, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=126.238579, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 48:
#   Location: Location(x=381.726257, y=1.209215, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=126.238579, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 49:
#   Location: Location(x=372.398834, y=-3.870844, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=128.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 50:
#   Location: Location(x=375.143280, y=-1.698742, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=128.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 51:
#   Location: Location(x=377.887726, y=0.473361, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=128.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 52:
#   Location: Location(x=380.632172, y=2.645464, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=128.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 53:
#   Location: Location(x=371.499176, y=-2.776392, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=130.481461, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 54:
#   Location: Location(x=374.161316, y=-0.504185, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=130.481461, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 55:
#   Location: Location(x=376.823486, y=1.768022, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=130.481461, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 56:
#   Location: Location(x=379.485626, y=4.040229, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=130.481461, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 57:
#   Location: Location(x=370.559601, y=-1.715992, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=132.602890, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 58:
#   Location: Location(x=373.135834, y=0.653203, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=132.602890, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 59:
#   Location: Location(x=375.712067, y=3.022399, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=132.602890, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 60:
#   Location: Location(x=378.288269, y=5.391595, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=132.602890, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 61:
#   Location: Location(x=369.581451, y=-0.691104, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=134.724319, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 62:
#   Location: Location(x=372.068207, y=1.771834, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=134.724319, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 63:
#   Location: Location(x=374.554962, y=4.234772, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=134.724319, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 64:
#   Location: Location(x=377.041718, y=6.697710, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=134.724319, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 65:
#   Location: Location(x=368.566010, y=0.296880, z=0.000069)
#   Rotation: Rotation(pitch=0.014383, yaw=136.845749, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 66:
#   Location: Location(x=370.959900, y=2.850183, z=0.000069)
#   Rotation: Rotation(pitch=0.014383, yaw=136.845749, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 67:
#   Location: Location(x=373.353760, y=5.403486, z=0.000069)
#   Rotation: Rotation(pitch=0.014383, yaw=136.845749, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 68:
#   Location: Location(x=375.747650, y=7.956789, z=0.000069)
#   Rotation: Rotation(pitch=0.014383, yaw=136.845749, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 69:
#   Location: Location(x=367.514709, y=1.246590, z=0.001481)
#   Rotation: Rotation(pitch=0.066477, yaw=138.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 70:
#   Location: Location(x=369.812439, y=3.886758, z=0.001481)
#   Rotation: Rotation(pitch=0.066477, yaw=138.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 71:
#   Location: Location(x=372.110168, y=6.526927, z=0.001481)
#   Rotation: Rotation(pitch=0.066477, yaw=138.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 72:
#   Location: Location(x=374.407867, y=9.167096, z=0.001481)
#   Rotation: Rotation(pitch=0.066477, yaw=138.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 73:
#   Location: Location(x=366.428986, y=2.156737, z=0.004710)
#   Rotation: Rotation(pitch=0.118572, yaw=141.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 74:
#   Location: Location(x=368.627380, y=4.880152, z=0.004710)
#   Rotation: Rotation(pitch=0.118572, yaw=141.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 75:
#   Location: Location(x=370.825806, y=7.603568, z=0.004710)
#   Rotation: Rotation(pitch=0.118572, yaw=141.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 76:
#   Location: Location(x=373.024200, y=10.326982, z=0.004710)
#   Rotation: Rotation(pitch=0.118572, yaw=141.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 77:
#   Location: Location(x=365.310272, y=3.026069, z=0.009758)
#   Rotation: Rotation(pitch=0.170667, yaw=143.210068, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 78:
#   Location: Location(x=367.406342, y=5.828998, z=0.009758)
#   Rotation: Rotation(pitch=0.170667, yaw=143.210068, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 79:
#   Location: Location(x=369.502441, y=8.631926, z=0.009758)
#   Rotation: Rotation(pitch=0.170667, yaw=143.210068, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 80:
#   Location: Location(x=371.598541, y=11.434855, z=0.009758)
#   Rotation: Rotation(pitch=0.170667, yaw=143.210068, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 81:
#   Location: Location(x=364.160156, y=3.853394, z=0.016625)
#   Rotation: Rotation(pitch=0.222761, yaw=145.331497, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -4
#   Is Intersection: True
# ------------------------------
# Waypoint 82:
#   Location: Location(x=366.151062, y=6.731993, z=0.016625)
#   Rotation: Rotation(pitch=0.222761, yaw=145.331497, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -3
#   Is Intersection: True
# ------------------------------
# Waypoint 83:
#   Location: Location(x=368.141968, y=9.610592, z=0.016625)
#   Rotation: Rotation(pitch=0.222761, yaw=145.331497, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -2
#   Is Intersection: True
# ------------------------------
# Waypoint 84:
#   Location: Location(x=370.132843, y=12.489192, z=0.016625)
#   Rotation: Rotation(pitch=0.222761, yaw=145.331497, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1602, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 85:
#   Location: Location(x=400.162994, y=-14.384812, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=282.902802, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 86:
#   Location: Location(x=403.574646, y=-13.603270, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=282.902802, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 87:
#   Location: Location(x=406.986267, y=-12.821728, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=282.902802, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 88:
#   Location: Location(x=410.397888, y=-12.040186, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=282.902802, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 89:
#   Location: Location(x=399.633514, y=-12.255391, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=285.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 90:
#   Location: Location(x=403.013855, y=-11.348095, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=285.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 91:
#   Location: Location(x=406.394226, y=-10.440798, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=285.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 92:
#   Location: Location(x=409.774567, y=-9.533502, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=285.024231, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 93:
#   Location: Location(x=399.025574, y=-10.147031, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=287.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 94:
#   Location: Location(x=402.370026, y=-9.115224, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=287.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 95:
#   Location: Location(x=405.714478, y=-8.083416, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=287.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 96:
#   Location: Location(x=409.058929, y=-7.051610, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=287.145660, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 97:
#   Location: Location(x=398.339996, y=-8.062619, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=289.267090, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 98:
#   Location: Location(x=401.643951, y=-6.907716, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=289.267090, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 99:
#   Location: Location(x=404.947937, y=-5.752812, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=289.267090, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 100:
#   Location: Location(x=408.251892, y=-4.597908, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=289.267090, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 101:
#   Location: Location(x=397.577728, y=-6.005016, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=291.388550, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 102:
#   Location: Location(x=400.836700, y=-4.728599, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=291.388550, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 103:
#   Location: Location(x=404.095642, y=-3.452182, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=291.388550, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 104:
#   Location: Location(x=407.354584, y=-2.175765, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=291.388550, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 105:
#   Location: Location(x=396.739807, y=-3.977041, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=293.509979, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 106:
#   Location: Location(x=399.949249, y=-2.580860, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=293.509979, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 107:
#   Location: Location(x=403.158722, y=-1.184680, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=293.509979, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 108:
#   Location: Location(x=406.368195, y=0.211501, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=293.509979, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 109:
#   Location: Location(x=395.827393, y=-1.981472, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=295.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 110:
#   Location: Location(x=398.983002, y=-0.467442, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=295.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 111:
#   Location: Location(x=402.138580, y=1.046589, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=295.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 112:
#   Location: Location(x=405.294159, y=2.560619, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=295.631409, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 113:
#   Location: Location(x=394.841736, y=-0.021047, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=297.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 114:
#   Location: Location(x=397.939117, y=1.608758, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=297.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 115:
#   Location: Location(x=401.036499, y=3.238563, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=297.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 116:
#   Location: Location(x=404.133850, y=4.868367, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=297.752838, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 117:
#   Location: Location(x=393.784210, y=1.901549, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=299.874268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 118:
#   Location: Location(x=396.819122, y=3.644895, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=299.874268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 119:
#   Location: Location(x=399.854034, y=5.388240, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=299.874268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 120:
#   Location: Location(x=402.888977, y=7.131585, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=299.874268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 121:
#   Location: Location(x=392.656219, y=3.783679, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=301.995728, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 122:
#   Location: Location(x=395.624512, y=5.638175, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=301.995728, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 123:
#   Location: Location(x=398.592834, y=7.492670, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=301.995728, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 124:
#   Location: Location(x=401.561127, y=9.347166, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=301.995728, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 125:
#   Location: Location(x=391.459320, y=5.622763, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=304.117157, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 126:
#   Location: Location(x=394.356964, y=7.585867, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=304.117157, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 127:
#   Location: Location(x=397.254578, y=9.548972, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=304.117157, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 128:
#   Location: Location(x=400.152191, y=11.512076, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=304.117157, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 129:
#   Location: Location(x=390.195190, y=7.416280, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=306.238586, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 130:
#   Location: Location(x=393.018158, y=9.485302, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=306.238586, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 131:
#   Location: Location(x=395.841125, y=11.554323, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=306.238586, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 132:
#   Location: Location(x=398.664093, y=13.623344, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=306.238586, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 133:
#   Location: Location(x=388.865509, y=9.161772, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=308.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 134:
#   Location: Location(x=391.609955, y=11.333875, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=308.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 135:
#   Location: Location(x=394.354401, y=13.505977, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=308.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 136:
#   Location: Location(x=397.098846, y=15.678080, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=308.360016, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 137:
#   Location: Location(x=387.472107, y=10.856850, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=310.481445, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 138:
#   Location: Location(x=390.134247, y=13.129057, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=310.481445, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 139:
#   Location: Location(x=392.796417, y=15.401264, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=310.481445, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 140:
#   Location: Location(x=395.458557, y=17.673470, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=310.481445, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 141:
#   Location: Location(x=386.016937, y=12.499182, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=312.602905, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 142:
#   Location: Location(x=388.593170, y=14.868378, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=312.602905, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 143:
#   Location: Location(x=391.169373, y=17.237574, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=312.602905, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 144:
#   Location: Location(x=393.745605, y=19.606770, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=312.602905, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 145:
#   Location: Location(x=384.501984, y=14.086523, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=314.724304, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 146:
#   Location: Location(x=386.988739, y=16.549461, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=314.724304, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 147:
#   Location: Location(x=389.475494, y=19.012400, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=314.724304, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 148:
#   Location: Location(x=391.962219, y=21.475338, z=0.000000)
#   Rotation: Rotation(pitch=360.000000, yaw=314.724304, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 149:
#   Location: Location(x=382.929260, y=15.616697, z=0.000069)
#   Rotation: Rotation(pitch=359.985626, yaw=316.845764, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 150:
#   Location: Location(x=385.323151, y=18.170002, z=0.000069)
#   Rotation: Rotation(pitch=359.985626, yaw=316.845764, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 151:
#   Location: Location(x=387.717010, y=20.723305, z=0.000069)
#   Rotation: Rotation(pitch=359.985626, yaw=316.845764, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 152:
#   Location: Location(x=390.110901, y=23.276608, z=0.000069)
#   Rotation: Rotation(pitch=359.985626, yaw=316.845764, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 153:
#   Location: Location(x=381.301025, y=17.087603, z=0.001481)
#   Rotation: Rotation(pitch=359.933533, yaw=318.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 154:
#   Location: Location(x=383.598755, y=19.727772, z=0.001481)
#   Rotation: Rotation(pitch=359.933533, yaw=318.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 155:
#   Location: Location(x=385.896454, y=22.367941, z=0.001481)
#   Rotation: Rotation(pitch=359.933533, yaw=318.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 156:
#   Location: Location(x=388.194183, y=25.008110, z=0.001481)
#   Rotation: Rotation(pitch=359.933533, yaw=318.967194, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 157:
#   Location: Location(x=379.619446, y=18.497229, z=0.004710)
#   Rotation: Rotation(pitch=359.881439, yaw=321.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 158:
#   Location: Location(x=381.817841, y=21.220642, z=0.004710)
#   Rotation: Rotation(pitch=359.881439, yaw=321.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 159:
#   Location: Location(x=384.016266, y=23.944057, z=0.004710)
#   Rotation: Rotation(pitch=359.881439, yaw=321.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 160:
#   Location: Location(x=386.214661, y=26.667473, z=0.004710)
#   Rotation: Rotation(pitch=359.881439, yaw=321.088623, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 161:
#   Location: Location(x=377.886810, y=19.843639, z=0.009758)
#   Rotation: Rotation(pitch=359.829346, yaw=323.210083, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 162:
#   Location: Location(x=379.982880, y=22.646568, z=0.009758)
#   Rotation: Rotation(pitch=359.829346, yaw=323.210083, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 163:
#   Location: Location(x=382.078979, y=25.449497, z=0.009758)
#   Rotation: Rotation(pitch=359.829346, yaw=323.210083, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 164:
#   Location: Location(x=384.175079, y=28.252426, z=0.009758)
#   Rotation: Rotation(pitch=359.829346, yaw=323.210083, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 165:
#   Location: Location(x=376.105530, y=21.124990, z=0.016625)
#   Rotation: Rotation(pitch=359.777252, yaw=325.331482, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 3
#   Is Intersection: True
# ------------------------------
# Waypoint 166:
#   Location: Location(x=378.096436, y=24.003590, z=0.016625)
#   Rotation: Rotation(pitch=359.777252, yaw=325.331482, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 4
#   Is Intersection: True
# ------------------------------
# Waypoint 167:
#   Location: Location(x=380.087341, y=26.882189, z=0.016625)
#   Rotation: Rotation(pitch=359.777252, yaw=325.331482, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 5
#   Is Intersection: True
# ------------------------------
# Waypoint 168:
#   Location: Location(x=382.078217, y=29.760788, z=0.016625)
#   Rotation: Rotation(pitch=359.777252, yaw=325.331482, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1601, Section ID: 0, Lane ID: 6
#   Is Intersection: True
# ------------------------------
# Waypoint 169:
#   Location: Location(x=397.997742, y=40.945084, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.424500, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 170:
#   Location: Location(x=398.330444, y=38.972950, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.424500, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 171:
#   Location: Location(x=398.663116, y=37.000816, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.424500, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 172:
#   Location: Location(x=398.995880, y=35.026543, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.493942, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 173:
#   Location: Location(x=399.323181, y=33.045883, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.739944, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 174:
#   Location: Location(x=399.641937, y=31.063848, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-80.985947, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 175:
#   Location: Location(x=399.952209, y=29.080458, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-81.231956, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 176:
#   Location: Location(x=400.253967, y=27.095751, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-81.477959, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 177:
#   Location: Location(x=400.547211, y=25.109772, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-81.723961, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 178:
#   Location: Location(x=400.831909, y=23.122551, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-81.969971, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 179:
#   Location: Location(x=401.108093, y=21.134125, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-82.215973, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 180:
#   Location: Location(x=401.375671, y=19.144531, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-82.461983, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 181:
#   Location: Location(x=401.634766, y=17.153807, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-82.707985, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 182:
#   Location: Location(x=401.885315, y=15.161989, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-82.953987, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 183:
#   Location: Location(x=402.127808, y=13.177402, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-82.932755, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 1595, Section ID: 0, Lane ID: -1
#   Is Intersection: True
# ------------------------------
# Waypoint 184:
#   Location: Location(x=402.381287, y=11.210482, z=0.000000)
# ...
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1719:
#   Location: Location(x=332.308289, y=139.904388, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-33.675686, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1720:
#   Location: Location(x=330.367584, y=136.991714, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-33.675686, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1721:
#   Location: Location(x=334.003326, y=138.765106, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-34.137268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1722:
#   Location: Location(x=332.039185, y=135.868179, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-34.137268, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1723:
#   Location: Location(x=335.689026, y=137.612228, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-34.598850, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1724:
#   Location: Location(x=333.701630, y=134.731201, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-34.598850, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1725:
#   Location: Location(x=337.365479, y=136.445801, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.060436, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1726:
#   Location: Location(x=335.354950, y=133.580887, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.060436, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1727:
#   Location: Location(x=339.032471, y=135.265884, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.522015, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1728:
#   Location: Location(x=336.998901, y=132.417252, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.522015, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1729:
#   Location: Location(x=340.689850, y=134.072601, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.983601, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1730:
#   Location: Location(x=338.633423, y=131.240463, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-35.983601, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1731:
#   Location: Location(x=342.337585, y=132.865997, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-36.445183, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1732:
#   Location: Location(x=340.258392, y=130.050507, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-36.445183, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1733:
#   Location: Location(x=343.975586, y=131.646164, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-36.906765, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1734:
#   Location: Location(x=341.873779, y=128.847519, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-36.906765, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1735:
#   Location: Location(x=345.603668, y=130.413177, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-37.368347, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1736:
#   Location: Location(x=343.479401, y=127.631554, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-37.368347, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1737:
#   Location: Location(x=347.221741, y=129.167114, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-37.829933, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1738:
#   Location: Location(x=345.075134, y=126.402695, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-37.829933, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1739:
#   Location: Location(x=348.829773, y=127.908028, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-38.291515, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1740:
#   Location: Location(x=346.660950, y=125.160995, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-38.291515, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1741:
#   Location: Location(x=350.427582, y=126.636055, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-38.753098, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1742:
#   Location: Location(x=348.236694, y=123.906578, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-38.753098, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1743:
#   Location: Location(x=352.015137, y=125.351250, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-39.214684, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1744:
#   Location: Location(x=349.802338, y=122.639511, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-39.214684, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1745:
#   Location: Location(x=353.592224, y=124.053696, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-39.676262, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1746:
#   Location: Location(x=351.357635, y=121.359871, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-39.676262, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1747:
#   Location: Location(x=355.158844, y=122.743477, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-40.137848, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1748:
#   Location: Location(x=352.902649, y=120.067741, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-40.137848, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1749:
#   Location: Location(x=356.714844, y=121.420685, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-40.599430, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1750:
#   Location: Location(x=354.437164, y=118.763214, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-40.599430, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1751:
#   Location: Location(x=358.260132, y=120.085388, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.061012, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1752:
#   Location: Location(x=355.961121, y=117.446350, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.061012, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1753:
#   Location: Location(x=359.794647, y=118.737701, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.522594, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1754:
#   Location: Location(x=357.474457, y=116.117271, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.522594, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1755:
#   Location: Location(x=361.318176, y=117.377686, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.984180, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1756:
#   Location: Location(x=358.976959, y=114.776031, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-41.984180, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1757:
#   Location: Location(x=362.851898, y=115.980118, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-42.801853, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1758:
#   Location: Location(x=360.473785, y=113.412140, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-42.801853, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1759:
#   Location: Location(x=364.372406, y=114.547943, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-43.771217, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1760:
#   Location: Location(x=361.951172, y=112.020561, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-43.771217, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1761:
#   Location: Location(x=365.868439, y=113.090240, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-44.740582, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1762:
#   Location: Location(x=363.404785, y=110.604187, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-44.740582, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1763:
#   Location: Location(x=367.339630, y=111.607437, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-45.709946, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1764:
#   Location: Location(x=364.834290, y=109.163422, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-45.709946, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1765:
#   Location: Location(x=368.785522, y=110.099960, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-46.679310, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1766:
#   Location: Location(x=366.239166, y=107.698677, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-46.679310, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1767:
#   Location: Location(x=370.205719, y=108.568253, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-47.648674, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1768:
#   Location: Location(x=367.619110, y=106.210388, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-47.648674, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1769:
#   Location: Location(x=371.599762, y=107.012718, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-48.618038, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1770:
#   Location: Location(x=368.973663, y=104.698952, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-48.618038, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1771:
#   Location: Location(x=372.967316, y=105.433823, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-49.587399, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1772:
#   Location: Location(x=370.302429, y=103.164818, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-49.587399, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1773:
#   Location: Location(x=374.307922, y=103.832031, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-50.556763, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1774:
#   Location: Location(x=371.605042, y=101.608429, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-50.556763, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -2
#   Is Intersection: False
# ------------------------------
# Waypoint 1775:
#   Location: Location(x=375.621307, y=102.207779, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-51.526127, roll=0.000000)
#   Lane Type: Driving
#   Road ID: 22, Section ID: 0, Lane ID: -3
#   Is Intersection: False
# ------------------------------
# Waypoint 1776:
#   Location: Location(x=372.881165, y=100.030228, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=-51.526127, roll=0.000000)
#   Lane Type: Driving
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3cbdadaab8dd> in <module>
#      39
#      40 #if __name__ == "__main__":
# ---> 41 analyze_waypoints()
#
# <ipython-input-6-3cbdadaab8dd> in analyze_waypoints()
#      34         print(f"  Rotation: {wp['rotation']}")
#      35         print(f"  Lane Type: {wp['lane_type']}")
# ---> 36         print(f"  Road ID: {wp['road_id']}, Section ID: {wp['section_id']}, Lane ID: {wp['lane_id']}")
#      37         print(f"  Is Intersection: {wp['is_intersection']}")
#      38         print("-" * 30)
#
# KeyboardInterrupt:

# %% [markdown]
# ## XAI

# %%
import carla
import random

# Connect to the CARLA server
# client = carla.Client('localhost', 2000)
# client.set_timeout(10.0)

# # Load the world
# world = client.get_world()

# Get the map
map = world.get_map()

# Generate waypoints with a customizable distance between them
distance_between_waypoints = 2.0  # Adjust this value as needed (meters)
waypoints = map.generate_waypoints(distance_between_waypoints)

# Function to print waypoint properties in a user-friendly format
def print_waypoint_properties(wp):
    print(f"\n--- Waypoint ID: {wp.id} ---")
    print(f"  Location: {wp.transform.location}")
    print(f"  Rotation: {wp.transform.rotation}")
    print(f"  Road ID: {wp.road_id}")
    print(f"  Lane ID: {wp.lane_id}")
    print(f"  Section ID: {wp.section_id}")
    print(f"  Lane Type: {wp.lane_type}")
    print(f"  Lane Change: {wp.lane_change}")
    print(f"  Is Junction: {wp.is_junction}")
    print(f"  Tag: {wp.tag}")
    print(f"  Next Waypoints: {[next_wp.id for next_wp in wp.next(distance_between_waypoints)]}")
    print(f"  Previous Waypoints: {[prev_wp.id for prev_wp in wp.previous(distance_between_waypoints)]}")

# Print properties for a specified number of waypoints
num_waypoints_to_print = 10
for i, wp in enumerate(waypoints[:num_waypoints_to_print]):
    print_waypoint_properties(wp)

# Optionally, filter waypoints by road ID for specific area analysis
# Provide the desired road ID here (replace with your actual road ID)
specific_road_id = None

if specific_road_id:
    road_waypoints = [wp for wp in waypoints if wp.road_id == specific_road_id]
    print(f"\n--- Waypoints on Road ID: {specific_road_id} ---")
    for wp in road_waypoints[:num_waypoints_to_print]:
        print_waypoint_properties(wp)

# Disconnect from the client (optional but recommended)
#client.apply_batch([carla.command.DestroyActor(x) for x in world.get_actors().filter('*vehicle*')])
# Out:
# --- Waypoint ID: 11910987357902096025 ---
#   Location: Location(x=379.693237, y=-19.074064, z=0.000000)
#   Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
#   Road ID: 1602
#   Lane ID: -4
#   Section ID: 0
#   Lane Type: Driving
#   Lane Change: Left
#   Is Junction: True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d3b7610420ed> in <module>
#      34 num_waypoints_to_print = 10
#      35 for i, wp in enumerate(waypoints[:num_waypoints_to_print]):
# ---> 36     print_waypoint_properties(wp)
#      37
#      38 # Optionally, filter waypoints by road ID for specific area analysis
#
# <ipython-input-8-d3b7610420ed> in print_waypoint_properties(wp)
#      27     print(f"  Lane Change: {wp.lane_change}")
#      28     print(f"  Is Junction: {wp.is_junction}")
# ---> 29     print(f"  Tag: {wp.tag}")
#      30     print(f"  Next Waypoints: {[next_wp.id for next_wp in wp.next(distance_between_waypoints)]}")
#      31     print(f"  Previous Waypoints: {[prev_wp.id for prev_wp in wp.previous(distance_between_waypoints)]}")
#
# AttributeError: 'Waypoint' object has no attribute 'tag'

# %%
import carla
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

def explore_waypoints(world, visualize=True):
   """
   Explore and visualize waypoints in Town04
   Returns dictionary of waypoints by road ID
   """
   carla_map = world.get_map()
   waypoints_by_road = {}
   
   # Generate waypoints every 2 meters
   all_waypoints = carla_map.generate_waypoints(2.0)
   
   # Group by road ID
   for waypoint in all_waypoints:
       road_id = waypoint.road_id
       if road_id not in waypoints_by_road:
           waypoints_by_road[road_id] = []
       waypoints_by_road[road_id].append(waypoint)
   
   if visualize:
       # Different colors for different roads
       colors = {
           20: carla.Color(255,0,0),    # Red
           21: carla.Color(0,255,0),    # Green
           22: carla.Color(0,0,255),    # Blue
           23: carla.Color(255,255,0)   # Yellow
       }
       
       for road_id, waypoints in waypoints_by_road.items():
           if road_id in colors:
               color = colors[road_id]
               for waypoint in waypoints:
                   # Draw point
                   world.debug.draw_point(
                       waypoint.transform.location,
                       size=0.1, 
                       color=color,
                       life_time=20.0
                   )
                   
                   # Draw direction arrow
                   fwd = waypoint.transform.get_forward_vector()
                   begin = waypoint.transform.location
                   end = begin + carla.Location(
                       x=fwd.x * 2,
                       y=fwd.y * 2,
                       z=fwd.z * 2
                   )
                   world.debug.draw_arrow(
                       begin,
                       end,
                       thickness=0.1,
                       arrow_size=0.1,
                       color=color,
                       life_time=20.0
                   )
   
   return waypoints_by_road

def get_outer_route(waypoints_by_road):
   """
   Create figure-8 route from outer road waypoints
   """
   outer_roads = [20, 21, 22, 23]  # Outer road IDs in Town04
   route = []
   
   for road_id in outer_roads:
       if road_id in waypoints_by_road:
           route.extend(waypoints_by_road[road_id])
   
   return route

# %%
client = carla.Client('localhost', 2000) 
world = client.get_world() 

# load Town04 map
world = client.load_world('Town04')

# %% [markdown]
# ## Roads with the most lanes

# %%
def find_road_with_most_lanes(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Dictionary to store number of lanes per road_id
    road_lanes = {}
    
    for wp in waypoints:
        road_id = wp.road_id
        if road_id not in road_lanes:
            road_lanes[road_id] = set()
        road_lanes[road_id].add(wp.lane_id)
    
    # Find road with most lanes
    road_with_most_lanes = max(road_lanes.items(), key=lambda x: len(x[1]))
    
    print(f"Road ID {road_with_most_lanes[0]} has the most lanes: {len(road_with_most_lanes[1])} lanes")
    print("Lane IDs:", sorted(list(road_with_most_lanes[1])))
    
    return road_with_most_lanes[0]

# Usage:
road_id = find_road_with_most_lanes(world)
road_id
# Out:
# Road ID 6 has the most lanes: 8 lanes
# Lane IDs: [-4, -3, -2, -1, 3, 4, 5, 6]
# 6

# %% [markdown]
# ## roads with 8 lanes

# %%
def find_eight_lane_roads(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    road_lanes = {}
    for wp in waypoints:
        road_id = wp.road_id
        if road_id not in road_lanes:
            road_lanes[road_id] = set()
        road_lanes[road_id].add(wp.lane_id)
    
    eight_lane_roads = [road_id for road_id, lanes in road_lanes.items() 
                       if len(lanes) == 8]
    
    if eight_lane_roads:
        print(f"Roads with 8 lanes:")
        for road_id in eight_lane_roads:
            print(f"Road ID: {road_id}, Lanes: {sorted(list(road_lanes[road_id]))}")
    else:
        print("No roads with exactly 8 lanes found")
    
    return eight_lane_roads

# Usage:
eight_lane_roads = find_eight_lane_roads(world)
eight_lane_roads
# Out:
# Roads with 8 lanes:
# Road ID: 6, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 35, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 36, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 37, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 38, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 39, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 40, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 41, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 42, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 43, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 45, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 46, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 47, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 48, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 49, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 50, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]

# %% [markdown]
# ## Place markers on lanes

# %%
def place_markers_on_lane(world, eight_lane_roads, target_lane_id=-4):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Filter waypoints for target roads and lane
    target_waypoints = [wp for wp in waypoints 
                       if wp.road_id in eight_lane_roads 
                       and wp.lane_id == target_lane_id]
    
    # Place markers
    markers = []
    marker_color = carla.Color(r=255, g=0, b=0)  # Red markers
    marker_life_time = 20.0  # Markers will persist for 20 seconds
    
    for wp in target_waypoints:
        location = wp.transform.location
        # Draw a sphere at each waypoint
        marker = world.debug.draw_point(
            location,
            size=0.1,  # 10cm sphere
            color=marker_color,
            life_time=marker_life_time
        )
        markers.append(marker)
    
    print(f"Placed {len(markers)} markers on lane {target_lane_id} "
          f"across {len(eight_lane_roads)} roads")
    
    return markers

# Usage:
markers = place_markers_on_lane(world, eight_lane_roads)
# Out:
# Placed 1246 markers on lane -4 across 16 roads

# %% [markdown]
# ## Study waypoints

# %%
def analyze_road_sequence(world, road_id=6, lane_id=-4):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Filter waypoints for target road and lane
    target_waypoints = [wp for wp in waypoints 
                       if wp.road_id == road_id 
                       and wp.lane_id == lane_id]
    
    print(f"Found {len(target_waypoints)} waypoints")
    
    # Study first waypoint
    if target_waypoints:
        wp = target_waypoints[0]
        print("\nSample waypoint properties:")
        print(f"s-value (distance along road): {wp.s}")
        print(f"Is junction: {wp.is_junction}")
        
        # Check next waypoints
        next_wps = wp.next(2.0)
        print(f"\nNext waypoints: {len(next_wps)}")
        for next_wp in next_wps:
            print(f"Next wp road_id: {next_wp.road_id}, lane_id: {next_wp.lane_id}")
        
        # Try to find sequence
        current = wp
        sequence = [current]
        while True:
            next_wps = current.next(2.0)
            if not next_wps or next_wps[0].road_id != road_id:
                break
            current = next_wps[0]
            sequence.append(current)
        
        print(f"\nBuilt sequence of {len(sequence)} waypoints")
        print(f"First waypoint location: {sequence[0].transform.location}")
        print(f"Last waypoint location: {sequence[-1].transform.location}")
        
        # Check for road connections
        next_road = sequence[-1].next(2.0)
        if next_road:
            print(f"\nConnects to road_id: {next_road[0].road_id}")
    
    return target_waypoints, sequence if target_waypoints else None

# Usage:
waypoints, sequence = analyze_road_sequence(world)
# Out:
# Found 32 waypoints
#
# Sample waypoint properties:
# s-value (distance along road): 2.220446049250313e-15
# Is junction: False
#
# Next waypoints: 1
# Next wp road_id: 6, lane_id: -4
#
# Built sequence of 32 waypoints
# First waypoint location: Location(x=-514.229675, y=177.521729, z=0.000000)
# Last waypoint location: Location(x=-515.252991, y=239.643921, z=0.000000)
#
# Connects to road_id: 45

# %%
import carla

def analyze_waypoint(world):
    carla_map = world.get_map()
    # Generate waypoints every 2 meters
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Get sample waypoint for demonstration
    sample_waypoint = waypoints[0]
    
    # Waypoint properties
    print("Waypoint Properties:")
    print(f"Location: {sample_waypoint.transform.location}")  # x, y, z coordinates
    print(f"Rotation: {sample_waypoint.transform.rotation}")  # pitch, yaw, roll
    print(f"Road ID: {sample_waypoint.road_id}")
    print(f"Section ID: {sample_waypoint.section_id}")
    print(f"Lane ID: {sample_waypoint.lane_id}")
    print(f"Junction: {sample_waypoint.is_junction}")
    print(f"Lane Width: {sample_waypoint.lane_width}")
    print(f"Lane Change: {sample_waypoint.lane_change}")
    print(f"Lane Type: {sample_waypoint.lane_type}")
    
    # Waypoint methods demonstration
    print("\nWaypoint Navigation Methods:")
    
    # Get next waypoints
    next_waypoints = sample_waypoint.next(2.0)  # Get waypoints 2m ahead
    print(f"Next waypoints count: {len(next_waypoints)}")
    
    # Get previous waypoint
    prev_waypoint = sample_waypoint.previous(2.0)[0]  # Get waypoint 2m behind
    print(f"Previous waypoint distance: {prev_waypoint.transform.location.distance(sample_waypoint.transform.location)}")
    
    # Get right and left lanes
    right_lane = sample_waypoint.get_right_lane()
    left_lane = sample_waypoint.get_left_lane()
    print(f"Has right lane: {right_lane is not None}")
    print(f"Has left lane: {left_lane is not None}")
    
    # Lane change availability
    print("\nLane Change Possibilities:")
    print(f"Can change left: {sample_waypoint.lane_change & carla.LaneChange.Left}")
    print(f"Can change right: {sample_waypoint.lane_change & carla.LaneChange.Right}")
    
    # Get landmarks
    landmarks = sample_waypoint.get_landmarks(distance=50)  # Get landmarks within 50m
    print(f"\nNumber of nearby landmarks: {len(landmarks)}")
    
    return waypoints

def analyze_road_topology(carla_map):
    """Analyze the road topology using waypoints"""
    topology = carla_map.get_topology()
    print(f"\nRoad Topology Analysis:")
    print(f"Number of road segments: {len(topology)}")
    
    # Analyze first road segment
    if topology:
        start_wp, end_wp = topology[0]
        print(f"Sample road segment:")
        print(f"Start location: {start_wp.transform.location}")
        print(f"End location: {end_wp.transform.location}")
        print(f"Road length: {start_wp.transform.location.distance(end_wp.transform.location):.2f}m")

# Usage example:
# client = carla.Client('localhost', 2000)
# world = client.get_world()
waypoints = analyze_waypoint(world)
analyze_road_topology(world.get_map())
# Out:
# Waypoint Properties:
# Location: Location(x=379.693237, y=-19.074064, z=0.000000)
# Rotation: Rotation(pitch=0.000000, yaw=102.902794, roll=0.000000)
# Road ID: 1602
# Section ID: 0
# Lane ID: -4
# Junction: True
# Lane Width: 3.5
# Lane Change: Left
# Lane Type: Driving
#
# Waypoint Navigation Methods:
# Next waypoints count: 1
# Previous waypoint distance: 1.4167555570602417
# Has right lane: True
# Has left lane: True
#
# Lane Change Possibilities:
# Can change left: 2
# Can change right: 0
#
# Number of nearby landmarks: 1
#
# Road Topology Analysis:
# Number of road segments: 559
# Sample road segment:
# Start location: Location(x=379.693237, y=-19.074064, z=0.000000)
# End location: Location(x=363.532532, y=4.278366, z=0.021045)
# Road length: 28.40m

# %%
type(waypoints) # list
len(waypoints) # 16919
type(waypoints[0]) # carla.libcarla.Waypoint
# for method in dir(waypoints[0]):
#     if not method.startswith("_"):
#         print(method)

waypoints[0].road_id # 1602

distinct_road_ids = [waypoint.road_id for waypoint in waypoints]
distinct_road_ids = list(set(distinct_road_ids))
distinct_road_ids
# Out:
# [0,
#  1,
#  1024,
#  1539,
#  1028,
#  2,
#  3,
#  4,
#  518,
#  5,
#  1546,
#  6,
#  8,
#  13,
#  14,
#  9,
#  528,
#  16,
#  18,
#  1043,
#  1044,
#  19,
#  22,
#  23,
#  24,
#  17,
#  26,
#  27,
#  540,
#  21,
#  29,
#  1567,
#  1568,
#  30,
#  31,
#  34,
#  7,
#  35,
#  36,
#  37,
#  38,
#  39,
#  40,
#  41,
#  42,
#  556,
#  43,
#  44,
#  1072,
#  45,
#  1073,
#  10,
#  46,
#  47,
#  561,
#  48,
#  11,
#  1076,
#  1594,
#  1595,
#  1080,
#  61,
#  12,
#  63,
#  569,
#  1601,
#  1602,
#  65,
#  1091,
#  1092,
#  573,
#  1097,
#  15,
#  1101,
#  593,
#  594,
#  88,
#  89,
#  1114,
#  1115,
#  1122,
#  20,
#  108,
#  1133,
#  109,
#  115,
#  1141,
#  119,
#  633,
#  634,
#  1148,
#  124,
#  25,
#  128,
#  135,
#  136,
#  1161,
#  1162,
#  28,
#  653,
#  144,
#  145,
#  1173,
#  149,
#  661,
#  1174,
#  666,
#  158,
#  1184,
#  161,
#  674,
#  32,
#  1185,
#  33,
#  1191,
#  170,
#  1194,
#  684,
#  179,
#  695,
#  1209,
#  1210,
#  189,
#  702,
#  1217,
#  708,
#  1225,
#  1232,
#  209,
#  210,
#  1239,
#  731,
#  732,
#  225,
#  231,
#  746,
#  749,
#  1263,
#  1264,
#  241,
#  247,
#  49,
#  761,
#  760,
#  50,
#  1281,
#  51,
#  774,
#  775,
#  1288,
#  52,
#  266,
#  779,
#  267,
#  782,
#  271,
#  54,
#  1297,
#  275,
#  1307,
#  797,
#  798,
#  799,
#  1312,
#  290,
#  291,
#  1318,
#  807,
#  808,
#  1327,
#  816,
#  306,
#  819,
#  1337,
#  314,
#  826,
#  828,
#  829,
#  321,
#  330,
#  844,
#  845,
#  1360,
#  1361,
#  861,
#  350,
#  351,
#  862,
#  863,
#  867,
#  879,
#  880,
#  372,
#  886,
#  1400,
#  1401,
#  381,
#  385,
#  1412,
#  901,
#  902,
#  393,
#  907,
#  1421,
#  912,
#  407,
#  1432,
#  413,
#  926,
#  927,
#  1442,
#  419,
#  1450,
#  428,
#  943,
#  949,
#  1465,
#  1466,
#  955,
#  962,
#  1479,
#  968,
#  457,
#  458,
#  974,
#  1488,
#  467,
#  468,
#  981,
#  1497,
#  988,
#  477,
#  1507,
#  996,
#  1003,
#  496,
#  497,
#  1522,
#  1012,
#  1015,
#  1531,
#  510]

# %%
waypoints_by_road = explore_waypoints(world)
route = get_outer_route(waypoints_by_road)
print(f"Found {len(route)} waypoints for outer route")
# Out:
# Found 911 waypoints for outer route

# %%
carla_map = world.get_map()
# type(carla_map)
# for methods in dir(carla_map):
#     print(methods)
all_waypoints = carla_map.generate_waypoints(2.0)
type(all_waypoints) # list
type(all_waypoints[0]) # carla.libcarla.Waypoint
for method in dir(all_waypoints[0]):
    print(method)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_junction
# get_landmarks
# get_landmarks_of_type
# get_left_lane
# get_right_lane
# id
# is_intersection
# is_junction
# junction_id
# lane_change
# lane_id
# lane_type
# lane_width
# left_lane_marking
# next
# next_until_lane_end
# previous
# previous_until_lane_start
# right_lane_marking
# road_id
# s
# section_id
# transform

# %%
import carla_helpers as helpers
#transform = helpers.get_spectator_transform(world)
transform = helpers.set_spectator_transform(world, (12.53, -430.17, 200.86), (-37.66, 57.56, 0))
# Out:
# === Spectator Transform Set ===
# Location: x=12.53, y=-430.17, z=200.86
# Rotation: pitch=-37.66, yaw=57.56, roll=0.00

# %%
def explore_all_waypoints(world, life_time=20.0):
    """Visualize all waypoints in Town04"""
    carla_map = world.get_map()
    
    # Generate waypoints every 2 meters
    all_waypoints = carla_map.generate_waypoints(2.0)
    
    # Draw all waypoints in white
    for waypoint in all_waypoints:
        # Point for location
        world.debug.draw_point(
            waypoint.transform.location,
            size=0.05, 
            color=carla.Color(255,255,255),
            life_time=life_time
        )
        
        # Arrow for direction
        fwd = waypoint.transform.get_forward_vector()
        begin = waypoint.transform.location
        end = begin + carla.Location(x=fwd.x, y=fwd.y, z=fwd.z)
        world.debug.draw_arrow(
            begin, end,
            thickness=0.05,
            arrow_size=0.1,
            color=carla.Color(255,255,255),
            life_time=life_time
        )
        
    return all_waypoints

# Usage
waypoints = explore_all_waypoints(world)
print(f"Found {len(waypoints)} total waypoints")
# Out:
# Found 16919 total waypoints

# %% [markdown]
# ## Explore roads

# %%
def explore_road_structure(world):
   """Print road information in CARLA Town04"""
   carla_map = world.get_map()
   waypoints = carla_map.generate_waypoints(2.0)
   
   road_info = {}
   for waypoint in waypoints:
       road_id = waypoint.road_id
       lane_id = waypoint.lane_id
       
       if road_id not in road_info:
           road_info[road_id] = {
               'lanes': set(),
               'sample_location': waypoint.transform.location,
               'is_junction': waypoint.is_junction,
               'waypoint_count': 0
           }
           
       road_info[road_id]['lanes'].add(lane_id)
       road_info[road_id]['waypoint_count'] += 1

   # Print summary
   for road_id, info in sorted(road_info.items()):
       print(f"\nRoad {road_id}:")
       print(f"Lanes: {sorted(info['lanes'])}")
       print(f"Is Junction: {info['is_junction']}")
       print(f"Waypoints: {info['waypoint_count']}")
       print(f"Sample Location: ({info['sample_location'].x:.1f}, {info['sample_location'].y:.1f})")

# Usage
explore_road_structure(world)
# Out:
# Road 0:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 36
# Sample Location: (213.3, -307.9)
#
# Road 1:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 86
# Sample Location: (266.2, -307.3)
#
# Road 2:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 6
# Sample Location: (311.6, -239.2)
#
# Road 3:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 4
# Sample Location: (311.1, -181.9)
#
# Road 4:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 32
# Sample Location: (310.9, -161.2)
#
# Road 5:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 96
# Sample Location: (310.5, -110.7)
#
# Road 6:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 256
# Sample Location: (-514.2, 177.5)
#
# Road 7:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 24
# Sample Location: (25.1, -170.5)
#
# Road 8:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 44
# Sample Location: (74.6, -170.2)
#
# Road 9:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 50
# Sample Location: (141.3, -169.9)
#
# Road 10:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 38
# Sample Location: (210.6, -169.5)
#
# Road 11:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 38
# Sample Location: (266.3, -169.1)
#
# Road 12:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 2
# Sample Location: (321.8, -168.8)
#
# Road 13:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 4
# Sample Location: (337.4, -168.7)
#
# Road 14:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 14
# Sample Location: (359.2, -168.6)
#
# Road 15:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 34
# Sample Location: (202.8, -353.9)
#
# Road 16:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 42
# Sample Location: (201.5, -298.5)
#
# Road 17:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 58
# Sample Location: (200.1, -237.6)
#
# Road 18:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 72
# Sample Location: (198.4, -162.2)
#
# Road 19:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 36
# Sample Location: (267.4, -118.7)
#
# Road 20:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 10
# Sample Location: (324.1, -117.8)
#
# Road 21:
# Lanes: [4]
# Is Junction: False
# Waypoints: 1
# Sample Location: (326.8, -183.5)
#
# Road 22:
# Lanes: [-3, -2]
# Is Junction: False
# Waypoints: 470
# Sample Location: (26.9, 296.6)
#
# Road 23:
# Lanes: [-3, -2]
# Is Junction: False
# Waypoints: 430
# Sample Location: (-39.4, -231.6)
#
# Road 24:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 20
# Sample Location: (351.5, -142.8)
#
# Road 25:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 92
# Sample Location: (352.0, -179.5)
#
# Road 26:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 40
# Sample Location: (304.3, -250.0)
#
# Road 27:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 34
# Sample Location: (246.7, -249.7)
#
# Road 28:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 32
# Sample Location: (258.3, -129.7)
#
# Road 29:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 58
# Sample Location: (258.5, -180.4)
#
# Road 30:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 44
# Sample Location: (258.7, -257.1)
#
# Road 31:
# Lanes: [2]
# Is Junction: False
# Waypoints: 89
# Sample Location: (34.7, 132.8)
#
# Road 32:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 34
# Sample Location: (334.0, -117.6)
#
# Road 33:
# Lanes: [2]
# Is Junction: False
# Waypoints: 84
# Sample Location: (-34.7, -88.6)
#
# Road 34:
# Lanes: [2]
# Is Junction: False
# Waypoints: 94
# Sample Location: (119.8, -14.2)
#
# Road 35:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 1144
# Sample Location: (248.7, -364.2)
#
# Road 36:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 328
# Sample Location: (381.9, -159.2)
#
# Road 37:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 168
# Sample Location: (380.9, -55.8)
#
# Road 38:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 984
# Sample Location: (363.5, 4.3)
#
# Road 39:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 536
# Sample Location: (66.4, 6.4)
#
# Road 40:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 952
# Sample Location: (-120.8, 5.8)
#
# Road 41:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 840
# Sample Location: (-412.6, 5.9)
#
# Road 42:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 136
# Sample Location: (160.3, -364.6)
#
# Road 43:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 136
# Sample Location: (215.7, -364.2)
#
# Road 44:
# Lanes: [2]
# Is Junction: False
# Waypoints: 90
# Sample Location: (-112.6, 55.9)
#
# Road 45:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 2344
# Sample Location: (-515.2, 241.0)
#
# Road 46:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 560
# Sample Location: (7.1, 283.7)
#
# Road 47:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 456
# Sample Location: (15.7, 66.0)
#
# Road 48:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 256
# Sample Location: (15.1, -98.7)
#
# Road 49:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 160
# Sample Location: (14.7, -183.2)
#
# Road 50:
# Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Is Junction: False
# Waypoints: 712
# Sample Location: (30.4, -285.9)
#
# Road 51:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 214
# Sample Location: (191.9, -311.2)
#
# Road 52:
# Lanes: [-1, 1]
# Is Junction: False
# Waypoints: 102
# Sample Location: (192.1, -248.6)
#
# Road 54:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (255.1, -238.3)
#
# Road 61:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.6, -238.3)
#
# Road 63:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.6, -238.3)
#
# Road 65:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (266.0, -249.8)
#
# Road 88:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (255.1, -238.3)
#
# Road 89:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (258.6, -238.3)
#
# Road 108:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (266.0, -249.8)
#
# Road 109:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (266.0, -246.3)
#
# Road 115:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (246.7, -249.7)
#
# Road 119:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.7, -257.1)
#
# Road 124:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (266.0, -246.3)
#
# Road 128:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (266.0, -249.8)
#
# Road 135:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 40
# Sample Location: (-28.1, 352.0)
#
# Road 136:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 40
# Sample Location: (-28.1, 352.0)
#
# Road 144:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 144
# Sample Location: (-44.7, 339.1)
#
# Road 145:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 144
# Sample Location: (-28.1, 352.0)
#
# Road 149:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (202.0, -320.4)
#
# Road 158:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (205.5, -320.3)
#
# Road 161:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (201.5, -298.5)
#
# Road 170:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (213.3, -307.9)
#
# Road 179:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (191.9, -311.2)
#
# Road 189:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (213.3, -307.9)
#
# Road 209:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (205.5, -320.3)
#
# Road 210:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (202.0, -320.4)
#
# Road 225:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (205.5, -320.3)
#
# Road 231:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (202.0, -320.4)
#
# Road 241:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (201.5, -298.5)
#
# Road 247:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (191.9, -311.2)
#
# Road 266:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 44
# Sample Location: (193.8, -385.4)
#
# Road 267:
# Lanes: [-3, -2, -1]
# Is Junction: True
# Waypoints: 33
# Sample Location: (193.7, -367.9)
#
# Road 271:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (193.7, -364.4)
#
# Road 275:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (215.7, -364.2)
#
# Road 290:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (248.2, -311.0)
#
# Road 291:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (248.1, -307.5)
#
# Road 306:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.8, -300.1)
#
# Road 314:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (248.1, -307.5)
#
# Road 321:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (255.3, -300.1)
#
# Road 330:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.8, -300.1)
#
# Road 350:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (315.3, -257.5)
#
# Road 351:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (311.8, -257.5)
#
# Road 372:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (311.8, -257.5)
#
# Road 381:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (322.6, -250.2)
#
# Road 385:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (311.8, -257.5)
#
# Road 393:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (315.3, -257.5)
#
# Road 407:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (322.6, -250.2)
#
# Road 413:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (322.6, -246.7)
#
# Road 419:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (311.6, -239.2)
#
# Road 428:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (304.3, -250.0)
#
# Road 457:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (322.6, -246.7)
#
# Road 458:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (322.6, -250.2)
#
# Road 467:
# Lanes: [1]
# Is Junction: True
# Waypoints: 26
# Sample Location: (315.1, -233.5)
#
# Road 468:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 26
# Sample Location: (311.6, -233.6)
#
# Road 477:
# Lanes: [1]
# Is Junction: True
# Waypoints: 26
# Sample Location: (315.1, -233.5)
#
# Road 496:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (314.6, -179.6)
#
# Road 497:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (311.1, -179.7)
#
# Road 510:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (314.6, -179.6)
#
# Road 518:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (311.1, -179.7)
#
# Road 528:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (303.7, -168.9)
#
# Road 540:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (311.1, -179.7)
#
# Road 556:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (321.8, -168.8)
#
# Road 561:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (310.9, -161.2)
#
# Road 569:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (303.7, -172.4)
#
# Road 573:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (303.7, -168.9)
#
# Road 593:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (303.7, -168.9)
#
# Road 594:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (303.7, -172.4)
#
# Road 633:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (314.1, -130.6)
#
# Road 634:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (310.6, -130.6)
#
# Road 653:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (302.0, -118.1)
#
# Road 661:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (310.6, -130.6)
#
# Road 666:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (314.1, -130.6)
#
# Road 674:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (310.6, -130.6)
#
# Road 684:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (302.0, -118.1)
#
# Road 695:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (302.1, -121.6)
#
# Road 702:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (310.5, -110.7)
#
# Road 708:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (324.1, -117.8)
#
# Road 731:
# Lanes: [1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (302.1, -121.6)
#
# Road 732:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (302.0, -118.1)
#
# Road 746:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (370.6, -65.1)
#
# Road 749:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (381.0, -77.8)
#
# Road 760:
# Lanes: [-3, -2, -1]
# Is Junction: True
# Waypoints: 33
# Sample Location: (384.5, -77.8)
#
# Road 761:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 44
# Sample Location: (402.0, -77.6)
#
# Road 774:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 104
# Sample Location: (15.3, -47.2)
#
# Road 775:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 104
# Sample Location: (-5.7, -47.2)
#
# Road 779:
# Lanes: [2, 6]
# Is Junction: True
# Waypoints: 26
# Sample Location: (-16.2, -47.1)
#
# Road 782:
# Lanes: [-4, -2]
# Is Junction: True
# Waypoints: 27
# Sample Location: (15.3, -47.2)
#
# Road 797:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (258.4, -160.7)
#
# Road 798:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (254.9, -160.7)
#
# Road 799:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (246.9, -169.3)
#
# Road 807:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (246.9, -172.8)
#
# Road 808:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (266.3, -169.1)
#
# Road 816:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.5, -180.4)
#
# Road 819:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.4, -160.7)
#
# Road 826:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (246.9, -169.3)
#
# Road 828:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (258.4, -160.7)
#
# Road 829:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (254.9, -160.7)
#
# Road 844:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (246.9, -172.8)
#
# Road 845:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (246.9, -169.3)
#
# Road 861:
# Lanes: [-3, -2, -1]
# Is Junction: True
# Waypoints: 33
# Sample Location: (385.6, -181.1)
#
# Road 862:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 44
# Sample Location: (403.1, -181.0)
#
# Road 863:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (371.7, -168.5)
#
# Road 867:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (382.1, -181.2)
#
# Road 879:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (323.3, -168.8)
#
# Road 880:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (323.3, -172.3)
#
# Road 886:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (326.9, -183.2)
#
# Road 901:
# Lanes: [-3, -2, -1]
# Is Junction: True
# Waypoints: 33
# Sample Location: (11.3, -161.2)
#
# Road 902:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 44
# Sample Location: (-6.2, -161.1)
#
# Road 907:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (14.7, -183.2)
#
# Road 912:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (14.8, -161.2)
#
# Road 926:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (204.1, -258.4)
#
# Road 927:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (200.6, -258.5)
#
# Road 943:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (212.8, -249.4)
#
# Road 949:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (200.6, -258.5)
#
# Road 955:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (200.6, -258.5)
#
# Road 962:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (204.1, -258.4)
#
# Road 968:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (212.8, -245.9)
#
# Road 974:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (212.8, -249.4)
#
# Road 981:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (192.1, -248.6)
#
# Road 988:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (200.1, -237.6)
#
# Road 996:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (212.8, -249.4)
#
# Road 1003:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (212.8, -245.9)
#
# Road 1012:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (246.6, -122.5)
#
# Road 1015:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (246.6, -119.0)
#
# Road 1024:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (267.4, -118.7)
#
# Road 1028:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (258.3, -129.7)
#
# Road 1043:
# Lanes: [1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (246.6, -122.5)
#
# Road 1044:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (246.6, -119.0)
#
# Road 1072:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 152
# Sample Location: (16.1, 141.3)
#
# Road 1073:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 152
# Sample Location: (-4.9, 141.4)
#
# Road 1076:
# Lanes: [2, 6]
# Is Junction: True
# Waypoints: 39
# Sample Location: (-33.9, 133.1)
#
# Road 1080:
# Lanes: [2, 4]
# Is Junction: True
# Waypoints: 39
# Sample Location: (15.7, 66.0)
#
# Road 1091:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 128
# Sample Location: (128.6, 7.0)
#
# Road 1092:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 128
# Sample Location: (128.3, 28.0)
#
# Road 1097:
# Lanes: [2, 4]
# Is Junction: True
# Waypoints: 33
# Sample Location: (66.4, 6.4)
#
# Road 1101:
# Lanes: [2, 6]
# Is Junction: True
# Waypoints: 33
# Sample Location: (119.4, 59.3)
#
# Road 1114:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (118.4, -170.0)
#
# Road 1115:
# Lanes: [1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (118.4, -173.5)
#
# Road 1122:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (131.3, -182.7)
#
# Road 1133:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (127.8, -182.8)
#
# Road 1141:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (127.8, -182.8)
#
# Road 1148:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (118.4, -170.0)
#
# Road 1161:
# Lanes: [1]
# Is Junction: True
# Waypoints: 41
# Sample Location: (-36.5, -229.6)
#
# Road 1162:
# Lanes: [3, 6]
# Is Junction: True
# Waypoints: 41
# Sample Location: (-39.4, -231.6)
#
# Road 1173:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 148
# Sample Location: (14.6, -222.2)
#
# Road 1174:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 148
# Sample Location: (-6.4, -222.5)
#
# Road 1184:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 108
# Sample Location: (-67.6, 5.9)
#
# Road 1185:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 108
# Sample Location: (-67.6, 26.9)
#
# Road 1191:
# Lanes: [-4, -2]
# Is Junction: True
# Waypoints: 26
# Sample Location: (-67.6, 5.9)
#
# Road 1194:
# Lanes: [2, 6]
# Is Junction: True
# Waypoints: 28
# Sample Location: (-67.6, 37.4)
#
# Road 1209:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 14
# Sample Location: (47.9, -170.4)
#
# Road 1210:
# Lanes: [1]
# Is Junction: True
# Waypoints: 14
# Sample Location: (47.9, -173.9)
#
# Road 1217:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (58.7, -182.7)
#
# Road 1225:
# Lanes: [1]
# Is Junction: True
# Waypoints: 12
# Sample Location: (62.2, -182.7)
#
# Road 1232:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (47.9, -170.4)
#
# Road 1239:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 11
# Sample Location: (58.7, -182.7)
#
# Road 1263:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (341.1, -172.2)
#
# Road 1264:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (341.0, -168.7)
#
# Road 1281:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (351.7, -161.3)
#
# Road 1288:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (341.0, -168.7)
#
# Road 1297:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (341.1, -172.2)
#
# Road 1307:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (341.0, -168.7)
#
# Road 1312:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (351.7, -161.3)
#
# Road 1318:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (348.2, -161.4)
#
# Road 1327:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (359.2, -168.6)
#
# Road 1337:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (352.0, -179.5)
#
# Road 1360:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (348.2, -161.4)
#
# Road 1361:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (351.7, -161.3)
#
# Road 1400:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 112
# Sample Location: (-357.6, 26.5)
#
# Road 1401:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 112
# Sample Location: (-357.8, 5.5)
#
# Road 1412:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 26
# Sample Location: (-380.6, -11.9)
#
# Road 1421:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 28
# Sample Location: (-380.6, -11.9)
#
# Road 1432:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 30
# Sample Location: (-380.6, -11.9)
#
# Road 1442:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 31
# Sample Location: (-380.6, -11.9)
#
# Road 1450:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 23
# Sample Location: (-384.1, -12.3)
#
# Road 1465:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (191.2, -173.1)
#
# Road 1466:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (191.2, -169.6)
#
# Road 1479:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (191.2, -169.6)
#
# Road 1488:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (198.8, -180.5)
#
# Road 1497:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (191.2, -169.6)
#
# Road 1507:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (191.2, -173.1)
#
# Road 1522:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (198.8, -180.5)
#
# Road 1531:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (202.3, -180.4)
#
# Road 1539:
# Lanes: [1]
# Is Junction: True
# Waypoints: 9
# Sample Location: (210.6, -169.5)
#
# Road 1546:
# Lanes: [1]
# Is Junction: True
# Waypoints: 8
# Sample Location: (198.4, -162.2)
#
# Road 1567:
# Lanes: [1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (202.3, -180.4)
#
# Road 1568:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 10
# Sample Location: (198.8, -180.5)
#
# Road 1594:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 28
# Sample Location: (401.4, 41.5)
#
# Road 1595:
# Lanes: [-1]
# Is Junction: True
# Waypoints: 28
# Sample Location: (398.0, 40.9)
#
# Road 1601:
# Lanes: [3, 4, 5, 6]
# Is Junction: True
# Waypoints: 84
# Sample Location: (400.2, -14.4)
#
# Road 1602:
# Lanes: [-4, -3, -2, -1]
# Is Junction: True
# Waypoints: 84
# Sample Location: (379.7, -19.1)

# %% [markdown]
# ## Display non-junction roads

# %%
def explore_main_roads(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    road_info = {}
    for wp in waypoints:
        if not wp.is_junction:  # Focus on main roads
            if wp.road_id not in road_info:
                road_info[wp.road_id] = {'waypoints': [], 'lanes': set()}
            road_info[wp.road_id]['waypoints'].append(wp)
            road_info[wp.road_id]['lanes'].add(wp.lane_id)
    
    for road_id, info in sorted(road_info.items()):
        length = len(info['waypoints']) * 2  # 2m spacing
        print(f"Road {road_id}: Length {length}m, Lanes: {sorted(info['lanes'])}")

explore_main_roads(world)
# Out:
# Road 0: Length 72m, Lanes: [-1, 1]
# Road 1: Length 172m, Lanes: [-1, 1]
# Road 2: Length 12m, Lanes: [-1, 1]
# Road 3: Length 8m, Lanes: [-1, 1]
# Road 4: Length 64m, Lanes: [-1, 1]
# Road 5: Length 192m, Lanes: [-1, 1]
# Road 6: Length 512m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 7: Length 48m, Lanes: [-1, 1]
# Road 8: Length 88m, Lanes: [-1, 1]
# Road 9: Length 100m, Lanes: [-1, 1]
# Road 10: Length 76m, Lanes: [-1, 1]
# Road 11: Length 76m, Lanes: [-1, 1]
# Road 12: Length 4m, Lanes: [-1, 1]
# Road 13: Length 8m, Lanes: [-1, 1]
# Road 14: Length 28m, Lanes: [-1, 1]
# Road 15: Length 68m, Lanes: [-1, 1]
# Road 16: Length 84m, Lanes: [-1, 1]
# Road 17: Length 116m, Lanes: [-1, 1]
# Road 18: Length 144m, Lanes: [-1, 1]
# Road 19: Length 72m, Lanes: [-1, 1]
# Road 20: Length 20m, Lanes: [-1, 1]
# Road 21: Length 2m, Lanes: [4]
# Road 22: Length 940m, Lanes: [-3, -2]
# Road 23: Length 860m, Lanes: [-3, -2]
# Road 24: Length 40m, Lanes: [-1, 1]
# Road 25: Length 184m, Lanes: [-1, 1]
# Road 26: Length 80m, Lanes: [-1, 1]
# Road 27: Length 68m, Lanes: [-1, 1]
# Road 28: Length 64m, Lanes: [-1, 1]
# Road 29: Length 116m, Lanes: [-1, 1]
# Road 30: Length 88m, Lanes: [-1, 1]
# Road 31: Length 178m, Lanes: [2]
# Road 32: Length 68m, Lanes: [-1, 1]
# Road 33: Length 168m, Lanes: [2]
# Road 34: Length 188m, Lanes: [2]
# Road 35: Length 2288m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 36: Length 656m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 37: Length 336m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 38: Length 1968m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 39: Length 1072m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 40: Length 1904m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 41: Length 1680m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 42: Length 272m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 43: Length 272m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 44: Length 180m, Lanes: [2]
# Road 45: Length 4688m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 46: Length 1120m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 47: Length 912m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 48: Length 512m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 49: Length 320m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 50: Length 1424m, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road 51: Length 428m, Lanes: [-1, 1]
# Road 52: Length 204m, Lanes: [-1, 1]

# %% [markdown]
# ## View long roads

# %%
import time

def visualize_outer_roads(world):
    carla_map = world.get_map()
    #target_roads = [45, 35, 38, 40]
    target_roads = [45]
    
    def draw_waypoints():
        waypoints = carla_map.generate_waypoints(2.0)
        for wp in waypoints:
            if wp.road_id in target_roads:
                color = carla.Color(255,0,0) if wp.road_id in [45, 35] else carla.Color(0,255,0)
                world.debug.draw_point(wp.transform.location, 0.1, color, life_time=0.1)

    while True:
        draw_waypoints()
        time.sleep(0.05)

visualize_outer_roads(world)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a6c7a34376c3> in <module>
#      17         time.sleep(0.05)
#      18
# ---> 19 visualize_outer_roads(world)
#
# <ipython-input-11-a6c7a34376c3> in visualize_outer_roads(world)
#      15     while True:
#      16         draw_waypoints()
# ---> 17         time.sleep(0.05)
#      18
#      19 visualize_outer_roads(world)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualise waypoints by road id

# %%
import time

def get_lane_waypoints(world, road_id, lane_id):
    carla_map = world.get_map()
    return [wp for wp in carla_map.generate_waypoints(2.0) 
            if wp.road_id == road_id and wp.lane_id == lane_id]

def visualize_waypoints(world, waypoints, color=carla.Color(255,0,0)):
   """Visualizes provided waypoints in specified color"""
   debug = world.debug
   for wp in waypoints:
       debug.draw_point(
           wp.transform.location,
           size=0.1, 
           color=color,
           life_time=-1,
           persistent_lines=True
       )
       time.sleep(0.025)

# Usage
# Example for rightmost lane
lane_waypoints = get_lane_waypoints(world, 45, -1)
visualize_waypoints(world, lane_waypoints, carla.Color(0,255,0))

# %%
lane_waypoints = get_lane_waypoints(world, 45, -1)
for wp in lane_waypoints:
    print(f"Location: ({wp.transform.location.x:.1f}, {wp.transform.location.y:.1f})")
# Out:
# Location: (-504.8, 240.9)
# Location: (-504.7, 243.0)
# Location: (-504.7, 245.0)
# Location: (-504.6, 247.1)
# Location: (-504.5, 249.2)
# Location: (-504.4, 251.2)
# Location: (-504.3, 253.3)
# Location: (-504.2, 255.3)
# Location: (-504.0, 257.4)
# Location: (-503.8, 259.4)
# Location: (-503.6, 261.5)
# Location: (-503.3, 263.5)
# Location: (-503.0, 265.6)
# Location: (-502.8, 267.6)
# Location: (-502.4, 269.6)
# Location: (-502.1, 271.7)
# Location: (-501.7, 273.7)
# Location: (-501.4, 275.7)
# Location: (-501.0, 277.7)
# Location: (-500.5, 279.7)
# Location: (-500.1, 281.8)
# Location: (-499.6, 283.8)
# Location: (-499.1, 285.8)
# Location: (-498.6, 287.7)
# Location: (-498.1, 289.7)
# Location: (-497.5, 291.7)
# Location: (-496.9, 293.7)
# Location: (-496.3, 295.7)
# Location: (-495.7, 297.6)
# Location: (-495.1, 299.6)
# Location: (-494.4, 301.5)
# Location: (-493.7, 303.5)
# Location: (-493.0, 305.4)
# Location: (-492.3, 307.3)
# Location: (-491.5, 309.2)
# Location: (-490.7, 311.1)
# Location: (-489.9, 313.0)
# Location: (-489.1, 314.9)
# Location: (-488.3, 316.8)
# Location: (-487.4, 318.7)
# Location: (-486.5, 320.5)
# Location: (-485.6, 322.4)
# Location: (-484.7, 324.2)
# Location: (-483.8, 326.1)
# Location: (-482.8, 327.9)
# Location: (-481.8, 329.7)
# Location: (-480.8, 331.5)
# Location: (-479.8, 333.3)
# Location: (-478.8, 335.0)
# Location: (-477.7, 336.8)
# Location: (-476.6, 338.6)
# Location: (-475.5, 340.3)
# Location: (-474.4, 342.0)
# Location: (-473.3, 343.7)
# Location: (-472.1, 345.4)
# Location: (-470.9, 347.1)
# Location: (-469.7, 348.8)
# Location: (-468.5, 350.5)
# Location: (-467.3, 352.1)
# Location: (-466.0, 353.8)
# Location: (-464.8, 355.4)
# Location: (-463.5, 357.0)
# Location: (-462.2, 358.6)
# Location: (-460.9, 360.1)
# Location: (-459.5, 361.7)
# Location: (-458.2, 363.3)
# Location: (-456.8, 364.8)
# Location: (-455.4, 366.3)
# Location: (-454.0, 367.8)
# Location: (-452.6, 369.3)
# Location: (-451.1, 370.8)
# Location: (-449.7, 372.2)
# Location: (-448.2, 373.7)
# Location: (-446.7, 375.1)
# Location: (-445.2, 376.5)
# Location: (-443.7, 377.9)
# Location: (-442.1, 379.2)
# Location: (-440.6, 380.6)
# Location: (-439.0, 381.9)
# Location: (-437.4, 383.2)
# Location: (-435.8, 384.5)
# Location: (-434.2, 385.8)
# Location: (-432.6, 387.1)
# Location: (-431.0, 388.3)
# Location: (-429.3, 389.6)
# Location: (-427.7, 390.8)
# Location: (-426.0, 392.0)
# Location: (-424.3, 393.1)
# Location: (-422.6, 394.3)
# Location: (-420.9, 395.4)
# Location: (-419.1, 396.5)
# Location: (-417.4, 397.6)
# Location: (-415.6, 398.7)
# Location: (-413.9, 399.8)
# Location: (-412.1, 400.8)
# Location: (-410.3, 401.8)
# Location: (-408.5, 402.8)
# Location: (-406.7, 403.8)
# Location: (-404.9, 404.8)
# Location: (-403.0, 405.7)
# Location: (-401.2, 406.6)
# Location: (-399.3, 407.5)
# Location: (-397.5, 408.4)
# Location: (-395.6, 409.2)
# Location: (-393.7, 410.1)
# Location: (-391.8, 410.9)
# Location: (-389.9, 411.7)
# Location: (-388.0, 412.4)
# Location: (-386.1, 413.2)
# Location: (-384.2, 413.9)
# Location: (-382.2, 414.6)
# Location: (-380.3, 415.3)
# Location: (-378.4, 416.0)
# Location: (-376.4, 416.6)
# Location: (-374.4, 417.2)
# Location: (-372.5, 417.8)
# Location: (-370.5, 418.4)
# Location: (-368.5, 419.0)
# Location: (-366.5, 419.5)
# Location: (-364.5, 420.0)
# Location: (-362.5, 420.5)
# Location: (-360.5, 421.0)
# Location: (-358.5, 421.4)
# Location: (-356.5, 421.8)
# Location: (-354.5, 422.2)
# Location: (-352.4, 422.6)
# Location: (-350.4, 422.9)
# Location: (-348.4, 423.3)
# Location: (-346.4, 423.6)
# Location: (-344.3, 423.9)
# Location: (-342.3, 424.1)
# Location: (-340.2, 424.4)
# Location: (-338.2, 424.6)
# Location: (-336.1, 424.8)
# Location: (-334.1, 425.0)
# Location: (-332.0, 425.1)
# Location: (-330.0, 425.2)
# Location: (-327.9, 425.3)
# Location: (-325.9, 425.4)
# Location: (-323.8, 425.5)
# Location: (-321.7, 425.5)
# Location: (-319.7, 425.5)
# Location: (-317.7, 425.5)
# Location: (-315.7, 425.5)
# Location: (-313.7, 425.5)
# Location: (-311.7, 425.5)
# Location: (-309.7, 425.5)
# Location: (-307.7, 425.5)
# Location: (-305.7, 425.5)
# Location: (-303.7, 425.4)
# Location: (-301.7, 425.4)
# Location: (-299.7, 425.4)
# Location: (-297.7, 425.4)
# Location: (-295.7, 425.4)
# Location: (-293.7, 425.4)
# Location: (-291.7, 425.4)
# Location: (-289.7, 425.4)
# Location: (-287.7, 425.4)
# Location: (-285.7, 425.4)
# Location: (-283.7, 425.4)
# Location: (-281.7, 425.4)
# Location: (-279.7, 425.4)
# Location: (-277.7, 425.4)
# Location: (-275.7, 425.3)
# Location: (-273.7, 425.3)
# Location: (-271.7, 425.3)
# Location: (-269.7, 425.3)
# Location: (-267.7, 425.3)
# Location: (-265.7, 425.3)
# Location: (-263.7, 425.3)
# Location: (-261.7, 425.3)
# Location: (-259.7, 425.3)
# Location: (-257.7, 425.3)
# Location: (-255.7, 425.3)
# Location: (-253.7, 425.3)
# Location: (-251.7, 425.3)
# Location: (-249.7, 425.3)
# Location: (-247.7, 425.2)
# Location: (-245.7, 425.2)
# Location: (-243.7, 425.2)
# Location: (-241.7, 425.2)
# Location: (-239.7, 425.2)
# Location: (-237.7, 425.2)
# Location: (-235.7, 425.2)
# Location: (-233.7, 425.2)
# Location: (-231.7, 425.2)
# Location: (-229.7, 425.2)
# Location: (-227.7, 425.2)
# Location: (-225.7, 425.2)
# Location: (-223.7, 425.2)
# Location: (-221.7, 425.2)
# Location: (-219.7, 425.1)
# Location: (-217.7, 425.1)
# Location: (-215.7, 425.1)
# Location: (-213.7, 425.1)
# Location: (-211.7, 425.1)
# Location: (-209.7, 425.1)
# Location: (-207.7, 425.1)
# Location: (-205.7, 425.1)
# Location: (-203.7, 425.1)
# Location: (-201.7, 425.1)
# Location: (-199.7, 425.1)
# Location: (-197.7, 425.1)
# Location: (-195.6, 425.0)
# Location: (-193.6, 425.0)
# Location: (-191.5, 425.0)
# Location: (-189.5, 424.9)
# Location: (-187.4, 424.8)
# Location: (-185.4, 424.7)
# Location: (-183.3, 424.5)
# Location: (-181.3, 424.4)
# Location: (-179.2, 424.2)
# Location: (-177.2, 424.0)
# Location: (-175.1, 423.8)
# Location: (-173.1, 423.5)
# Location: (-171.1, 423.3)
# Location: (-169.0, 423.0)
# Location: (-167.0, 422.7)
# Location: (-165.0, 422.4)
# Location: (-163.0, 422.0)
# Location: (-160.9, 421.7)
# Location: (-158.9, 421.3)
# Location: (-156.9, 420.9)
# Location: (-154.9, 420.4)
# Location: (-152.9, 420.0)
# Location: (-150.9, 419.5)
# Location: (-148.9, 419.0)
# Location: (-146.9, 418.5)
# Location: (-144.9, 418.0)
# Location: (-142.9, 417.5)
# Location: (-141.0, 416.9)
# Location: (-139.0, 416.3)
# Location: (-137.0, 415.7)
# Location: (-135.1, 415.1)
# Location: (-133.1, 414.5)
# Location: (-131.2, 413.8)
# Location: (-129.3, 413.1)
# Location: (-127.3, 412.4)
# Location: (-125.4, 411.7)
# Location: (-123.5, 410.9)
# Location: (-121.6, 410.2)
# Location: (-119.7, 409.4)
# Location: (-117.8, 408.6)
# Location: (-115.9, 407.8)
# Location: (-114.0, 407.0)
# Location: (-112.2, 406.1)
# Location: (-110.3, 405.2)
# Location: (-108.5, 404.3)
# Location: (-106.6, 403.4)
# Location: (-104.8, 402.5)
# Location: (-103.0, 401.5)
# Location: (-101.2, 400.6)
# Location: (-99.4, 399.6)
# Location: (-97.6, 398.6)
# Location: (-95.8, 397.6)
# Location: (-94.0, 396.5)
# Location: (-92.3, 395.5)
# Location: (-90.5, 394.4)
# Location: (-88.8, 393.3)
# Location: (-87.0, 392.2)
# Location: (-85.3, 391.1)
# Location: (-83.6, 389.9)
# Location: (-81.9, 388.8)
# Location: (-80.2, 387.6)
# Location: (-78.6, 386.4)
# Location: (-76.9, 385.2)
# Location: (-75.3, 384.0)
# Location: (-73.6, 382.7)
# Location: (-72.0, 381.5)
# Location: (-70.4, 380.2)
# Location: (-68.8, 378.9)
# Location: (-67.2, 377.6)
# Location: (-65.7, 376.3)
# Location: (-64.1, 374.9)
# Location: (-62.6, 373.6)
# Location: (-61.0, 372.2)
# Location: (-59.5, 370.8)
# Location: (-58.0, 369.4)
# Location: (-56.5, 368.0)
# Location: (-55.1, 366.6)
# Location: (-53.6, 365.1)
# Location: (-52.2, 363.7)
# Location: (-50.7, 362.2)
# Location: (-49.3, 360.7)
# Location: (-47.9, 359.2)
# Location: (-46.5, 357.7)
# Location: (-45.2, 356.1)
# Location: (-43.8, 354.6)
# Location: (-42.5, 353.0)
# Location: (-41.2, 351.5)
# Location: (-39.9, 349.9)
# Location: (-38.6, 348.3)
# Location: (-37.3, 346.7)

# %% [markdown]
# ## Plot inner lane

# %%
def plot_inner_lane(world, road_id=45, lane_id=3):
    waypoints = get_lane_waypoints(world, road_id, lane_id)
    visualize_waypoints(world, waypoints, carla.Color(0,255,0))
    
    # Print first few points to verify direction
    for wp in waypoints[:5]:
        print(f"Location: ({wp.transform.location.x:.1f}, {wp.transform.location.y:.1f})")

plot_inner_lane(world, road_id=45, lane_id=3)
# Out:
# Location: (-494.3, 240.9)
# Location: (-494.2, 242.8)
# Location: (-494.2, 244.8)
# Location: (-494.1, 246.7)
# Location: (-494.1, 248.7)

# %% [markdown]
# ## Plot slow lane waypoints

# %%
def plot_cautious_lane(world, road_id=45, lane_id=6):  # lane 6 is outer slow lane
    waypoints = get_lane_waypoints(world, road_id, lane_id)
    visualize_waypoints(world, waypoints, carla.Color(0,255,0))
    
    for wp in waypoints[:5]:
        print(f"Location: ({wp.transform.location.x:.1f}, {wp.transform.location.y:.1f})")
        
# For other half of figure-8, use lane_id=-1 (outer slow lane in opposite direction)
plot_cautious_lane(world, road_id=45, lane_id=6)
# Out:
# Location: (-483.8, 240.9)
# Location: (-483.7, 242.7)
# Location: (-483.7, 244.5)
# Location: (-483.6, 246.4)
# Location: (-483.6, 248.2)

# %%
# other half of figure-8, use lane_id=-1 (outer slow lane in opposite direction)
plot_cautious_lane(world, road_id=45, lane_id=-4)
# Out:
# Location: (-515.2, 241.0)
# Location: (-515.2, 243.1)
# Location: (-515.2, 245.3)
# Location: (-515.1, 247.5)
# Location: (-515.0, 249.7)

# %% [markdown]
# ## Plot outer lanes

# %%
def plot_outer_lanes(world):
   # Slow lane in one direction
   waypoints_1 = get_lane_waypoints(world, 45, 6)
   visualize_waypoints(world, waypoints_1, carla.Color(0,255,0))
   
   # Slow lane in opposite direction 
   waypoints_2 = get_lane_waypoints(world, 45, -4)
   visualize_waypoints(world, waypoints_2, carla.Color(0,0,255))

plot_outer_lanes(world)

# %% [markdown]
# ## Visualise segments

# %%
def visualize_segments(world):
    colors = {
        (45, 6): carla.Color(255,0,0),    # Red
        (38, 6): carla.Color(0,255,0),    # Green
        (35, 6): carla.Color(0,0,255),    # Blue
        (40, -4): carla.Color(255,255,0)  # Yellow
    }
    
    for (road_id, lane_id), color in colors.items():
        waypoints = get_lane_waypoints(world, road_id, lane_id)
        visualize_waypoints(world, waypoints, color)

visualize_segments(world)

# %% [markdown]
# ## Find connecting segments

# %%
def find_connecting_roads(world):
    junctions = {}
    for road_id in range(0, 1700):  # Scan all road IDs
        waypoints = get_lane_waypoints(world, road_id, 6)  # Try lane 6
        if waypoints and waypoints[0].is_junction:
            loc = waypoints[0].transform.location
            junctions[road_id] = (loc.x, loc.y)
            visualize_waypoints(world, waypoints, carla.Color(255,0,255))
            print(f"Junction {road_id}: {junctions[road_id]}")


find_connecting_roads(world)
# Out:
# Junction 144: (-53.049217224121094, 332.7235412597656)
# Junction 266: (193.8870086669922, -395.862060546875)
# Junction 761: (412.5441589355469, -77.5523910522461)
# Junction 775: (-16.246580123901367, -47.11484909057617)
# Junction 779: (-16.246580123901367, -47.11485290527344)
# Junction 862: (413.61224365234375, -180.85299682617188)
# Junction 902: (-16.693941116333008, -161.10397338867188)
# Junction 1073: (-15.371306419372559, 141.44076538085938)
# Junction 1076: (-15.746291160583496, 67.13235473632812)
# Junction 1092: (128.07969665527344, 38.499168395996094)
# Junction 1101: (67.32251739501953, 37.85639190673828)
# Junction 1162: (1.7574024200439453, -299.07855224609375)
# Junction 1174: (-16.907346725463867, -222.62460327148438)
# Junction 1185: (-67.64703369140625, 37.356319427490234)
# Junction 1194: (-67.64703369140625, 37.35631561279297)
# Junction 1400: (-357.55426025390625, 37.0203857421875)
# Junction 1601: (410.39788818359375, -12.040185928344727)

# %%
def create_figure8_waypoints(world):
    segments = [
        (45, 6),      # North section
        (862, 6),     # East junction
        (38, 6),      # East to center
        (1092, 6),    # Center junction
        (35, 6),      # South section
        (1174, -4),   # South junction
        (40, -4),     # West section
        (1185, -4)    # West junction back to start
    ]
    
    route_waypoints = []
    for road_id, lane_id in segments:
        waypoints = get_lane_waypoints(world, road_id, lane_id)
        route_waypoints.extend(waypoints)
    
    return route_waypoints

def visualize_figure8(world):
   colors = {
       (45, 6): carla.Color(255,0,0),      # Red - North
       (862, 6): carla.Color(255,255,0),    # Yellow - East junction
       (38, 6): carla.Color(0,255,0),       # Green - East
       (1092, 6): carla.Color(0,255,255),   # Cyan - Center
       (35, 6): carla.Color(0,0,255),       # Blue - South
       (1174, -4): carla.Color(255,0,255),  # Magenta - South junction
       (40, -4): carla.Color(255,128,0),    # Orange - West
       (1185, -4): carla.Color(128,0,255)   # Purple - West junction
   }
   
   for (road_id, lane_id), color in colors.items():
       waypoints = get_lane_waypoints(world, road_id, lane_id)
       if waypoints:
           visualize_waypoints(world, waypoints, color)

visualize_figure8(world)

# %% [markdown]
# ## Check lane connections

# %%
def check_lane_connections(world, road_id, lane_id):
   waypoints = get_lane_waypoints(world, road_id, lane_id)
   if not waypoints:
       return
       
   start = waypoints[0].transform.location
   end = waypoints[-1].transform.location
   
   print(f"Road {road_id} Lane {lane_id}:")
   print(f"Start: ({start.x:.1f}, {start.y:.1f})")
   print(f"End: ({end.x:.1f}, {end.y:.1f})")
   
   # Visualize points
   world.debug.draw_point(start, size=0.5, color=carla.Color(255,0,0), life_time=-1)
   world.debug.draw_point(end, size=0.5, color=carla.Color(0,255,0), life_time=-1)

# Usage for major roads
for road_id in [35, 38, 40, 45]:
   check_lane_connections(world, road_id, -4)
# Out:
# Road 35 Lane -4:
# Start: (248.7, -364.2)
# End: (382.1, -182.8)
# Road 38 Lane -4:
# Start: (363.5, 4.3)
# End: (130.3, 7.0)
# Road 40 Lane -4:
# Start: (-120.8, 5.8)
# End: (-356.9, 5.5)
# Road 45 Lane -4:
# Start: (-515.2, 241.0)
# End: (-29.0, 353.1)

# %% [markdown]
# ## Find connecting segments

# %%
def euclidean_distance(p1, p2):
    return ((p1.x - p2.x)**2 + (p1.y - p2.y)**2)**0.5

def get_road_endpoints(world, road_id, lane_id):
    waypoints = get_lane_waypoints(world, road_id, lane_id)
    if not waypoints:
        return None
    return (waypoints[0].transform.location, waypoints[-1].transform.location)

def get_road_reference_distance(world, road_id, lane_id):
    """Get average distance between consecutive waypoints on this road"""
    waypoints = get_lane_waypoints(world, road_id, lane_id)
    if not waypoints or len(waypoints) < 2:
        return None
    distances = [euclidean_distance(w1.transform.location, w2.transform.location) 
                for w1, w2 in zip(waypoints[:-1], waypoints[1:])]
    return sum(distances) / len(distances)

def is_connecting(p1, p2, ref_distance):
    dist = euclidean_distance(p1, p2)
    return 0.7 * ref_distance <= dist <= 1.3 * ref_distance

def build_figure8(world, initial_segment):
    figure8 = [initial_segment]  # List of (road_id, lane_id) tuples
    changed = True
    
    while changed:
        changed = False
        current_endpoints = get_road_endpoints(world, figure8[-1][0], figure8[-1][1])
        if not current_endpoints:
            continue
            
        # Get all roads with 8 lanes
        candidates = [(r, -4) for r in range(0, 1700) 
                     if get_lane_waypoints(world, r, -4) 
                     and (r, -4) not in figure8]
        
        for candidate in candidates:
            candidate_endpoints = get_road_endpoints(world, candidate[0], candidate[1])
            if not candidate_endpoints:
                continue
                
            ref_dist = get_road_reference_distance(world, figure8[-1][0], figure8[-1][1])
            if not ref_dist:
                continue
                
            # Check if candidate connects to last segment
            if (is_connecting(current_endpoints[1], candidate_endpoints[0], ref_dist) or
                is_connecting(current_endpoints[1], candidate_endpoints[1], ref_dist)):
                figure8.append(candidate)
                changed = True
                break
                
    return figure8

# Usage
initial_segment = (45, -4)  # Start with road 45
figure8_segments = build_figure8(world, initial_segment)

# Visualize result
colors = [carla.Color(r,g,b) for r,g,b in 
         [(255,0,0), (0,255,0), (0,0,255), (255,255,0), 
          (0,255,255), (255,0,255), (128,128,0), (0,128,128)]]

for (road_id, lane_id), color in zip(figure8_segments, colors):
    waypoints = get_lane_waypoints(world, road_id, lane_id)
    visualize_waypoints(world, waypoints, color)
