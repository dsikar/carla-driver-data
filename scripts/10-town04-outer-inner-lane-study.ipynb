# %% [markdown]
# ## Town04 Figure of 8 ring road study

# %%
# Boilerplate code, we assume that world with town 04 has been loaded in a parallel session
# boilerplate code
import carla 
import math 
import random 
import time 
import carla_helpers as helpers

# Connect to the client and get the world object
client = carla.Client('localhost', 2000) 
world = client.get_world() 

# load Town04 map
world = client.load_world('Town04')

# %% [markdown]
# ## Place spectator for optimal viewing experience

# %%
transform = helpers.get_spectator_transform(world)

# transform = helpers.set_spectator_transform(world, (12.53, -430.17, 200.86), (-37.66, 57.56, 0))
# Out:
# === Spectator Transform ===
# Location: x=-56.26, y=4.20, z=554.04
# Rotation: pitch=-87.06, yaw=54.52, roll=-0.00

# %%
import carla_helpers as helpers
#transform = helpers.get_spectator_transform(world)
# === Spectator Transform ===
# Location: x=-56.26, y=4.20, z=554.04
# Rotation: pitch=-87.06, yaw=54.52, roll=-0.00
transform = helpers.set_spectator_transform(world, (-56.26, 4.20, 554.04), (-87.06, 54.52, 0))
# Out:
# === Spectator Transform Set ===
# Location: x=-56.26, y=4.20, z=554.04
# Rotation: pitch=-87.06, yaw=54.52, roll=0.00

# %% [markdown]
# ## Lane plotting

# %%
# helper functions
def find_eight_lane_roads(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    road_lanes = {}
    for wp in waypoints:
        road_id = wp.road_id
        if road_id not in road_lanes:
            road_lanes[road_id] = set()
        road_lanes[road_id].add(wp.lane_id)
    
    eight_lane_roads = [road_id for road_id, lanes in road_lanes.items() 
                       if len(lanes) == 8]
    
    if eight_lane_roads:
        print(f"Roads with 8 lanes:")
        for road_id in eight_lane_roads:
            print(f"Road ID: {road_id}, Lanes: {sorted(list(road_lanes[road_id]))}")
    else:
        print("No roads with exactly 8 lanes found")
    
    return eight_lane_roads

# Usage:
eight_lane_roads = find_eight_lane_roads(world)
# eight_lane_roads

def place_markers_on_lane(world, eight_lane_roads, target_lane_id=-3):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Filter waypoints for target roads and lane
    target_waypoints = [wp for wp in waypoints 
                       if wp.road_id in eight_lane_roads 
                       and wp.lane_id == target_lane_id]
    
    # Place markers
    markers = []
    marker_color = carla.Color(r=255, g=0, b=0)  # Red markers
    marker_life_time = 20.0  # Markers will persist for 20 seconds
    
    for wp in target_waypoints:
        location = wp.transform.location
        # Draw a sphere at each waypoint
        marker = world.debug.draw_point(
            location,
            size=0.1,  # 10cm sphere
            color=marker_color,
            life_time=marker_life_time
        )
        markers.append(marker)
    
    print(f"Placed {len(markers)} markers on lane {target_lane_id} "
          f"across {len(eight_lane_roads)} roads")
    
    return markers, target_waypoints

# Usage:
markers, target_waypoints = place_markers_on_lane(world, eight_lane_roads)
# Out:
# Roads with 8 lanes:
# Road ID: 6, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 35, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 36, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 37, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 38, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 39, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 40, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 41, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 42, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 43, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 45, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 46, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 47, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 48, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 49, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 50, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Placed 1246 markers on lane -3 across 16 roads
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Place markers on one road segment (road_id) only

# %%
#markers = place_markers_on_lane(world, [6])
markers = place_markers_on_lane(world, [50])
# Out:
# Placed 89 markers on lane -3 across 1 roads

# %%
type(markers) # tuple
type(markers[0]) # list
type(markers[1]) # list
markers[1]
type(markers[1][0]) # carla.Waypoint
# Out:
# carla.libcarla.Waypoint

# %% [markdown]
# ## Determine if markers are geo-sequencial

# %%
def analyze_marker_sequence(markers, distance_threshold=2.5):
    if len(markers) < 2:
        print("At least two markers are required for analysis")
        return True
        
    sequence_breaks = []
    for i in range(len(markers) - 1):
        loc1 = markers[1][i].transform.location
        loc2 = markers[1][i + 1].transform.location
        
        distance = ((loc2.x - loc1.x)**2 + 
                   (loc2.y - loc1.y)**2 + 
                   (loc2.z - loc1.z)**2)**0.5
                   
        if distance > distance_threshold:
            sequence_breaks.append((i, distance))
    
    if sequence_breaks:
        print(f"Found {len(sequence_breaks)} breaks in sequence:")
        for break_idx, dist in sequence_breaks:
            print(f"Break between markers {break_idx} and {break_idx+1}, distance: {dist:.2f}m")
        return False
        
    return True

analyze_marker_sequence(markers)
# Out:
# True

# %% [markdown]
# ## Determine if waypoints are sequencial

# %%
type(target_waypoints) # list
type(target_waypoints[0]) # carla.libcarla.Waypoint
for method in dir(target_waypoints[0]):
    print(method)
type(target_waypoints[0].transform) # carla.libcarla.Transform 
for method in dir(target_waypoints[0].transform):
    print(method)
print(type(target_waypoints[0].transform.location)) # <class 'carla.libcarla.Location'>
for method in dir(target_waypoints[0].transform.location):
    print(method)
type(target_waypoints[0].transform.location.x) # float
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_junction
# get_landmarks
# get_landmarks_of_type
# get_left_lane
# get_right_lane
# id
# is_intersection
# is_junction
# junction_id
# lane_change
# lane_id
# lane_type
# lane_width
# left_lane_marking
# next
# next_until_lane_end
# previous
# previous_until_lane_start
# right_lane_marking
# road_id
# s
# section_id
# transform
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __instance_size__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_forward_vector
# get_inverse_matrix
# get_matrix
# get_right_vector
# get_up_vector
# location
# rotation
# transform
# transform_vector
# <class 'carla.libcarla.Location'>
# __abs__
# __add__
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __iadd__
# __idiv__
# __imul__
# __init__
# __init_subclass__
# __instance_size__
# __isub__
# __le__
# __lt__
# __module__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __rmul__
# __rtruediv__
# __setattr__
# __sizeof__
# __str__
# __sub__
# __subclasshook__
# __truediv__
# __weakref__
# cross
# distance
# distance_2d
# distance_squared
# distance_squared_2d
# dot
# dot_2d
# get_vector_angle
# length
# make_unit_vector
# squared_length
# x
# y
# z
# float

# %%
def analyze_road_sequence(world, road_id, distance_threshold=2.5, debug=False):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    if debug:
        print(f"Analyzing road_id: {road_id}")
    
    # Get all waypoints for this road, organized by lane
    road_lanes = {}
    for wp in waypoints:
        if wp.road_id == road_id:
            if wp.lane_id not in road_lanes:
                road_lanes[wp.lane_id] = []
            road_lanes[wp.lane_id].append(wp)
    
    # Sort waypoints in each lane by s-value
    for lane_id in road_lanes:
        if debug:
            print(f"Checking sequence for lane_id: {lane_id}")
        road_lanes[lane_id].sort(key=lambda x: x.s)
    
    # Check sequence for each lane
    sequence_breaks = {}
    for lane_id, lane_waypoints in road_lanes.items():
        if len(lane_waypoints) < 2:
            continue
        breaks = []
        for i in range(len(lane_waypoints) - 1):
            loc1 = lane_waypoints[i].transform.location
            loc2 = lane_waypoints[i + 1].transform.location
            distance = ((loc2.x - loc1.x)**2 + 
                       (loc2.y - loc1.y)**2 + 
                       (loc2.z - loc1.z)**2)**0.5
            if distance > distance_threshold:
                breaks.append((i, distance))
        if breaks:
            sequence_breaks[lane_id] = breaks
    
    # Report findings
    if sequence_breaks:
        print(f"Found sequence breaks in road {road_id}:")
        for lane_id, breaks in sequence_breaks.items():
            print(f"\nLane {lane_id}:")
            for break_idx, dist in breaks:
                print(f"Break between waypoints {break_idx} and {break_idx+1}, distance: {dist:.2f}m")
        return False
    
    print(f"Road {road_id} has continuous waypoint sequences in all lanes")
    return True
road_id = 6
analyze_road_sequence(world, road_id, distance_threshold=2.5, debug=True)
# Out:
# Analyzing road_id: 6
# Checking sequence for lane_id: -4
# Checking sequence for lane_id: -3
# Checking sequence for lane_id: -2
# Checking sequence for lane_id: -1
# Checking sequence for lane_id: 3
# Checking sequence for lane_id: 4
# Checking sequence for lane_id: 5
# Checking sequence for lane_id: 6
# Road 6 has continuous waypoint sequences in all lanes
# True

# %%
carla_map = world.get_map()
waypoints = carla_map.generate_waypoints(2.0)
for method in dir(waypoints[0]):
    print(method)
type(waypoints)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_junction
# get_landmarks
# get_landmarks_of_type
# get_left_lane
# get_right_lane
# id
# is_intersection
# is_junction
# junction_id
# lane_change
# lane_id
# lane_type
# lane_width
# left_lane_marking
# next
# next_until_lane_end
# previous
# previous_until_lane_start
# right_lane_marking
# road_id
# s
# section_id
# transform
# list

# %%
waypoints[0].right_lane_marking.type
# Out:
# carla.libcarla.LaneMarkingType.Solid

# %% [markdown]
# ## check all road_ids for non-sequential waypoint

# %%
def get_unique_road_ids(waypoints):
    return sorted(list(set(wp.road_id for wp in waypoints)))

road_ids = get_unique_road_ids(waypoints)

for road_id in road_ids:
    analyze_road_sequence(world, road_id, distance_threshold=2.5)
# Out:
# Road 0 has continuous waypoint sequences in all lanes
# Road 1 has continuous waypoint sequences in all lanes
# Road 2 has continuous waypoint sequences in all lanes
# Road 3 has continuous waypoint sequences in all lanes
# Road 4 has continuous waypoint sequences in all lanes
# Road 5 has continuous waypoint sequences in all lanes
# Road 6 has continuous waypoint sequences in all lanes
# Road 7 has continuous waypoint sequences in all lanes
# Road 8 has continuous waypoint sequences in all lanes
# Road 9 has continuous waypoint sequences in all lanes
# Road 10 has continuous waypoint sequences in all lanes
# Road 11 has continuous waypoint sequences in all lanes
# Road 12 has continuous waypoint sequences in all lanes
# Road 13 has continuous waypoint sequences in all lanes
# Road 14 has continuous waypoint sequences in all lanes
# Road 15 has continuous waypoint sequences in all lanes
# Road 16 has continuous waypoint sequences in all lanes
# Road 17 has continuous waypoint sequences in all lanes
# Road 18 has continuous waypoint sequences in all lanes
# Road 19 has continuous waypoint sequences in all lanes
# Road 20 has continuous waypoint sequences in all lanes
# Road 21 has continuous waypoint sequences in all lanes
# Road 22 has continuous waypoint sequences in all lanes
# Road 23 has continuous waypoint sequences in all lanes
# Road 24 has continuous waypoint sequences in all lanes
# Road 25 has continuous waypoint sequences in all lanes
# Road 26 has continuous waypoint sequences in all lanes
# Road 27 has continuous waypoint sequences in all lanes
# Road 28 has continuous waypoint sequences in all lanes
# Road 29 has continuous waypoint sequences in all lanes
# Road 30 has continuous waypoint sequences in all lanes
# Road 31 has continuous waypoint sequences in all lanes
# Road 32 has continuous waypoint sequences in all lanes
# Road 33 has continuous waypoint sequences in all lanes
# Road 34 has continuous waypoint sequences in all lanes
# Road 35 has continuous waypoint sequences in all lanes
# Road 36 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 37:
#
# Lane 6:
# Break between waypoints 15 and 16, distance: 2.58m
# Break between waypoints 16 and 17, distance: 2.58m
# Break between waypoints 17 and 18, distance: 2.58m
# Break between waypoints 18 and 19, distance: 2.58m
# Break between waypoints 19 and 20, distance: 2.58m
# Found sequence breaks in road 38:
#
# Lane 6:
# Break between waypoints 0 and 1, distance: 2.58m
# Break between waypoints 1 and 2, distance: 2.58m
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.58m
# Break between waypoints 5 and 6, distance: 2.58m
# Break between waypoints 6 and 7, distance: 2.58m
# Break between waypoints 7 and 8, distance: 2.58m
# Break between waypoints 8 and 9, distance: 2.58m
# Break between waypoints 9 and 10, distance: 2.58m
# Break between waypoints 10 and 11, distance: 2.58m
# Break between waypoints 11 and 12, distance: 2.58m
# Break between waypoints 12 and 13, distance: 2.58m
# Break between waypoints 13 and 14, distance: 2.58m
# Break between waypoints 14 and 15, distance: 2.58m
# Break between waypoints 15 and 16, distance: 2.58m
# Road 39 has continuous waypoint sequences in all lanes
# Road 40 has continuous waypoint sequences in all lanes
# Road 41 has continuous waypoint sequences in all lanes
# Road 42 has continuous waypoint sequences in all lanes
# Road 43 has continuous waypoint sequences in all lanes
# Road 44 has continuous waypoint sequences in all lanes
# Road 45 has continuous waypoint sequences in all lanes
# Road 46 has continuous waypoint sequences in all lanes
# Road 47 has continuous waypoint sequences in all lanes
# Road 48 has continuous waypoint sequences in all lanes
# Road 49 has continuous waypoint sequences in all lanes
# Road 50 has continuous waypoint sequences in all lanes
# Road 51 has continuous waypoint sequences in all lanes
# Road 52 has continuous waypoint sequences in all lanes
# Road 54 has continuous waypoint sequences in all lanes
# Road 61 has continuous waypoint sequences in all lanes
# Road 63 has continuous waypoint sequences in all lanes
# Road 65 has continuous waypoint sequences in all lanes
# Road 88 has continuous waypoint sequences in all lanes
# Road 89 has continuous waypoint sequences in all lanes
# Road 108 has continuous waypoint sequences in all lanes
# Road 109 has continuous waypoint sequences in all lanes
# Road 115 has continuous waypoint sequences in all lanes
# Road 119 has continuous waypoint sequences in all lanes
# Road 124 has continuous waypoint sequences in all lanes
# Road 128 has continuous waypoint sequences in all lanes
# Road 135 has continuous waypoint sequences in all lanes
# Road 136 has continuous waypoint sequences in all lanes
# Road 144 has continuous waypoint sequences in all lanes
# Road 145 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 149:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.64m
# Break between waypoints 5 and 6, distance: 2.79m
# Road 158 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 161:
#
# Lane 1:
# Break between waypoints 5 and 6, distance: 2.60m
# Break between waypoints 6 and 7, distance: 2.60m
# Road 170 has continuous waypoint sequences in all lanes
# Road 179 has continuous waypoint sequences in all lanes
# Road 189 has continuous waypoint sequences in all lanes
# Road 209 has continuous waypoint sequences in all lanes
# Road 210 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 225:
#
# Lane 1:
# Break between waypoints 3 and 4, distance: 2.59m
# Break between waypoints 4 and 5, distance: 2.59m
# Road 231 has continuous waypoint sequences in all lanes
# Road 241 has continuous waypoint sequences in all lanes
# Road 247 has continuous waypoint sequences in all lanes
# Road 266 has continuous waypoint sequences in all lanes
# Road 267 has continuous waypoint sequences in all lanes
# Road 271 has continuous waypoint sequences in all lanes
# Road 275 has continuous waypoint sequences in all lanes
# Road 290 has continuous waypoint sequences in all lanes
# Road 291 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 306:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.50m
# Break between waypoints 3 and 4, distance: 2.55m
# Break between waypoints 4 and 5, distance: 2.71m
# Break between waypoints 5 and 6, distance: 2.68m
# Road 314 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 321:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.67m
# Break between waypoints 3 and 4, distance: 2.67m
# Break between waypoints 4 and 5, distance: 2.66m
# Break between waypoints 5 and 6, distance: 2.66m
# Road 330 has continuous waypoint sequences in all lanes
# Road 350 has continuous waypoint sequences in all lanes
# Road 351 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 372:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.55m
# Break between waypoints 5 and 6, distance: 2.55m
# Road 381 has continuous waypoint sequences in all lanes
# Road 385 has continuous waypoint sequences in all lanes
# Road 393 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 407:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.59m
# Break between waypoints 5 and 6, distance: 2.59m
# Road 413 has continuous waypoint sequences in all lanes
# Road 419 has continuous waypoint sequences in all lanes
# Road 428 has continuous waypoint sequences in all lanes
# Road 457 has continuous waypoint sequences in all lanes
# Road 458 has continuous waypoint sequences in all lanes
# Road 467 has continuous waypoint sequences in all lanes
# Road 468 has continuous waypoint sequences in all lanes
# Road 477 has continuous waypoint sequences in all lanes
# Road 496 has continuous waypoint sequences in all lanes
# Road 497 has continuous waypoint sequences in all lanes
# Road 510 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 518:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.53m
# Break between waypoints 3 and 4, distance: 2.60m
# Break between waypoints 4 and 5, distance: 2.84m
# Break between waypoints 5 and 6, distance: 2.60m
# Found sequence breaks in road 528:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.69m
# Break between waypoints 3 and 4, distance: 2.70m
# Break between waypoints 4 and 5, distance: 2.64m
# Break between waypoints 5 and 6, distance: 2.63m
# Road 540 has continuous waypoint sequences in all lanes
# Road 556 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 561:
#
# Lane 1:
# Break between waypoints 3 and 4, distance: 2.52m
# Break between waypoints 4 and 5, distance: 2.71m
# Break between waypoints 5 and 6, distance: 2.71m
# Found sequence breaks in road 569:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.64m
# Break between waypoints 3 and 4, distance: 2.64m
# Road 573 has continuous waypoint sequences in all lanes
# Road 593 has continuous waypoint sequences in all lanes
# Road 594 has continuous waypoint sequences in all lanes
# Road 633 has continuous waypoint sequences in all lanes
# Road 634 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 653:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.63m
# Break between waypoints 3 and 4, distance: 2.63m
# Road 661 has continuous waypoint sequences in all lanes
# Road 666 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 674:
#
# Lane -1:
# Break between waypoints 5 and 6, distance: 2.57m
# Break between waypoints 6 and 7, distance: 2.57m
# Road 684 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 695:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.54m
# Break between waypoints 3 and 4, distance: 2.54m
# Break between waypoints 5 and 6, distance: 2.78m
# Found sequence breaks in road 702:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.65m
# Break between waypoints 3 and 4, distance: 2.63m
# Road 708 has continuous waypoint sequences in all lanes
# Road 731 has continuous waypoint sequences in all lanes
# Road 732 has continuous waypoint sequences in all lanes
# Road 746 has continuous waypoint sequences in all lanes
# Road 749 has continuous waypoint sequences in all lanes
# Road 760 has continuous waypoint sequences in all lanes
# Road 761 has continuous waypoint sequences in all lanes
# Road 774 has continuous waypoint sequences in all lanes
# Road 775 has continuous waypoint sequences in all lanes
# Road 779 has continuous waypoint sequences in all lanes
# Road 782 has continuous waypoint sequences in all lanes
# Road 797 has continuous waypoint sequences in all lanes
# Road 798 has continuous waypoint sequences in all lanes
# Road 799 has continuous waypoint sequences in all lanes
# Road 807 has continuous waypoint sequences in all lanes
# Road 808 has continuous waypoint sequences in all lanes
# Road 816 has continuous waypoint sequences in all lanes
# Road 819 has continuous waypoint sequences in all lanes
# Road 826 has continuous waypoint sequences in all lanes
# Road 828 has continuous waypoint sequences in all lanes
# Road 829 has continuous waypoint sequences in all lanes
# Road 844 has continuous waypoint sequences in all lanes
# Road 845 has continuous waypoint sequences in all lanes
# Road 861 has continuous waypoint sequences in all lanes
# Road 862 has continuous waypoint sequences in all lanes
# Road 863 has continuous waypoint sequences in all lanes
# Road 867 has continuous waypoint sequences in all lanes
# Road 879 has continuous waypoint sequences in all lanes
# Road 880 has continuous waypoint sequences in all lanes
# Road 886 has continuous waypoint sequences in all lanes
# Road 901 has continuous waypoint sequences in all lanes
# Road 902 has continuous waypoint sequences in all lanes
# Road 907 has continuous waypoint sequences in all lanes
# Road 912 has continuous waypoint sequences in all lanes
# Road 926 has continuous waypoint sequences in all lanes
# Road 927 has continuous waypoint sequences in all lanes
# Road 943 has continuous waypoint sequences in all lanes
# Road 949 has continuous waypoint sequences in all lanes
# Road 955 has continuous waypoint sequences in all lanes
# Road 962 has continuous waypoint sequences in all lanes
# Road 968 has continuous waypoint sequences in all lanes
# Road 974 has continuous waypoint sequences in all lanes
# Road 981 has continuous waypoint sequences in all lanes
# Road 988 has continuous waypoint sequences in all lanes
# Road 996 has continuous waypoint sequences in all lanes
# Road 1003 has continuous waypoint sequences in all lanes
# Road 1012 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1015:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.60m
# Break between waypoints 5 and 6, distance: 2.60m
# Found sequence breaks in road 1024:
#
# Lane 1:
# Break between waypoints 5 and 6, distance: 2.52m
# Break between waypoints 6 and 7, distance: 2.52m
# Road 1028 has continuous waypoint sequences in all lanes
# Road 1043 has continuous waypoint sequences in all lanes
# Road 1044 has continuous waypoint sequences in all lanes
# Road 1072 has continuous waypoint sequences in all lanes
# Road 1073 has continuous waypoint sequences in all lanes
# Road 1076 has continuous waypoint sequences in all lanes
# Road 1080 has continuous waypoint sequences in all lanes
# Road 1091 has continuous waypoint sequences in all lanes
# Road 1092 has continuous waypoint sequences in all lanes
# Road 1097 has continuous waypoint sequences in all lanes
# Road 1101 has continuous waypoint sequences in all lanes
# Road 1114 has continuous waypoint sequences in all lanes
# Road 1115 has continuous waypoint sequences in all lanes
# Road 1122 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1133:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 3 and 4, distance: 2.52m
# Break between waypoints 4 and 5, distance: 2.50m
# Road 1141 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1148:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 3 and 4, distance: 2.52m
# Road 1161 has continuous waypoint sequences in all lanes
# Road 1162 has continuous waypoint sequences in all lanes
# Road 1173 has continuous waypoint sequences in all lanes
# Road 1174 has continuous waypoint sequences in all lanes
# Road 1184 has continuous waypoint sequences in all lanes
# Road 1185 has continuous waypoint sequences in all lanes
# Road 1191 has continuous waypoint sequences in all lanes
# Road 1194 has continuous waypoint sequences in all lanes
# Road 1209 has continuous waypoint sequences in all lanes
# Road 1210 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1217:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.53m
# Break between waypoints 5 and 6, distance: 2.75m
# Break between waypoints 6 and 7, distance: 2.53m
# Road 1225 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1232:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.76m
# Break between waypoints 5 and 6, distance: 2.72m
# Road 1239 has continuous waypoint sequences in all lanes
# Road 1263 has continuous waypoint sequences in all lanes
# Road 1264 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1281:
#
# Lane -1:
# Break between waypoints 3 and 4, distance: 2.54m
# Break between waypoints 4 and 5, distance: 2.70m
# Break between waypoints 5 and 6, distance: 2.69m
# Road 1288 has continuous waypoint sequences in all lanes
# Road 1297 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1307:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.59m
# Break between waypoints 3 and 4, distance: 2.59m
# Road 1312 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1318:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.51m
# Break between waypoints 3 and 4, distance: 2.51m
# Break between waypoints 4 and 5, distance: 2.50m
# Break between waypoints 5 and 6, distance: 2.50m
# Found sequence breaks in road 1327:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.54m
# Break between waypoints 3 and 4, distance: 2.53m
# Road 1337 has continuous waypoint sequences in all lanes
# Road 1360 has continuous waypoint sequences in all lanes
# Road 1361 has continuous waypoint sequences in all lanes
# Road 1400 has continuous waypoint sequences in all lanes
# Road 1401 has continuous waypoint sequences in all lanes
# Road 1412 has continuous waypoint sequences in all lanes
# Road 1421 has continuous waypoint sequences in all lanes
# Road 1432 has continuous waypoint sequences in all lanes
# Road 1442 has continuous waypoint sequences in all lanes
# Road 1450 has continuous waypoint sequences in all lanes
# Road 1465 has continuous waypoint sequences in all lanes
# Road 1466 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1479:
#
# Lane -1:
# Break between waypoints 1 and 2, distance: 2.52m
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 5 and 6, distance: 2.53m
# Road 1488 has continuous waypoint sequences in all lanes
# Road 1497 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1507:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.57m
# Break between waypoints 3 and 4, distance: 2.56m
# Break between waypoints 5 and 6, distance: 2.71m
# Found sequence breaks in road 1522:
#
# Lane -1:
# Break between waypoints 1 and 2, distance: 2.62m
# Break between waypoints 2 and 3, distance: 2.62m
# Break between waypoints 3 and 4, distance: 2.56m
# Road 1531 has continuous waypoint sequences in all lanes
# Road 1539 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1546:
#
# Lane 1:
# Break between waypoints 1 and 2, distance: 2.57m
# Break between waypoints 2 and 3, distance: 2.62m
# Break between waypoints 3 and 4, distance: 2.62m
# Road 1567 has continuous waypoint sequences in all lanes
# Road 1568 has continuous waypoint sequences in all lanes
# Road 1594 has continuous waypoint sequences in all lanes
# Road 1595 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1601:
#
# Lane 6:
# Break between waypoints 0 and 1, distance: 2.58m
# Break between waypoints 1 and 2, distance: 2.58m
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.58m
# Break between waypoints 5 and 6, distance: 2.58m
# Break between waypoints 6 and 7, distance: 2.58m
# Break between waypoints 7 and 8, distance: 2.58m
# Break between waypoints 8 and 9, distance: 2.58m
# Break between waypoints 9 and 10, distance: 2.58m
# Break between waypoints 10 and 11, distance: 2.58m
# Break between waypoints 11 and 12, distance: 2.58m
# Break between waypoints 12 and 13, distance: 2.58m
# Break between waypoints 13 and 14, distance: 2.58m
# Break between waypoints 14 and 15, distance: 2.58m
# Break between waypoints 15 and 16, distance: 2.58m
# Break between waypoints 16 and 17, distance: 2.58m
# Break between waypoints 17 and 18, distance: 2.58m
# Break between waypoints 18 and 19, distance: 2.58m
# Break between waypoints 19 and 20, distance: 2.58m
# Road 1602 has continuous waypoint sequences in all lanes

# %% [markdown]
# ## List road lanes

# %%
def get_unique_lane_ids(waypoints, road_id):
    return sorted(list(set(wp.lane_id for wp in waypoints if wp.road_id == road_id)))

road_id = 6
lane_ids = get_unique_lane_ids(waypoints, road_id)  
print(lane_ids) # [-4, -3, -2, -1, 3, 4, 5, 6]

road_id = 38
lane_ids = get_unique_lane_ids(waypoints, road_id)  
lane_ids
# Out:
# [-4, -3, -2, -1, 3, 4, 5, 6]
# [-4, -3, -2, -1, 3, 4, 5, 6]

# %%
eight_lane_roads
# Out:
# [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]

# %% [markdown]
# # Plot inner lane of figure of 8 ring road, town 04

# %%
road_ids = [6, 35]
markers = place_markers_on_lane(world, road_ids)

# for road_id in eight_lane_roads:
#     place_markers_on_lane(world, [road_id])
# Out:
# Placed 175 markers on lane -4 across 2 roads

# %%
## Waypoints set at distance > 2.5m
for waypoint in waypoints:
    if waypoint.road_id == 6:
        print(waypoint.id)
        # print(waypoint.s)
# Out:
# 4641250760981045379
# 4592942668712833820
# 11983327098621662466
# 5224660670092596996
# 6982654154847670249
# 6129230666532924672
# 5034693531769484326
# 2827203210415223208
# 18313294055911148380
# 15644884804647786691
# 3383236460981022085
# 7460701396986866395
# 8423436749056312822
# 9516529405160445831
# 7374316201285725625
# 3090671597044257503
# 9387395423480887448
# 16864857345223855
# 11347369723081038233
# 3248915232482796439
# 10806400343159910738
# 11881993350336530155
# 4654049739649610341
# 17483696824142191507
# 2811769558798115716
# 13458593866777907099
# 12933423164516232109
# 10559221071065543683
# 11217352454628465086
# 7135836977279816703
# 8990204711485311697
# 4229121148518471847
# 5644134607749557701
# 6752368382134331394
# 12251833964545368092
# 356858600335447322
# 16762126860177900383
# 10096639739408483614
# 8779535702564972536
# 6065289533055955062
# 604644998855766037
# 5973068758167605170
# 4105289373958060140
# 14865034262452006250
# 3407846882579146319
# 14004514317817939822
# 4103668378455050984
# 3492852901020968294
# 10576358984672155825
# 3957045305942469358
# 7403925809211710768
# 17838788807326729606
# 3093301504159927243
# 6738728460707820082
# 10913117610509574244
# 3238096789532061066
# 14050683428595618361
# 1021802896377092198
# 12039195062785148600
# 3755888448294901774
# 15360923541899420915
# 3280798490661858826
# 16564051007181567708
# 2278863579294085810
# 16545651071243131649
# 3225949398874415774
# 7690972828668634496
# 17524110244802727382
# 12940998674137198267
# 15973276888091980930
# 6834942587718554452
# 6679965813352764026
# 11276292304506337737
# 1000656347952981334
# 12787908455397002952
# 11223279057678158622
# 17563328699930393955
# 13880331105925417754
# 7815639674455183180
# 13224394229742542114
# 17111461512357632145
# 10815841795111175566
# 12593652146134494608
# 13317173821907905254
# 6400877984126824747
# 5519205528106013074
# 3476257105316550084
# 579091828553710826
# 11246331680563308841
# 2899590222081732470
# 17740497696741753768
# 10703346943551783166
# 10805961902096729923
# 18224951256520634618
# 3974497715760280876
# 6941095994996724482
# 12864967477828082669
# 221441560794928346
# 5316842419220831812
# 12321303592479107138
# 9990448003007979815
# 5109340444785566102
# 10172487852465983248
# 5788947017899226686
# 11702860305944070129
# 16899334194479940142
# 801369052642254064
# 9142369452109606470
# 18285046751136778379
# 4872749565697905906
# 3995344496080453924
# 17438252085927411786
# 10432172256905962677
# 3078177337155768722
# 2803103804336988812
# 17665881966350068618
# 5450960468618623087
# 9912427563110958478
# 4417530077840847112
# 11090065165234676614
# 2432536914972006265
# 5950439773509623206
# 3366590307640268408
# 16296817180436517582
# 9763502566385442739
# 11215068040235247818
# 4084307421940969884
# 12904297672977657202
# 11938797503871107965
# 16906631647560888778
# 3567097384881422676
# 17343846926918699858
# 5898566184885402007
# 5755205539435806374
# 15816455167758759808
# 12112349105544024238
# 12566231313047385665
# 5691199864520064478
# 6439177872430626112
# 4999201875973485206
# 11974123335616172923
# 10962484439389777730
# 9116201476668373012
# 8304105703978536250
# 4359908673935565381
# 4741396042720162946
# 2219683051256441500
# 4204800441485756570
# 13306709698795502303
# 11262432126986658462
# 5010360321219326840
# 17669242420268797430
# 1890474392022859529
# 14161635859296103062
# 10651445784935549320
# 9144933806922286558
# 15848472007325677603
# 4376933551420704218
# 10409091712357435916
# 3463427461515057122
# 7321120737264890317
# 10729903591443730426
# 13315374822573057060
# 5362350370104913186
# 16921523225374773767
# 8823354608762205814
# 16940103057385513968
# 5981696022773250846
# 5130588589298416215
# 3636891176505257200
# 9557825557128368686
# 13624533870196746712
# 17442536375875686077
# 16052579407108047660
# 2015934516716820218
# 14428257235825792980
# 10410043317833181093
# 5821850389280232610
# 1020085999720783740
# 10023826485530011770
# 7775925013729073855
# 14754481744807200894
# 14142192099616162648
# 4452219569286382550
# 4801190377008588379
# 2209240067057365572
# 4666976938699677914
# 3538191183467517916
# 10483538440324767265
# 18083434714978799240
# 9344199428774197518
# 2169468191887231456
# 1683766421169712745
# 16487978806747870390
# 5668182746055103336
# 5580744049203100606
# 2796649102097252867
# 9566016993882237882
# 16937200216277512172
# 2410946518181416386
# 8295661718815217951
# 12311681629360428968
# 2406463569960909686
# 5159193077278539552
# 17552538208279279621
# 1120915618321071908
# 14119276021068387058
# 15596729913685552412
# 6787589490558558509
# 17419785305167272474
# 17265874106529093892
# 3133756159601713922
# 6212737841118075879
# 5209181102949801046
# 6898850186770074064
# 17255247412404629758
# 15317220772266309091
# 7540018227375902140
# 13678280812259973730
# 12009611894074129508
# 2548123129160086857
# 12389945111653048928
# 13961540121744533894
# 16533706562529441544
# 7816116041520598321
# 1369548590166460270
# 10424444518519363504
# 17526371726549821702
# 14695482779914060619
# 9181462431594024882
# 11044313920777206756
# 12082148138643323658
# 5907019248576455143
# 9386918507332045280
# 7395869622416378430
# 16752480819941084392
# 8892122108871108397
# 13643940210794078268
# 7649289220231511914
# 11027723423031571012
# 14137674073020956661
# 1019835282029915346
# 6224198917135413836
# 1345118080928125002
# 3872384976555154735
# 9683170861581025358
# 16702600240792802760
# 12858366089568427590
# 3541367734338098347
# 8420578687583901172
# 17203150574134880554
# 17574928149027681324
# 14672251935615631633
# 5454695595941581016
# 8500237508271636478
# 11083447514615934672

# %% [markdown]
# ## world object methods

# %%
for method in dir(world):
    print(method)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# apply_color_texture_to_object
# apply_color_texture_to_objects
# apply_float_color_texture_to_object
# apply_float_color_texture_to_objects
# apply_settings
# apply_textures_to_object
# apply_textures_to_objects
# cast_ray
# debug
# enable_environment_objects
# freeze_all_traffic_lights
# get_actor
# get_actors
# get_blueprint_library
# get_environment_objects
# get_level_bbs
# get_lightmanager
# get_map
# get_names_of_all_objects
# get_random_location_from_navigation
# get_settings
# get_snapshot
# get_spectator
# get_traffic_light
# get_traffic_light_from_opendrive_id
# get_traffic_lights_from_waypoint
# get_traffic_lights_in_junction
# get_traffic_sign
# get_vehicles_light_states
# get_weather
# ground_projection
# id
# load_map_layer
# on_tick
# project_point
# remove_on_tick
# reset_all_traffic_lights
# set_pedestrians_cross_factor
# set_pedestrians_seed
# set_weather
# spawn_actor
# tick
# try_spawn_actor
# unload_map_layer
# wait_for_tick

# %% [markdown]
# ## Figure of 8 waypoings

# %%
def validate_figure8_waypoints(world):
    """Get and validate waypoints for figure-8 track."""
    road_sequence = [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    target_lane_id = -4
    waypoint_spacing = 2.0
    
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(waypoint_spacing)
    
    # Filter and sort waypoints
    road_waypoints = {}
    for road_id in road_sequence:
        road_waypoints[road_id] = [wp for wp in waypoints 
                                 if wp.road_id == road_id and wp.lane_id == target_lane_id]
        road_waypoints[road_id].sort(key=lambda x: x.s)
        
        print(f"Road {road_id}: {len(road_waypoints[road_id])} waypoints")
        
        # Validate waypoint spacing
        if len(road_waypoints[road_id]) > 1:
            first = road_waypoints[road_id][0].transform.location
            last = road_waypoints[road_id][-1].transform.location
            distance = ((last.x - first.x)**2 + 
                       (last.y - first.y)**2 + 
                       (last.z - first.z)**2)**0.5
            print(f"Road length: {distance:.1f}m")
    
    return road_waypoints

road_waypoints = validate_figure8_waypoints(world)
road_waypoints
# Out:
# Road 6: 32 waypoints
# Road length: 62.1m
# Road 35: 143 waypoints
# Road length: 225.2m
# Road 36: 41 waypoints
# Road length: 80.0m
# Road 37: 21 waypoints
# Road length: 36.6m
# Road 38: 123 waypoints
# Road length: 233.5m
# Road 39: 67 waypoints
# Road length: 132.0m
# Road 40: 119 waypoints
# Road length: 236.3m
# Road 41: 105 waypoints
# Road length: 198.2m
# Road 42: 17 waypoints
# Road length: 32.0m
# Road 43: 17 waypoints
# Road length: 32.2m
# Road 45: 293 waypoints
# Road length: 499.0m
# Road 46: 70 waypoints
# Road length: 142.1m
# Road 47: 57 waypoints
# Road length: 112.0m
# Road 48: 32 waypoints
# Road length: 62.0m
# Road 49: 20 waypoints
# Road length: 37.8m
# Road 50: 89 waypoints
# Road length: 150.8m
# {6: [<carla.libcarla.Waypoint at 0x7fc1a49fb920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fbbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fbea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fc190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fc450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fc710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fc9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fcc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fcf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fd240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fd500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fd7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fda80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fdd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fe030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fe2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fe5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fe870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49feb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49fedf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ff0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ff3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ff660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ff920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ffbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ffea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a00190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a00450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a00710>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a009d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a00c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4a00f50>],
#  35: [<carla.libcarla.Waypoint at 0x7fc1a067ace8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067afa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067b298>,
#   <carla.libcarla.Waypoint at 0x7fc1a067b558>,
#   <carla.libcarla.Waypoint at 0x7fc1a067b818>,
#   <carla.libcarla.Waypoint at 0x7fc1a067bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a067c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a067c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a067c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a067c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a067ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a067d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a067d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a067dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a067def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067e768>,
#   <carla.libcarla.Waypoint at 0x7fc1a067ea28>,
#   <carla.libcarla.Waypoint at 0x7fc1a067ece8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067efa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067f298>,
#   <carla.libcarla.Waypoint at 0x7fc1a067f558>,
#   <carla.libcarla.Waypoint at 0x7fc1a067f818>,
#   <carla.libcarla.Waypoint at 0x7fc1a067fad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a067fd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0680088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0680348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0680608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06808c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0680b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0680e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a0681138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06813f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06816b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0681978>,
#   <carla.libcarla.Waypoint at 0x7fc1a0681c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a0681ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06821e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06824a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0682768>,
#   <carla.libcarla.Waypoint at 0x7fc1a0682a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a0682ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0682fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0683298>,
#   <carla.libcarla.Waypoint at 0x7fc1a0683558>,
#   <carla.libcarla.Waypoint at 0x7fc1a0683818>,
#   <carla.libcarla.Waypoint at 0x7fc1a0683ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0683d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0684088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0684348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0684608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06848c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0684b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0684e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a0685138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06853f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06856b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0685978>,
#   <carla.libcarla.Waypoint at 0x7fc1a0685c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a0685ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06861e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06864a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0686768>,
#   <carla.libcarla.Waypoint at 0x7fc1a0686a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a0686ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0686fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0687298>,
#   <carla.libcarla.Waypoint at 0x7fc1a0687558>,
#   <carla.libcarla.Waypoint at 0x7fc1a0687818>,
#   <carla.libcarla.Waypoint at 0x7fc1a0687ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0687d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0688088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0688348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0688608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06888c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0688b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0688e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a0689138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06893f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06896b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0689978>,
#   <carla.libcarla.Waypoint at 0x7fc1a0689c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a0689ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068a1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068a4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068a768>,
#   <carla.libcarla.Waypoint at 0x7fc1a068aa28>,
#   <carla.libcarla.Waypoint at 0x7fc1a068ace8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068afa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068b298>,
#   <carla.libcarla.Waypoint at 0x7fc1a068b558>,
#   <carla.libcarla.Waypoint at 0x7fc1a068b818>,
#   <carla.libcarla.Waypoint at 0x7fc1a068bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a068c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a068c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a068c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a068c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a068ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a068d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a068d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a068dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a068def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068e768>,
#   <carla.libcarla.Waypoint at 0x7fc1a068ea28>,
#   <carla.libcarla.Waypoint at 0x7fc1a068ece8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068efa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068f298>,
#   <carla.libcarla.Waypoint at 0x7fc1a068f558>,
#   <carla.libcarla.Waypoint at 0x7fc1a068f818>,
#   <carla.libcarla.Waypoint at 0x7fc1a068fad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a068fd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0691088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0691348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0691608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06918c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0691b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0691e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a0692138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06923f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06926b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0692978>,
#   <carla.libcarla.Waypoint at 0x7fc1a0692c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a0692ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06931e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06934a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0693768>,
#   <carla.libcarla.Waypoint at 0x7fc1a0693a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a0693ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0693fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0694298>,
#   <carla.libcarla.Waypoint at 0x7fc1a0694558>,
#   <carla.libcarla.Waypoint at 0x7fc1a0694818>],
#  36: [<carla.libcarla.Waypoint at 0x7fc1a0694ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0694d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0695088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0695348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0695608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06958c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0695b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0695e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a0696138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06963f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06966b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0696978>,
#   <carla.libcarla.Waypoint at 0x7fc1a0696c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a0696ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06971e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06974a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0697768>,
#   <carla.libcarla.Waypoint at 0x7fc1a0697a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a0697ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0697fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0698298>,
#   <carla.libcarla.Waypoint at 0x7fc1a0698558>,
#   <carla.libcarla.Waypoint at 0x7fc1a0698818>,
#   <carla.libcarla.Waypoint at 0x7fc1a0698ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0698d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a0699088>,
#   <carla.libcarla.Waypoint at 0x7fc1a0699348>,
#   <carla.libcarla.Waypoint at 0x7fc1a0699608>,
#   <carla.libcarla.Waypoint at 0x7fc1a06998c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a0699b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a0699e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a069a138>,
#   <carla.libcarla.Waypoint at 0x7fc1a069a3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069a6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069a978>,
#   <carla.libcarla.Waypoint at 0x7fc1a069ac38>,
#   <carla.libcarla.Waypoint at 0x7fc1a069aef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069b1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069b4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069b768>,
#   <carla.libcarla.Waypoint at 0x7fc1a069ba28>],
#  37: [<carla.libcarla.Waypoint at 0x7fc1a069cef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069d1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069d4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069d768>,
#   <carla.libcarla.Waypoint at 0x7fc1a069da28>,
#   <carla.libcarla.Waypoint at 0x7fc1a069dce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069dfa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069e298>,
#   <carla.libcarla.Waypoint at 0x7fc1a069e558>,
#   <carla.libcarla.Waypoint at 0x7fc1a069e818>,
#   <carla.libcarla.Waypoint at 0x7fc1a069ead8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069ed98>,
#   <carla.libcarla.Waypoint at 0x7fc1a069f088>,
#   <carla.libcarla.Waypoint at 0x7fc1a069f348>,
#   <carla.libcarla.Waypoint at 0x7fc1a069f608>,
#   <carla.libcarla.Waypoint at 0x7fc1a069f8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a069fb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a069fe48>,
#   <carla.libcarla.Waypoint at 0x7fc1a06a0138>,
#   <carla.libcarla.Waypoint at 0x7fc1a06a03f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a06a06b8>],
#  38: [<carla.libcarla.Waypoint at 0x7fc1a06ab450>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ab710>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ab9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06abc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a06abf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ac240>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ac500>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ac7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06aca80>,
#   <carla.libcarla.Waypoint at 0x7fc1a06acd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ad030>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ad2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ad5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ad870>,
#   <carla.libcarla.Waypoint at 0x7fc1a06adb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a06addf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ae0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ae3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ae660>,
#   <carla.libcarla.Waypoint at 0x7fc1a06ae920>,
#   <carla.libcarla.Waypoint at 0x7fc1a06aebe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06aeea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06af190>,
#   <carla.libcarla.Waypoint at 0x7fc1a06af450>,
#   <carla.libcarla.Waypoint at 0x7fc1a06af710>,
#   <carla.libcarla.Waypoint at 0x7fc1a06af9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06afc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a06aff50>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b0240>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b0500>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b07c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b0a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b0d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b1030>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b12f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b15b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b1870>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b1b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b1df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b20e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b23a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b2660>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b2920>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b2be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b2ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b3190>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b3450>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b3710>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b39d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b3c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b3f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b4240>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b4500>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b47c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b4a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a06b4d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4990030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49902f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49905b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4990870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4990b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4990df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49910e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49913a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4991660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4991920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4991be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4991ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4992190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4992450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4992710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49929d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4992c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4992f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4993240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4993500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49937c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4993a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4993d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4994030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49942f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49945b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4994870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4994b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4994df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49950e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49953a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4995660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4995920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4995be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4995ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4996190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4996450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4996710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49969d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4996c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4996f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4997240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4997500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49977c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4997a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4997d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4998030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49982f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49985b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4998870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4998b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4998df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49990e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49993a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4999660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4999920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4999be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4999ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499a190>,
#   <carla.libcarla.Waypoint at 0x7fc1a499a450>,
#   <carla.libcarla.Waypoint at 0x7fc1a499a710>,
#   <carla.libcarla.Waypoint at 0x7fc1a499a9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499ac90>,
#   <carla.libcarla.Waypoint at 0x7fc1a499af50>,
#   <carla.libcarla.Waypoint at 0x7fc1a499b240>,
#   <carla.libcarla.Waypoint at 0x7fc1a499b500>,
#   <carla.libcarla.Waypoint at 0x7fc1a499b7c0>],
#  39: [<carla.libcarla.Waypoint at 0x7fc1a499ba80>,
#   <carla.libcarla.Waypoint at 0x7fc1a499bd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a499c030>,
#   <carla.libcarla.Waypoint at 0x7fc1a499c2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499c5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499c870>,
#   <carla.libcarla.Waypoint at 0x7fc1a499cb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a499cdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499d0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499d3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499d660>,
#   <carla.libcarla.Waypoint at 0x7fc1a499d920>,
#   <carla.libcarla.Waypoint at 0x7fc1a499dbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499dea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499e190>,
#   <carla.libcarla.Waypoint at 0x7fc1a499e450>,
#   <carla.libcarla.Waypoint at 0x7fc1a499e710>,
#   <carla.libcarla.Waypoint at 0x7fc1a499e9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499ec90>,
#   <carla.libcarla.Waypoint at 0x7fc1a499ef50>,
#   <carla.libcarla.Waypoint at 0x7fc1a499f240>,
#   <carla.libcarla.Waypoint at 0x7fc1a499f500>,
#   <carla.libcarla.Waypoint at 0x7fc1a499f7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a499fa80>,
#   <carla.libcarla.Waypoint at 0x7fc1a499fd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a0030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a02f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a05b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a0870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a0b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a0df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a10e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a13a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a1660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a1920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a1be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a1ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a2190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a2450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a2710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a29d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a2c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a2f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a3240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a3500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a37c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a3a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a3d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a4030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a42f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a45b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a4870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a4b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a4df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a50e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a53a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a5660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a5920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a5be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a5ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a6190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a6450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a6710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a69d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a6c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a6f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a7240>],
#  40: [<carla.libcarla.Waypoint at 0x7fc1a49a7870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a7b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a7df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a80e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a83a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a8660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a8920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a8be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a8ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a9190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a9450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a9710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a99d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a9c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49a9f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aa240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aa500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aa7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aaa80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aad40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ab030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ab2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ab5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ab870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49abb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49abdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ac0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ac3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ac660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ac920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49acbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49acea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ad190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ad450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ad710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ad9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49adc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49adf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ae240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ae500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ae7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aea80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49aed40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49af030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49af2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49af5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49af870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49afb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49afdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b00e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b03a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b0660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b0920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b0be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b0ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b1190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b1450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b1710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b19d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b1c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b1f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b2240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b2500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b27c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b2a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b2d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b3030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b32f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b35b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b3870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b3b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b3df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b40e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b43a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b4660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b4920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b4be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b4ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b5190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b5450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b5710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b59d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b5c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b5f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b6240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b6500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b67c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b6a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b6d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b7030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b72f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b75b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b7870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b7b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b7df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b80e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b83a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b8660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b8920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b8be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b8ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b9190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b9450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b9710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b99d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b9c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49b9f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ba240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ba500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ba7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49baa80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bad40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bb030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bb2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bb5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bb870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bbb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bbdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bc0e0>],
#  41: [<carla.libcarla.Waypoint at 0x7fc1a49bc3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bc660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bc920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bcbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bcea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bd190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bd450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bd710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bd9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bdc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bdf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49be240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49be500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49be7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bea80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bed40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bf030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bf2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bf5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bf870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bfb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49bfdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c00e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c03a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c0660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c0920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c0be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c0ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c1190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c1450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c1710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c19d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c1c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c1f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c2240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c2500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c27c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c2a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c2d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c3030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c32f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c35b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c3870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c3b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c3df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c40e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c43a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c4660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c4920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c4be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c4ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c5190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c5450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c5710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c59d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c5c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c5f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c6240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c6500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c67c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c6a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c6d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c7030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c72f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c75b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c7870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c7b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c7df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c80e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c83a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c8660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c8920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c8be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c8ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c9190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c9450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c9710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c99d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c9c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49c9f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ca240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ca500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ca7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49caa80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cad40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cb030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cb2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cb5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cb870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cbb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cbdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cc0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cc3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cc660>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cc920>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ccbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ccea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cd190>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cd450>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cd710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cd9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cdc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cdf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ce240>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ce500>],
#  42: [<carla.libcarla.Waypoint at 0x7fc1a49ce7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cea80>,
#   <carla.libcarla.Waypoint at 0x7fc1a49ced40>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cf030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cf2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cf5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cf870>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cfb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a49cfdf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49500e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49503a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4950660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4950920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4950be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4950ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4951190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4951450>],
#  43: [<carla.libcarla.Waypoint at 0x7fc1a4953768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4953a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4953ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4953fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4954298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4954558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4954818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4954ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4954d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4955088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4955348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4955608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49558c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4955b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4955e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4956138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49563f8>],
#  45: [<carla.libcarla.Waypoint at 0x7fc1a495bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a495c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a495c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a495c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a495c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a495ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a495d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a495d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a495dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a495def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495e768>,
#   <carla.libcarla.Waypoint at 0x7fc1a495ea28>,
#   <carla.libcarla.Waypoint at 0x7fc1a495ece8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495efa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495f298>,
#   <carla.libcarla.Waypoint at 0x7fc1a495f558>,
#   <carla.libcarla.Waypoint at 0x7fc1a495f818>,
#   <carla.libcarla.Waypoint at 0x7fc1a495fad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a495fd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4960088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4960348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4960608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49608c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4960b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4960e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4961138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49613f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49616b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4961978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4961c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4961ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49621e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49624a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4962768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4962a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4962ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4962fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4963298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4963558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4963818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4963ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4963d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4964088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4964348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4964608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49648c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4964b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4964e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4965138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49653f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49656b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4965978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4965c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4965ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49661e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49664a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4966768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4966a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4966ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4966fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4967298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4967558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4967818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4967ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4967d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4968088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4968348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4968608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49688c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4968b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4968e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4969138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49693f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49696b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4969978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4969c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4969ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496a1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496a4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496a768>,
#   <carla.libcarla.Waypoint at 0x7fc1a496aa28>,
#   <carla.libcarla.Waypoint at 0x7fc1a496ace8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496afa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496b298>,
#   <carla.libcarla.Waypoint at 0x7fc1a496b558>,
#   <carla.libcarla.Waypoint at 0x7fc1a496b818>,
#   <carla.libcarla.Waypoint at 0x7fc1a496bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a496c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a496c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a496c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a496c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a496ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a496d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a496d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a496dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a496def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496e768>,
#   <carla.libcarla.Waypoint at 0x7fc1a496ea28>,
#   <carla.libcarla.Waypoint at 0x7fc1a496ece8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496efa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496f298>,
#   <carla.libcarla.Waypoint at 0x7fc1a496f558>,
#   <carla.libcarla.Waypoint at 0x7fc1a496f818>,
#   <carla.libcarla.Waypoint at 0x7fc1a496fad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a496fd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4970088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4970348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4970608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49708c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4970b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4970e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4971138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49713f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49716b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4971978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4971c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4971ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49721e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49724a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4972768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4972a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4972ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4972fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4973298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4973558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4973818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4973ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4973d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4974088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4974348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4974608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49748c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4974b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4974e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4975138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49753f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49756b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4975978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4975c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4975ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49761e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49764a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4976768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4976a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4976ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4976fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4977298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4977558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4977818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4977ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4977d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4978088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4978348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4978608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49788c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4978b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4978e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4979138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49793f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49796b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4979978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4979c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4979ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497a1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497a4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497a768>,
#   <carla.libcarla.Waypoint at 0x7fc1a497aa28>,
#   <carla.libcarla.Waypoint at 0x7fc1a497ace8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497afa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497b298>,
#   <carla.libcarla.Waypoint at 0x7fc1a497b558>,
#   <carla.libcarla.Waypoint at 0x7fc1a497b818>,
#   <carla.libcarla.Waypoint at 0x7fc1a497bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a497c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a497c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a497c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a497c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a497ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a497d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a497d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a497dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a497def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497e768>,
#   <carla.libcarla.Waypoint at 0x7fc1a497ea28>,
#   <carla.libcarla.Waypoint at 0x7fc1a497ece8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497efa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497f298>,
#   <carla.libcarla.Waypoint at 0x7fc1a497f558>,
#   <carla.libcarla.Waypoint at 0x7fc1a497f818>,
#   <carla.libcarla.Waypoint at 0x7fc1a497fad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a497fd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4980088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4980348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4980608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49808c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4980b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4980e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4981138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49813f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49816b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4981978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4981c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4981ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49821e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49824a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4982768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4982a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4982ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4982fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4983298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4983558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4983818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4983ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4983d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4984088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4984348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4984608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49848c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4984b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4984e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4985138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49853f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49856b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4985978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4985c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4985ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49861e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49864a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4986768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4986a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4986ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4986fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4987298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4987558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4987818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4987ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4987d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4988088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4988348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4988608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49888c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4988b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4988e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4989138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49893f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49896b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4989978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4989c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4989ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498a1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498a4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498a768>,
#   <carla.libcarla.Waypoint at 0x7fc1a498aa28>,
#   <carla.libcarla.Waypoint at 0x7fc1a498ace8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498afa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498b298>,
#   <carla.libcarla.Waypoint at 0x7fc1a498b558>,
#   <carla.libcarla.Waypoint at 0x7fc1a498b818>,
#   <carla.libcarla.Waypoint at 0x7fc1a498bad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498bd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a498c088>,
#   <carla.libcarla.Waypoint at 0x7fc1a498c348>,
#   <carla.libcarla.Waypoint at 0x7fc1a498c608>,
#   <carla.libcarla.Waypoint at 0x7fc1a498c8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498cb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a498ce48>,
#   <carla.libcarla.Waypoint at 0x7fc1a498d138>,
#   <carla.libcarla.Waypoint at 0x7fc1a498d3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498d6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498d978>,
#   <carla.libcarla.Waypoint at 0x7fc1a498dc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a498def8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498e1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498e4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a498e768>],
#  46: [<carla.libcarla.Waypoint at 0x7fc1a49125b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4912870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4912b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4912df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49130e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49133a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4913660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4913920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4913be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4913ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4914190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4914450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4914710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49149d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4914c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4914f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4915240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4915500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49157c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4915a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4915d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4916030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49162f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49165b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4916870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4916b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4916df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49170e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49173a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4917660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4917920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4917be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4917ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4918190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4918450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4918710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49189d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4918c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4918f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4919240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4919500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49197c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4919a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4919d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a491a030>,
#   <carla.libcarla.Waypoint at 0x7fc1a491a2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491a5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491a870>,
#   <carla.libcarla.Waypoint at 0x7fc1a491ab30>,
#   <carla.libcarla.Waypoint at 0x7fc1a491adf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491b0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491b3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491b660>,
#   <carla.libcarla.Waypoint at 0x7fc1a491b920>,
#   <carla.libcarla.Waypoint at 0x7fc1a491bbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491bea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491c190>,
#   <carla.libcarla.Waypoint at 0x7fc1a491c450>,
#   <carla.libcarla.Waypoint at 0x7fc1a491c710>,
#   <carla.libcarla.Waypoint at 0x7fc1a491c9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491cc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a491cf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a491d240>,
#   <carla.libcarla.Waypoint at 0x7fc1a491d500>,
#   <carla.libcarla.Waypoint at 0x7fc1a491d7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491da80>,
#   <carla.libcarla.Waypoint at 0x7fc1a491dd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a491e030>,
#   <carla.libcarla.Waypoint at 0x7fc1a491e2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491e5b0>],
#  47: [<carla.libcarla.Waypoint at 0x7fc1a491eb30>,
#   <carla.libcarla.Waypoint at 0x7fc1a491edf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491f0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491f3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491f660>,
#   <carla.libcarla.Waypoint at 0x7fc1a491f920>,
#   <carla.libcarla.Waypoint at 0x7fc1a491fbe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a491fea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4920190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4920450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4920710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49209d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4920c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4920f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4921240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4921500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49217c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4921a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4921d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4922030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49222f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49225b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4922870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4922b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4922df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49230e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49233a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4923660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4923920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4923be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4923ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4924190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4924450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4924710>,
#   <carla.libcarla.Waypoint at 0x7fc1a49249d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4924c90>,
#   <carla.libcarla.Waypoint at 0x7fc1a4924f50>,
#   <carla.libcarla.Waypoint at 0x7fc1a4925240>,
#   <carla.libcarla.Waypoint at 0x7fc1a4925500>,
#   <carla.libcarla.Waypoint at 0x7fc1a49257c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4925a80>,
#   <carla.libcarla.Waypoint at 0x7fc1a4925d40>,
#   <carla.libcarla.Waypoint at 0x7fc1a4926030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49262f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49265b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4926870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4926b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4926df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49270e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49273a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4927660>,
#   <carla.libcarla.Waypoint at 0x7fc1a4927920>,
#   <carla.libcarla.Waypoint at 0x7fc1a4927be0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4927ea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4928190>,
#   <carla.libcarla.Waypoint at 0x7fc1a4928450>,
#   <carla.libcarla.Waypoint at 0x7fc1a4928710>],
#  48: [<carla.libcarla.Waypoint at 0x7fc1a4929030>,
#   <carla.libcarla.Waypoint at 0x7fc1a49292f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a49295b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a4929870>,
#   <carla.libcarla.Waypoint at 0x7fc1a4929b30>,
#   <carla.libcarla.Waypoint at 0x7fc1a4929df0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492a0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492a3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492a660>,
#   <carla.libcarla.Waypoint at 0x7fc1a492a920>,
#   <carla.libcarla.Waypoint at 0x7fc1a492abe0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492aea0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492b190>,
#   <carla.libcarla.Waypoint at 0x7fc1a492b450>,
#   <carla.libcarla.Waypoint at 0x7fc1a492b710>,
#   <carla.libcarla.Waypoint at 0x7fc1a492b9d0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492bc90>,
#   <carla.libcarla.Waypoint at 0x7fc1a492bf50>,
#   <carla.libcarla.Waypoint at 0x7fc1a492c240>,
#   <carla.libcarla.Waypoint at 0x7fc1a492c500>,
#   <carla.libcarla.Waypoint at 0x7fc1a492c7c0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492ca80>,
#   <carla.libcarla.Waypoint at 0x7fc1a492cd40>,
#   <carla.libcarla.Waypoint at 0x7fc1a492d030>,
#   <carla.libcarla.Waypoint at 0x7fc1a492d2f0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492d5b0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492d870>,
#   <carla.libcarla.Waypoint at 0x7fc1a492db30>,
#   <carla.libcarla.Waypoint at 0x7fc1a492ddf0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492e0e0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492e3a0>,
#   <carla.libcarla.Waypoint at 0x7fc1a492e660>],
#  49: [<carla.libcarla.Waypoint at 0x7fc1a492f6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a492f978>,
#   <carla.libcarla.Waypoint at 0x7fc1a492fc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a492fef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49301e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49304a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4930768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4930a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4930ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4930fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4931298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4931558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4931818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4931ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4931d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4932088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4932348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4932608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49328c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4932b88>],
#  50: [<carla.libcarla.Waypoint at 0x7fc1a4933138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49333f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49336b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4933978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4933c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4933ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49341e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49344a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4934768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4934a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4934ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4934fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4935298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4935558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4935818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4935ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4935d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4936088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4936348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4936608>,
#   <carla.libcarla.Waypoint at 0x7fc1a49368c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4936b88>,
#   <carla.libcarla.Waypoint at 0x7fc1a4936e48>,
#   <carla.libcarla.Waypoint at 0x7fc1a4937138>,
#   <carla.libcarla.Waypoint at 0x7fc1a49373f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49376b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4937978>,
#   <carla.libcarla.Waypoint at 0x7fc1a4937c38>,
#   <carla.libcarla.Waypoint at 0x7fc1a4937ef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49381e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49384a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4938768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4938a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4938ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4938fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4939298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4939558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4939818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4939ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4939d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a493a088>,
#   <carla.libcarla.Waypoint at 0x7fc1a493a348>,
#   <carla.libcarla.Waypoint at 0x7fc1a493a608>,
#   <carla.libcarla.Waypoint at 0x7fc1a493a8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493ab88>,
#   <carla.libcarla.Waypoint at 0x7fc1a493ae48>,
#   <carla.libcarla.Waypoint at 0x7fc1a493b138>,
#   <carla.libcarla.Waypoint at 0x7fc1a493b3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493b6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493b978>,
#   <carla.libcarla.Waypoint at 0x7fc1a493bc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a493bef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493c1e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493c4a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493c768>,
#   <carla.libcarla.Waypoint at 0x7fc1a493ca28>,
#   <carla.libcarla.Waypoint at 0x7fc1a493cce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493cfa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493d298>,
#   <carla.libcarla.Waypoint at 0x7fc1a493d558>,
#   <carla.libcarla.Waypoint at 0x7fc1a493d818>,
#   <carla.libcarla.Waypoint at 0x7fc1a493dad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493dd98>,
#   <carla.libcarla.Waypoint at 0x7fc1a493e088>,
#   <carla.libcarla.Waypoint at 0x7fc1a493e348>,
#   <carla.libcarla.Waypoint at 0x7fc1a493e608>,
#   <carla.libcarla.Waypoint at 0x7fc1a493e8c8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493eb88>,
#   <carla.libcarla.Waypoint at 0x7fc1a493ee48>,
#   <carla.libcarla.Waypoint at 0x7fc1a493f138>,
#   <carla.libcarla.Waypoint at 0x7fc1a493f3f8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493f6b8>,
#   <carla.libcarla.Waypoint at 0x7fc1a493f978>,
#   <carla.libcarla.Waypoint at 0x7fc1a493fc38>,
#   <carla.libcarla.Waypoint at 0x7fc1a493fef8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49401e8>,
#   <carla.libcarla.Waypoint at 0x7fc1a49404a8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4940768>,
#   <carla.libcarla.Waypoint at 0x7fc1a4940a28>,
#   <carla.libcarla.Waypoint at 0x7fc1a4940ce8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4940fa8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4941298>,
#   <carla.libcarla.Waypoint at 0x7fc1a4941558>,
#   <carla.libcarla.Waypoint at 0x7fc1a4941818>,
#   <carla.libcarla.Waypoint at 0x7fc1a4941ad8>,
#   <carla.libcarla.Waypoint at 0x7fc1a4941d98>,
#   <carla.libcarla.Waypoint at 0x7fc1a4942088>,
#   <carla.libcarla.Waypoint at 0x7fc1a4942348>,
#   <carla.libcarla.Waypoint at 0x7fc1a4942608>]}

# %% [markdown]
# ## Road waypoints

# %%
def drive_figure_eight(world, vehicle):
    """Drive vehicle around Town04's figure-eight."""
    road_waypoints = validate_figure8_waypoints(world)
    road_sequence = [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    target_speed = 30  # km/h
    
    try:
        while True:
            for road_id in road_sequence:
                for wp in road_waypoints[road_id]:
                    control = compute_control(vehicle, wp, target_speed)
                    vehicle.apply_control(control)
                    
                    if world.get_settings().synchronous_mode:
                        world.tick()
                    else:
                        time.sleep(0.1)  # Adjust timing as needed
                        
    except KeyboardInterrupt:
        control = carla.VehicleControl(throttle=0, brake=1)
        vehicle.apply_control(control)

def compute_control(vehicle, target_wp, target_speed):
    """Compute vehicle control to reach waypoint."""
    control = carla.VehicleControl()
    
    # Get current state
    current_transform = vehicle.get_transform()
    current_velocity = vehicle.get_velocity()
    speed = 3.6 * math.sqrt(current_velocity.x**2 + current_velocity.y**2)  # km/h
    
    # Steering based on angle difference
    forward = current_transform.get_forward_vector()
    right = current_transform.get_right_vector()
    up = current_transform.get_up_vector()
    target_vector = target_wp.transform.location - current_transform.location
    
    forward_dot = (forward.x * target_vector.x + forward.y * target_vector.y) 
    right_dot = (right.x * target_vector.x + right.y * target_vector.y)
    
    steering = math.atan2(right_dot, forward_dot) / math.pi
    control.steer = max(-1.0, min(1.0, steering))
    
    # Speed control
    if speed < target_speed:
        control.throttle = 0.7
        control.brake = 0.0
    else:
        control.throttle = 0.0
        control.brake = 0.3
        
    return control
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
