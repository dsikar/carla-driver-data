# %% [markdown]
# ## Town04 Figure of 8 ring road study

# %%
# Boilerplate code, we assume that world with town 04 has been loaded in a parallel session
# boilerplate code
import carla 
import math 
import random 
import time 
import carla_helpers as helpers

# Connect to the client and get the world object
client = carla.Client('localhost', 2000) 
world = client.get_world() 

# load Town04 map
world = client.load_world('Town04')

# %% [markdown]
# ## Place spectator for optimal viewing experience

# %%
import carla_helpers as helpers
#transform = helpers.get_spectator_transform(world)
transform = helpers.set_spectator_transform(world, (12.53, -430.17, 200.86), (-37.66, 57.56, 0))
# Out:
# === Spectator Transform Set ===
# Location: x=12.53, y=-430.17, z=200.86
# Rotation: pitch=-37.66, yaw=57.56, roll=0.00

# %% [markdown]
# ## Lane plotting

# %%
# helper functions
def find_eight_lane_roads(world):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    road_lanes = {}
    for wp in waypoints:
        road_id = wp.road_id
        if road_id not in road_lanes:
            road_lanes[road_id] = set()
        road_lanes[road_id].add(wp.lane_id)
    
    eight_lane_roads = [road_id for road_id, lanes in road_lanes.items() 
                       if len(lanes) == 8]
    
    if eight_lane_roads:
        print(f"Roads with 8 lanes:")
        for road_id in eight_lane_roads:
            print(f"Road ID: {road_id}, Lanes: {sorted(list(road_lanes[road_id]))}")
    else:
        print("No roads with exactly 8 lanes found")
    
    return eight_lane_roads

# Usage:
eight_lane_roads = find_eight_lane_roads(world)
# eight_lane_roads

def place_markers_on_lane(world, eight_lane_roads, target_lane_id=-4):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    # Filter waypoints for target roads and lane
    target_waypoints = [wp for wp in waypoints 
                       if wp.road_id in eight_lane_roads 
                       and wp.lane_id == target_lane_id]
    
    # Place markers
    markers = []
    marker_color = carla.Color(r=255, g=0, b=0)  # Red markers
    marker_life_time = 20.0  # Markers will persist for 20 seconds
    
    for wp in target_waypoints:
        location = wp.transform.location
        # Draw a sphere at each waypoint
        marker = world.debug.draw_point(
            location,
            size=0.1,  # 10cm sphere
            color=marker_color,
            life_time=marker_life_time
        )
        markers.append(marker)
    
    print(f"Placed {len(markers)} markers on lane {target_lane_id} "
          f"across {len(eight_lane_roads)} roads")
    
    return markers, target_waypoints

# Usage:
markers, target_waypoints = place_markers_on_lane(world, eight_lane_roads)
# Out:
# Roads with 8 lanes:
# Road ID: 6, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 35, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 36, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 37, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 38, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 39, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 40, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 41, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 42, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 43, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 45, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 46, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 47, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 48, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 49, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Road ID: 50, Lanes: [-4, -3, -2, -1, 3, 4, 5, 6]
# Placed 1246 markers on lane -4 across 16 roads

# %% [markdown]
# ## Place markers on one road segment (road_id) only

# %%
#markers = place_markers_on_lane(world, [6])
markers = place_markers_on_lane(world, [50])
# Out:
# Placed 89 markers on lane -4 across 1 roads

# %%
type(markers) # tuple
type(markers[0]) # list
type(markers[1]) # list
markers[1]
type(markers[1][0]) # carla.Waypoint
# Out:
# carla.libcarla.Waypoint

# %% [markdown]
# ## Determine if markers are geo-sequencial

# %%
def analyze_marker_sequence(markers, distance_threshold=2.5):
    if len(markers) < 2:
        print("At least two markers are required for analysis")
        return True
        
    sequence_breaks = []
    for i in range(len(markers) - 1):
        loc1 = markers[1][i].transform.location
        loc2 = markers[1][i + 1].transform.location
        
        distance = ((loc2.x - loc1.x)**2 + 
                   (loc2.y - loc1.y)**2 + 
                   (loc2.z - loc1.z)**2)**0.5
                   
        if distance > distance_threshold:
            sequence_breaks.append((i, distance))
    
    if sequence_breaks:
        print(f"Found {len(sequence_breaks)} breaks in sequence:")
        for break_idx, dist in sequence_breaks:
            print(f"Break between markers {break_idx} and {break_idx+1}, distance: {dist:.2f}m")
        return False
        
    return True

analyze_marker_sequence(markers)
# Out:
# True

# %% [markdown]
# ## Determine if waypoints are sequencial

# %%
type(target_waypoints) # list
type(target_waypoints[0]) # carla.libcarla.Waypoint
for method in dir(target_waypoints[0]):
    print(method)
type(target_waypoints[0].transform) # carla.libcarla.Transform 
for method in dir(target_waypoints[0].transform):
    print(method)
print(type(target_waypoints[0].transform.location)) # <class 'carla.libcarla.Location'>
for method in dir(target_waypoints[0].transform.location):
    print(method)
type(target_waypoints[0].transform.location.x) # float
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_junction
# get_landmarks
# get_landmarks_of_type
# get_left_lane
# get_right_lane
# id
# is_intersection
# is_junction
# junction_id
# lane_change
# lane_id
# lane_type
# lane_width
# left_lane_marking
# next
# next_until_lane_end
# previous
# previous_until_lane_start
# right_lane_marking
# road_id
# s
# section_id
# transform
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __instance_size__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_forward_vector
# get_inverse_matrix
# get_matrix
# get_right_vector
# get_up_vector
# location
# rotation
# transform
# transform_vector
# <class 'carla.libcarla.Location'>
# __abs__
# __add__
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __iadd__
# __idiv__
# __imul__
# __init__
# __init_subclass__
# __instance_size__
# __isub__
# __le__
# __lt__
# __module__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __rmul__
# __rtruediv__
# __setattr__
# __sizeof__
# __str__
# __sub__
# __subclasshook__
# __truediv__
# __weakref__
# cross
# distance
# distance_2d
# distance_squared
# distance_squared_2d
# dot
# dot_2d
# get_vector_angle
# length
# make_unit_vector
# squared_length
# x
# y
# z
# float

# %%
def analyze_road_sequence(world, road_id, distance_threshold=2.5, debug=False):
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(2.0)
    
    if debug:
        print(f"Analyzing road_id: {road_id}")
    
    # Get all waypoints for this road, organized by lane
    road_lanes = {}
    for wp in waypoints:
        if wp.road_id == road_id:
            if wp.lane_id not in road_lanes:
                road_lanes[wp.lane_id] = []
            road_lanes[wp.lane_id].append(wp)
    
    # Sort waypoints in each lane by s-value
    for lane_id in road_lanes:
        if debug:
            print(f"Checking sequence for lane_id: {lane_id}")
        road_lanes[lane_id].sort(key=lambda x: x.s)
    
    # Check sequence for each lane
    sequence_breaks = {}
    for lane_id, lane_waypoints in road_lanes.items():
        if len(lane_waypoints) < 2:
            continue
        breaks = []
        for i in range(len(lane_waypoints) - 1):
            loc1 = lane_waypoints[i].transform.location
            loc2 = lane_waypoints[i + 1].transform.location
            distance = ((loc2.x - loc1.x)**2 + 
                       (loc2.y - loc1.y)**2 + 
                       (loc2.z - loc1.z)**2)**0.5
            if distance > distance_threshold:
                breaks.append((i, distance))
        if breaks:
            sequence_breaks[lane_id] = breaks
    
    # Report findings
    if sequence_breaks:
        print(f"Found sequence breaks in road {road_id}:")
        for lane_id, breaks in sequence_breaks.items():
            print(f"\nLane {lane_id}:")
            for break_idx, dist in breaks:
                print(f"Break between waypoints {break_idx} and {break_idx+1}, distance: {dist:.2f}m")
        return False
    
    print(f"Road {road_id} has continuous waypoint sequences in all lanes")
    return True
road_id = 6
analyze_road_sequence(world, road_id, distance_threshold=2.5, debug=True)
# Out:
# Analyzing road_id: 6
# Checking sequence for lane_id: -4
# Checking sequence for lane_id: -3
# Checking sequence for lane_id: -2
# Checking sequence for lane_id: -1
# Checking sequence for lane_id: 3
# Checking sequence for lane_id: 4
# Checking sequence for lane_id: 5
# Checking sequence for lane_id: 6
# Road 6 has continuous waypoint sequences in all lanes
# True

# %%
carla_map = world.get_map()
waypoints = carla_map.generate_waypoints(2.0)
for method in dir(waypoints[0]):
    print(method)
type(waypoints)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# get_junction
# get_landmarks
# get_landmarks_of_type
# get_left_lane
# get_right_lane
# id
# is_intersection
# is_junction
# junction_id
# lane_change
# lane_id
# lane_type
# lane_width
# left_lane_marking
# next
# next_until_lane_end
# previous
# previous_until_lane_start
# right_lane_marking
# road_id
# s
# section_id
# transform
# list

# %%
waypoints[0].right_lane_marking.type
# Out:
# carla.libcarla.LaneMarkingType.Solid

# %% [markdown]
# ## check all road_ids for non-sequential waypoint

# %%
def get_unique_road_ids(waypoints):
    return sorted(list(set(wp.road_id for wp in waypoints)))

road_ids = get_unique_road_ids(waypoints)

for road_id in road_ids:
    analyze_road_sequence(world, road_id, distance_threshold=2.5)
# Out:
# Road 0 has continuous waypoint sequences in all lanes
# Road 1 has continuous waypoint sequences in all lanes
# Road 2 has continuous waypoint sequences in all lanes
# Road 3 has continuous waypoint sequences in all lanes
# Road 4 has continuous waypoint sequences in all lanes
# Road 5 has continuous waypoint sequences in all lanes
# Road 6 has continuous waypoint sequences in all lanes
# Road 7 has continuous waypoint sequences in all lanes
# Road 8 has continuous waypoint sequences in all lanes
# Road 9 has continuous waypoint sequences in all lanes
# Road 10 has continuous waypoint sequences in all lanes
# Road 11 has continuous waypoint sequences in all lanes
# Road 12 has continuous waypoint sequences in all lanes
# Road 13 has continuous waypoint sequences in all lanes
# Road 14 has continuous waypoint sequences in all lanes
# Road 15 has continuous waypoint sequences in all lanes
# Road 16 has continuous waypoint sequences in all lanes
# Road 17 has continuous waypoint sequences in all lanes
# Road 18 has continuous waypoint sequences in all lanes
# Road 19 has continuous waypoint sequences in all lanes
# Road 20 has continuous waypoint sequences in all lanes
# Road 21 has continuous waypoint sequences in all lanes
# Road 22 has continuous waypoint sequences in all lanes
# Road 23 has continuous waypoint sequences in all lanes
# Road 24 has continuous waypoint sequences in all lanes
# Road 25 has continuous waypoint sequences in all lanes
# Road 26 has continuous waypoint sequences in all lanes
# Road 27 has continuous waypoint sequences in all lanes
# Road 28 has continuous waypoint sequences in all lanes
# Road 29 has continuous waypoint sequences in all lanes
# Road 30 has continuous waypoint sequences in all lanes
# Road 31 has continuous waypoint sequences in all lanes
# Road 32 has continuous waypoint sequences in all lanes
# Road 33 has continuous waypoint sequences in all lanes
# Road 34 has continuous waypoint sequences in all lanes
# Road 35 has continuous waypoint sequences in all lanes
# Road 36 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 37:
#
# Lane 6:
# Break between waypoints 15 and 16, distance: 2.58m
# Break between waypoints 16 and 17, distance: 2.58m
# Break between waypoints 17 and 18, distance: 2.58m
# Break between waypoints 18 and 19, distance: 2.58m
# Break between waypoints 19 and 20, distance: 2.58m
# Found sequence breaks in road 38:
#
# Lane 6:
# Break between waypoints 0 and 1, distance: 2.58m
# Break between waypoints 1 and 2, distance: 2.58m
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.58m
# Break between waypoints 5 and 6, distance: 2.58m
# Break between waypoints 6 and 7, distance: 2.58m
# Break between waypoints 7 and 8, distance: 2.58m
# Break between waypoints 8 and 9, distance: 2.58m
# Break between waypoints 9 and 10, distance: 2.58m
# Break between waypoints 10 and 11, distance: 2.58m
# Break between waypoints 11 and 12, distance: 2.58m
# Break between waypoints 12 and 13, distance: 2.58m
# Break between waypoints 13 and 14, distance: 2.58m
# Break between waypoints 14 and 15, distance: 2.58m
# Break between waypoints 15 and 16, distance: 2.58m
# Road 39 has continuous waypoint sequences in all lanes
# Road 40 has continuous waypoint sequences in all lanes
# Road 41 has continuous waypoint sequences in all lanes
# Road 42 has continuous waypoint sequences in all lanes
# Road 43 has continuous waypoint sequences in all lanes
# Road 44 has continuous waypoint sequences in all lanes
# Road 45 has continuous waypoint sequences in all lanes
# Road 46 has continuous waypoint sequences in all lanes
# Road 47 has continuous waypoint sequences in all lanes
# Road 48 has continuous waypoint sequences in all lanes
# Road 49 has continuous waypoint sequences in all lanes
# Road 50 has continuous waypoint sequences in all lanes
# Road 51 has continuous waypoint sequences in all lanes
# Road 52 has continuous waypoint sequences in all lanes
# Road 54 has continuous waypoint sequences in all lanes
# Road 61 has continuous waypoint sequences in all lanes
# Road 63 has continuous waypoint sequences in all lanes
# Road 65 has continuous waypoint sequences in all lanes
# Road 88 has continuous waypoint sequences in all lanes
# Road 89 has continuous waypoint sequences in all lanes
# Road 108 has continuous waypoint sequences in all lanes
# Road 109 has continuous waypoint sequences in all lanes
# Road 115 has continuous waypoint sequences in all lanes
# Road 119 has continuous waypoint sequences in all lanes
# Road 124 has continuous waypoint sequences in all lanes
# Road 128 has continuous waypoint sequences in all lanes
# Road 135 has continuous waypoint sequences in all lanes
# Road 136 has continuous waypoint sequences in all lanes
# Road 144 has continuous waypoint sequences in all lanes
# Road 145 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 149:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.64m
# Break between waypoints 5 and 6, distance: 2.79m
# Road 158 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 161:
#
# Lane 1:
# Break between waypoints 5 and 6, distance: 2.60m
# Break between waypoints 6 and 7, distance: 2.60m
# Road 170 has continuous waypoint sequences in all lanes
# Road 179 has continuous waypoint sequences in all lanes
# Road 189 has continuous waypoint sequences in all lanes
# Road 209 has continuous waypoint sequences in all lanes
# Road 210 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 225:
#
# Lane 1:
# Break between waypoints 3 and 4, distance: 2.59m
# Break between waypoints 4 and 5, distance: 2.59m
# Road 231 has continuous waypoint sequences in all lanes
# Road 241 has continuous waypoint sequences in all lanes
# Road 247 has continuous waypoint sequences in all lanes
# Road 266 has continuous waypoint sequences in all lanes
# Road 267 has continuous waypoint sequences in all lanes
# Road 271 has continuous waypoint sequences in all lanes
# Road 275 has continuous waypoint sequences in all lanes
# Road 290 has continuous waypoint sequences in all lanes
# Road 291 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 306:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.50m
# Break between waypoints 3 and 4, distance: 2.55m
# Break between waypoints 4 and 5, distance: 2.71m
# Break between waypoints 5 and 6, distance: 2.68m
# Road 314 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 321:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.67m
# Break between waypoints 3 and 4, distance: 2.67m
# Break between waypoints 4 and 5, distance: 2.66m
# Break between waypoints 5 and 6, distance: 2.66m
# Road 330 has continuous waypoint sequences in all lanes
# Road 350 has continuous waypoint sequences in all lanes
# Road 351 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 372:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.55m
# Break between waypoints 5 and 6, distance: 2.55m
# Road 381 has continuous waypoint sequences in all lanes
# Road 385 has continuous waypoint sequences in all lanes
# Road 393 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 407:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.59m
# Break between waypoints 5 and 6, distance: 2.59m
# Road 413 has continuous waypoint sequences in all lanes
# Road 419 has continuous waypoint sequences in all lanes
# Road 428 has continuous waypoint sequences in all lanes
# Road 457 has continuous waypoint sequences in all lanes
# Road 458 has continuous waypoint sequences in all lanes
# Road 467 has continuous waypoint sequences in all lanes
# Road 468 has continuous waypoint sequences in all lanes
# Road 477 has continuous waypoint sequences in all lanes
# Road 496 has continuous waypoint sequences in all lanes
# Road 497 has continuous waypoint sequences in all lanes
# Road 510 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 518:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.53m
# Break between waypoints 3 and 4, distance: 2.60m
# Break between waypoints 4 and 5, distance: 2.84m
# Break between waypoints 5 and 6, distance: 2.60m
# Found sequence breaks in road 528:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.69m
# Break between waypoints 3 and 4, distance: 2.70m
# Break between waypoints 4 and 5, distance: 2.64m
# Break between waypoints 5 and 6, distance: 2.63m
# Road 540 has continuous waypoint sequences in all lanes
# Road 556 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 561:
#
# Lane 1:
# Break between waypoints 3 and 4, distance: 2.52m
# Break between waypoints 4 and 5, distance: 2.71m
# Break between waypoints 5 and 6, distance: 2.71m
# Found sequence breaks in road 569:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.64m
# Break between waypoints 3 and 4, distance: 2.64m
# Road 573 has continuous waypoint sequences in all lanes
# Road 593 has continuous waypoint sequences in all lanes
# Road 594 has continuous waypoint sequences in all lanes
# Road 633 has continuous waypoint sequences in all lanes
# Road 634 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 653:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.63m
# Break between waypoints 3 and 4, distance: 2.63m
# Road 661 has continuous waypoint sequences in all lanes
# Road 666 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 674:
#
# Lane -1:
# Break between waypoints 5 and 6, distance: 2.57m
# Break between waypoints 6 and 7, distance: 2.57m
# Road 684 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 695:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.54m
# Break between waypoints 3 and 4, distance: 2.54m
# Break between waypoints 5 and 6, distance: 2.78m
# Found sequence breaks in road 702:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.65m
# Break between waypoints 3 and 4, distance: 2.63m
# Road 708 has continuous waypoint sequences in all lanes
# Road 731 has continuous waypoint sequences in all lanes
# Road 732 has continuous waypoint sequences in all lanes
# Road 746 has continuous waypoint sequences in all lanes
# Road 749 has continuous waypoint sequences in all lanes
# Road 760 has continuous waypoint sequences in all lanes
# Road 761 has continuous waypoint sequences in all lanes
# Road 774 has continuous waypoint sequences in all lanes
# Road 775 has continuous waypoint sequences in all lanes
# Road 779 has continuous waypoint sequences in all lanes
# Road 782 has continuous waypoint sequences in all lanes
# Road 797 has continuous waypoint sequences in all lanes
# Road 798 has continuous waypoint sequences in all lanes
# Road 799 has continuous waypoint sequences in all lanes
# Road 807 has continuous waypoint sequences in all lanes
# Road 808 has continuous waypoint sequences in all lanes
# Road 816 has continuous waypoint sequences in all lanes
# Road 819 has continuous waypoint sequences in all lanes
# Road 826 has continuous waypoint sequences in all lanes
# Road 828 has continuous waypoint sequences in all lanes
# Road 829 has continuous waypoint sequences in all lanes
# Road 844 has continuous waypoint sequences in all lanes
# Road 845 has continuous waypoint sequences in all lanes
# Road 861 has continuous waypoint sequences in all lanes
# Road 862 has continuous waypoint sequences in all lanes
# Road 863 has continuous waypoint sequences in all lanes
# Road 867 has continuous waypoint sequences in all lanes
# Road 879 has continuous waypoint sequences in all lanes
# Road 880 has continuous waypoint sequences in all lanes
# Road 886 has continuous waypoint sequences in all lanes
# Road 901 has continuous waypoint sequences in all lanes
# Road 902 has continuous waypoint sequences in all lanes
# Road 907 has continuous waypoint sequences in all lanes
# Road 912 has continuous waypoint sequences in all lanes
# Road 926 has continuous waypoint sequences in all lanes
# Road 927 has continuous waypoint sequences in all lanes
# Road 943 has continuous waypoint sequences in all lanes
# Road 949 has continuous waypoint sequences in all lanes
# Road 955 has continuous waypoint sequences in all lanes
# Road 962 has continuous waypoint sequences in all lanes
# Road 968 has continuous waypoint sequences in all lanes
# Road 974 has continuous waypoint sequences in all lanes
# Road 981 has continuous waypoint sequences in all lanes
# Road 988 has continuous waypoint sequences in all lanes
# Road 996 has continuous waypoint sequences in all lanes
# Road 1003 has continuous waypoint sequences in all lanes
# Road 1012 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1015:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.60m
# Break between waypoints 5 and 6, distance: 2.60m
# Found sequence breaks in road 1024:
#
# Lane 1:
# Break between waypoints 5 and 6, distance: 2.52m
# Break between waypoints 6 and 7, distance: 2.52m
# Road 1028 has continuous waypoint sequences in all lanes
# Road 1043 has continuous waypoint sequences in all lanes
# Road 1044 has continuous waypoint sequences in all lanes
# Road 1072 has continuous waypoint sequences in all lanes
# Road 1073 has continuous waypoint sequences in all lanes
# Road 1076 has continuous waypoint sequences in all lanes
# Road 1080 has continuous waypoint sequences in all lanes
# Road 1091 has continuous waypoint sequences in all lanes
# Road 1092 has continuous waypoint sequences in all lanes
# Road 1097 has continuous waypoint sequences in all lanes
# Road 1101 has continuous waypoint sequences in all lanes
# Road 1114 has continuous waypoint sequences in all lanes
# Road 1115 has continuous waypoint sequences in all lanes
# Road 1122 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1133:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 3 and 4, distance: 2.52m
# Break between waypoints 4 and 5, distance: 2.50m
# Road 1141 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1148:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 3 and 4, distance: 2.52m
# Road 1161 has continuous waypoint sequences in all lanes
# Road 1162 has continuous waypoint sequences in all lanes
# Road 1173 has continuous waypoint sequences in all lanes
# Road 1174 has continuous waypoint sequences in all lanes
# Road 1184 has continuous waypoint sequences in all lanes
# Road 1185 has continuous waypoint sequences in all lanes
# Road 1191 has continuous waypoint sequences in all lanes
# Road 1194 has continuous waypoint sequences in all lanes
# Road 1209 has continuous waypoint sequences in all lanes
# Road 1210 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1217:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.53m
# Break between waypoints 5 and 6, distance: 2.75m
# Break between waypoints 6 and 7, distance: 2.53m
# Road 1225 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1232:
#
# Lane -1:
# Break between waypoints 4 and 5, distance: 2.76m
# Break between waypoints 5 and 6, distance: 2.72m
# Road 1239 has continuous waypoint sequences in all lanes
# Road 1263 has continuous waypoint sequences in all lanes
# Road 1264 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1281:
#
# Lane -1:
# Break between waypoints 3 and 4, distance: 2.54m
# Break between waypoints 4 and 5, distance: 2.70m
# Break between waypoints 5 and 6, distance: 2.69m
# Road 1288 has continuous waypoint sequences in all lanes
# Road 1297 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1307:
#
# Lane -1:
# Break between waypoints 2 and 3, distance: 2.59m
# Break between waypoints 3 and 4, distance: 2.59m
# Road 1312 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1318:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.51m
# Break between waypoints 3 and 4, distance: 2.51m
# Break between waypoints 4 and 5, distance: 2.50m
# Break between waypoints 5 and 6, distance: 2.50m
# Found sequence breaks in road 1327:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.54m
# Break between waypoints 3 and 4, distance: 2.53m
# Road 1337 has continuous waypoint sequences in all lanes
# Road 1360 has continuous waypoint sequences in all lanes
# Road 1361 has continuous waypoint sequences in all lanes
# Road 1400 has continuous waypoint sequences in all lanes
# Road 1401 has continuous waypoint sequences in all lanes
# Road 1412 has continuous waypoint sequences in all lanes
# Road 1421 has continuous waypoint sequences in all lanes
# Road 1432 has continuous waypoint sequences in all lanes
# Road 1442 has continuous waypoint sequences in all lanes
# Road 1450 has continuous waypoint sequences in all lanes
# Road 1465 has continuous waypoint sequences in all lanes
# Road 1466 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1479:
#
# Lane -1:
# Break between waypoints 1 and 2, distance: 2.52m
# Break between waypoints 2 and 3, distance: 2.52m
# Break between waypoints 5 and 6, distance: 2.53m
# Road 1488 has continuous waypoint sequences in all lanes
# Road 1497 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1507:
#
# Lane 1:
# Break between waypoints 2 and 3, distance: 2.57m
# Break between waypoints 3 and 4, distance: 2.56m
# Break between waypoints 5 and 6, distance: 2.71m
# Found sequence breaks in road 1522:
#
# Lane -1:
# Break between waypoints 1 and 2, distance: 2.62m
# Break between waypoints 2 and 3, distance: 2.62m
# Break between waypoints 3 and 4, distance: 2.56m
# Road 1531 has continuous waypoint sequences in all lanes
# Road 1539 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1546:
#
# Lane 1:
# Break between waypoints 1 and 2, distance: 2.57m
# Break between waypoints 2 and 3, distance: 2.62m
# Break between waypoints 3 and 4, distance: 2.62m
# Road 1567 has continuous waypoint sequences in all lanes
# Road 1568 has continuous waypoint sequences in all lanes
# Road 1594 has continuous waypoint sequences in all lanes
# Road 1595 has continuous waypoint sequences in all lanes
# Found sequence breaks in road 1601:
#
# Lane 6:
# Break between waypoints 0 and 1, distance: 2.58m
# Break between waypoints 1 and 2, distance: 2.58m
# Break between waypoints 2 and 3, distance: 2.58m
# Break between waypoints 3 and 4, distance: 2.58m
# Break between waypoints 4 and 5, distance: 2.58m
# Break between waypoints 5 and 6, distance: 2.58m
# Break between waypoints 6 and 7, distance: 2.58m
# Break between waypoints 7 and 8, distance: 2.58m
# Break between waypoints 8 and 9, distance: 2.58m
# Break between waypoints 9 and 10, distance: 2.58m
# Break between waypoints 10 and 11, distance: 2.58m
# Break between waypoints 11 and 12, distance: 2.58m
# Break between waypoints 12 and 13, distance: 2.58m
# Break between waypoints 13 and 14, distance: 2.58m
# Break between waypoints 14 and 15, distance: 2.58m
# Break between waypoints 15 and 16, distance: 2.58m
# Break between waypoints 16 and 17, distance: 2.58m
# Break between waypoints 17 and 18, distance: 2.58m
# Break between waypoints 18 and 19, distance: 2.58m
# Break between waypoints 19 and 20, distance: 2.58m
# Road 1602 has continuous waypoint sequences in all lanes

# %% [markdown]
# ## List road lanes

# %%
def get_unique_lane_ids(waypoints, road_id):
    return sorted(list(set(wp.lane_id for wp in waypoints if wp.road_id == road_id)))

road_id = 6
lane_ids = get_unique_lane_ids(waypoints, road_id)  
print(lane_ids) # [-4, -3, -2, -1, 3, 4, 5, 6]

road_id = 38
lane_ids = get_unique_lane_ids(waypoints, road_id)  
lane_ids
# Out:
# [-4, -3, -2, -1, 3, 4, 5, 6]
# [-4, -3, -2, -1, 3, 4, 5, 6]

# %%
eight_lane_roads
# Out:
# [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]

# %% [markdown]
# # Plot inner late of figure of 8 ring road, town 04

# %%
road_ids = [6, 35]
markers = place_markers_on_lane(world, road_ids)

# for road_id in eight_lane_roads:
#     place_markers_on_lane(world, [road_id])
# Out:
# Placed 175 markers on lane -4 across 2 roads

# %%
## Waypoints set at distance > 2.5m
for waypoint in waypoints:
    if waypoint.road_id == 6:
        print(waypoint.id)
        # print(waypoint.s)
# Out:
# 4641250760981045379
# 4592942668712833820
# 11983327098621662466
# 5224660670092596996
# 6982654154847670249
# 6129230666532924672
# 5034693531769484326
# 2827203210415223208
# 18313294055911148380
# 15644884804647786691
# 3383236460981022085
# 7460701396986866395
# 8423436749056312822
# 9516529405160445831
# 7374316201285725625
# 3090671597044257503
# 9387395423480887448
# 16864857345223855
# 11347369723081038233
# 3248915232482796439
# 10806400343159910738
# 11881993350336530155
# 4654049739649610341
# 17483696824142191507
# 2811769558798115716
# 13458593866777907099
# 12933423164516232109
# 10559221071065543683
# 11217352454628465086
# 7135836977279816703
# 8990204711485311697
# 4229121148518471847
# 5644134607749557701
# 6752368382134331394
# 12251833964545368092
# 356858600335447322
# 16762126860177900383
# 10096639739408483614
# 8779535702564972536
# 6065289533055955062
# 604644998855766037
# 5973068758167605170
# 4105289373958060140
# 14865034262452006250
# 3407846882579146319
# 14004514317817939822
# 4103668378455050984
# 3492852901020968294
# 10576358984672155825
# 3957045305942469358
# 7403925809211710768
# 17838788807326729606
# 3093301504159927243
# 6738728460707820082
# 10913117610509574244
# 3238096789532061066
# 14050683428595618361
# 1021802896377092198
# 12039195062785148600
# 3755888448294901774
# 15360923541899420915
# 3280798490661858826
# 16564051007181567708
# 2278863579294085810
# 16545651071243131649
# 3225949398874415774
# 7690972828668634496
# 17524110244802727382
# 12940998674137198267
# 15973276888091980930
# 6834942587718554452
# 6679965813352764026
# 11276292304506337737
# 1000656347952981334
# 12787908455397002952
# 11223279057678158622
# 17563328699930393955
# 13880331105925417754
# 7815639674455183180
# 13224394229742542114
# 17111461512357632145
# 10815841795111175566
# 12593652146134494608
# 13317173821907905254
# 6400877984126824747
# 5519205528106013074
# 3476257105316550084
# 579091828553710826
# 11246331680563308841
# 2899590222081732470
# 17740497696741753768
# 10703346943551783166
# 10805961902096729923
# 18224951256520634618
# 3974497715760280876
# 6941095994996724482
# 12864967477828082669
# 221441560794928346
# 5316842419220831812
# 12321303592479107138
# 9990448003007979815
# 5109340444785566102
# 10172487852465983248
# 5788947017899226686
# 11702860305944070129
# 16899334194479940142
# 801369052642254064
# 9142369452109606470
# 18285046751136778379
# 4872749565697905906
# 3995344496080453924
# 17438252085927411786
# 10432172256905962677
# 3078177337155768722
# 2803103804336988812
# 17665881966350068618
# 5450960468618623087
# 9912427563110958478
# 4417530077840847112
# 11090065165234676614
# 2432536914972006265
# 5950439773509623206
# 3366590307640268408
# 16296817180436517582
# 9763502566385442739
# 11215068040235247818
# 4084307421940969884
# 12904297672977657202
# 11938797503871107965
# 16906631647560888778
# 3567097384881422676
# 17343846926918699858
# 5898566184885402007
# 5755205539435806374
# 15816455167758759808
# 12112349105544024238
# 12566231313047385665
# 5691199864520064478
# 6439177872430626112
# 4999201875973485206
# 11974123335616172923
# 10962484439389777730
# 9116201476668373012
# 8304105703978536250
# 4359908673935565381
# 4741396042720162946
# 2219683051256441500
# 4204800441485756570
# 13306709698795502303
# 11262432126986658462
# 5010360321219326840
# 17669242420268797430
# 1890474392022859529
# 14161635859296103062
# 10651445784935549320
# 9144933806922286558
# 15848472007325677603
# 4376933551420704218
# 10409091712357435916
# 3463427461515057122
# 7321120737264890317
# 10729903591443730426
# 13315374822573057060
# 5362350370104913186
# 16921523225374773767
# 8823354608762205814
# 16940103057385513968
# 5981696022773250846
# 5130588589298416215
# 3636891176505257200
# 9557825557128368686
# 13624533870196746712
# 17442536375875686077
# 16052579407108047660
# 2015934516716820218
# 14428257235825792980
# 10410043317833181093
# 5821850389280232610
# 1020085999720783740
# 10023826485530011770
# 7775925013729073855
# 14754481744807200894
# 14142192099616162648
# 4452219569286382550
# 4801190377008588379
# 2209240067057365572
# 4666976938699677914
# 3538191183467517916
# 10483538440324767265
# 18083434714978799240
# 9344199428774197518
# 2169468191887231456
# 1683766421169712745
# 16487978806747870390
# 5668182746055103336
# 5580744049203100606
# 2796649102097252867
# 9566016993882237882
# 16937200216277512172
# 2410946518181416386
# 8295661718815217951
# 12311681629360428968
# 2406463569960909686
# 5159193077278539552
# 17552538208279279621
# 1120915618321071908
# 14119276021068387058
# 15596729913685552412
# 6787589490558558509
# 17419785305167272474
# 17265874106529093892
# 3133756159601713922
# 6212737841118075879
# 5209181102949801046
# 6898850186770074064
# 17255247412404629758
# 15317220772266309091
# 7540018227375902140
# 13678280812259973730
# 12009611894074129508
# 2548123129160086857
# 12389945111653048928
# 13961540121744533894
# 16533706562529441544
# 7816116041520598321
# 1369548590166460270
# 10424444518519363504
# 17526371726549821702
# 14695482779914060619
# 9181462431594024882
# 11044313920777206756
# 12082148138643323658
# 5907019248576455143
# 9386918507332045280
# 7395869622416378430
# 16752480819941084392
# 8892122108871108397
# 13643940210794078268
# 7649289220231511914
# 11027723423031571012
# 14137674073020956661
# 1019835282029915346
# 6224198917135413836
# 1345118080928125002
# 3872384976555154735
# 9683170861581025358
# 16702600240792802760
# 12858366089568427590
# 3541367734338098347
# 8420578687583901172
# 17203150574134880554
# 17574928149027681324
# 14672251935615631633
# 5454695595941581016
# 8500237508271636478
# 11083447514615934672

# %% [markdown]
# ## world object methods

# %%
for method in dir(world):
    print(method)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# apply_color_texture_to_object
# apply_color_texture_to_objects
# apply_float_color_texture_to_object
# apply_float_color_texture_to_objects
# apply_settings
# apply_textures_to_object
# apply_textures_to_objects
# cast_ray
# debug
# enable_environment_objects
# freeze_all_traffic_lights
# get_actor
# get_actors
# get_blueprint_library
# get_environment_objects
# get_level_bbs
# get_lightmanager
# get_map
# get_names_of_all_objects
# get_random_location_from_navigation
# get_settings
# get_snapshot
# get_spectator
# get_traffic_light
# get_traffic_light_from_opendrive_id
# get_traffic_lights_from_waypoint
# get_traffic_lights_in_junction
# get_traffic_sign
# get_vehicles_light_states
# get_weather
# ground_projection
# id
# load_map_layer
# on_tick
# project_point
# remove_on_tick
# reset_all_traffic_lights
# set_pedestrians_cross_factor
# set_pedestrians_seed
# set_weather
# spawn_actor
# tick
# try_spawn_actor
# unload_map_layer
# wait_for_tick

# %% [markdown]
# ## Figure of 8 waypoings

# %%
def validate_figure8_waypoints(world):
    """Get and validate waypoints for figure-8 track."""
    road_sequence = [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    target_lane_id = -4
    waypoint_spacing = 2.0
    
    carla_map = world.get_map()
    waypoints = carla_map.generate_waypoints(waypoint_spacing)
    
    # Filter and sort waypoints
    road_waypoints = {}
    for road_id in road_sequence:
        road_waypoints[road_id] = [wp for wp in waypoints 
                                 if wp.road_id == road_id and wp.lane_id == target_lane_id]
        road_waypoints[road_id].sort(key=lambda x: x.s)
        
        print(f"Road {road_id}: {len(road_waypoints[road_id])} waypoints")
        
        # Validate waypoint spacing
        if len(road_waypoints[road_id]) > 1:
            first = road_waypoints[road_id][0].transform.location
            last = road_waypoints[road_id][-1].transform.location
            distance = ((last.x - first.x)**2 + 
                       (last.y - first.y)**2 + 
                       (last.z - first.z)**2)**0.5
            print(f"Road length: {distance:.1f}m")
    
    return road_waypoints

road_waypoints = validate_figure8_waypoints(world)
road_waypoints
# Out:
# Road 6: 32 waypoints
# Road length: 62.1m
# Road 35: 143 waypoints
# Road length: 225.2m
# Road 36: 41 waypoints
# Road length: 80.0m
# Road 37: 21 waypoints
# Road length: 36.6m
# Road 38: 123 waypoints
# Road length: 233.5m
# Road 39: 67 waypoints
# Road length: 132.0m
# Road 40: 119 waypoints
# Road length: 236.3m
# Road 41: 105 waypoints
# Road length: 198.2m
# Road 42: 17 waypoints
# Road length: 32.0m
# Road 43: 17 waypoints
# Road length: 32.2m
# Road 45: 293 waypoints
# Road length: 499.0m
# Road 46: 70 waypoints
# Road length: 142.1m
# Road 47: 57 waypoints
# Road length: 112.0m
# Road 48: 32 waypoints
# Road length: 62.0m
# Road 49: 20 waypoints
# Road length: 37.8m
# Road 50: 89 waypoints
# Road length: 150.8m
# {6: [<carla.libcarla.Waypoint at 0x7f574718e5b0>,
#   <carla.libcarla.Waypoint at 0x7f574718e450>,
#   <carla.libcarla.Waypoint at 0x7f574718ead8>,
#   <carla.libcarla.Waypoint at 0x7f574718f190>,
#   <carla.libcarla.Waypoint at 0x7f574718fb88>,
#   <carla.libcarla.Waypoint at 0x7f574718f1e8>,
#   <carla.libcarla.Waypoint at 0x7f574718f768>,
#   <carla.libcarla.Waypoint at 0x7f574718fce8>,
#   <carla.libcarla.Waypoint at 0x7f57471954a8>,
#   <carla.libcarla.Waypoint at 0x7f5747195c38>,
#   <carla.libcarla.Waypoint at 0x7f5747195348>,
#   <carla.libcarla.Waypoint at 0x7f5747195768>,
#   <carla.libcarla.Waypoint at 0x7f5747195be0>,
#   <carla.libcarla.Waypoint at 0x7f5747196710>,
#   <carla.libcarla.Waypoint at 0x7f5747196fa8>,
#   <carla.libcarla.Waypoint at 0x7f5747196500>,
#   <carla.libcarla.Waypoint at 0x7f5747196978>,
#   <carla.libcarla.Waypoint at 0x7f5747196df0>,
#   <carla.libcarla.Waypoint at 0x7f5747197558>,
#   <carla.libcarla.Waypoint at 0x7f5747197240>,
#   <carla.libcarla.Waypoint at 0x7f5747197768>,
#   <carla.libcarla.Waypoint at 0x7f5747197be0>,
#   <carla.libcarla.Waypoint at 0x7f5747198450>,
#   <carla.libcarla.Waypoint at 0x7f5747198240>,
#   <carla.libcarla.Waypoint at 0x7f5747198710>,
#   <carla.libcarla.Waypoint at 0x7f5747198ad8>,
#   <carla.libcarla.Waypoint at 0x7f5747198ef8>,
#   <carla.libcarla.Waypoint at 0x7f574719d1e8>,
#   <carla.libcarla.Waypoint at 0x7f574719d558>,
#   <carla.libcarla.Waypoint at 0x7f574719d870>,
#   <carla.libcarla.Waypoint at 0x7f574719db88>,
#   <carla.libcarla.Waypoint at 0x7f574719def8>],
#  35: [<carla.libcarla.Waypoint at 0x7f57471b52f0>,
#   <carla.libcarla.Waypoint at 0x7f57471b5920>,
#   <carla.libcarla.Waypoint at 0x7f57471b5e48>,
#   <carla.libcarla.Waypoint at 0x7f57471b63f8>,
#   <carla.libcarla.Waypoint at 0x7f57471b6138>,
#   <carla.libcarla.Waypoint at 0x7f57471b6608>,
#   <carla.libcarla.Waypoint at 0x7f57471b6b88>,
#   <carla.libcarla.Waypoint at 0x7f57471b7298>,
#   <carla.libcarla.Waypoint at 0x7f57471b7348>,
#   <carla.libcarla.Waypoint at 0x7f57471b7450>,
#   <carla.libcarla.Waypoint at 0x7f57471b7920>,
#   <carla.libcarla.Waypoint at 0x7f57471b7ea0>,
#   <carla.libcarla.Waypoint at 0x7f57471b8298>,
#   <carla.libcarla.Waypoint at 0x7f57471b80e0>,
#   <carla.libcarla.Waypoint at 0x7f57471b85b0>,
#   <carla.libcarla.Waypoint at 0x7f57471b8be0>,
#   <carla.libcarla.Waypoint at 0x7f57471b9608>,
#   <carla.libcarla.Waypoint at 0x7f57471b9a28>,
#   <carla.libcarla.Waypoint at 0x7f57471b93f8>,
#   <carla.libcarla.Waypoint at 0x7f57471b98c8>,
#   <carla.libcarla.Waypoint at 0x7f57471b9ea0>,
#   <carla.libcarla.Waypoint at 0x7f57471ba1e8>,
#   <carla.libcarla.Waypoint at 0x7f57471ba240>,
#   <carla.libcarla.Waypoint at 0x7f57471ba768>,
#   <carla.libcarla.Waypoint at 0x7f57471bac38>,
#   <carla.libcarla.Waypoint at 0x7f57471bb9d0>,
#   <carla.libcarla.Waypoint at 0x7f57471bbb88>,
#   <carla.libcarla.Waypoint at 0x7f57471bb450>,
#   <carla.libcarla.Waypoint at 0x7f57471bba28>,
#   <carla.libcarla.Waypoint at 0x7f57471bbf50>,
#   <carla.libcarla.Waypoint at 0x7f57471bcb88>,
#   <carla.libcarla.Waypoint at 0x7f57471bc1e8>,
#   <carla.libcarla.Waypoint at 0x7f57471bc710>,
#   <carla.libcarla.Waypoint at 0x7f57471bcbe0>,
#   <carla.libcarla.Waypoint at 0x7f57471bd818>,
#   <carla.libcarla.Waypoint at 0x7f57471bda28>,
#   <carla.libcarla.Waypoint at 0x7f57471bd500>,
#   <carla.libcarla.Waypoint at 0x7f57471bd9d0>,
#   <carla.libcarla.Waypoint at 0x7f57471bdef8>,
#   <carla.libcarla.Waypoint at 0x7f57471beea0>,
#   <carla.libcarla.Waypoint at 0x7f57471be1e8>,
#   <carla.libcarla.Waypoint at 0x7f57471be710>,
#   <carla.libcarla.Waypoint at 0x7f57471bece8>,
#   <carla.libcarla.Waypoint at 0x7f57471bfad8>,
#   <carla.libcarla.Waypoint at 0x7f57471bfb88>,
#   <carla.libcarla.Waypoint at 0x7f57471bf4a8>,
#   <carla.libcarla.Waypoint at 0x7f57471bf978>,
#   <carla.libcarla.Waypoint at 0x7f57471bfea0>,
#   <carla.libcarla.Waypoint at 0x7f57471c0240>,
#   <carla.libcarla.Waypoint at 0x7f57471c00e0>,
#   <carla.libcarla.Waypoint at 0x7f57471c0768>,
#   <carla.libcarla.Waypoint at 0x7f57471c0be0>,
#   <carla.libcarla.Waypoint at 0x7f57471c15b0>,
#   <carla.libcarla.Waypoint at 0x7f57471c1a28>,
#   <carla.libcarla.Waypoint at 0x7f57471c13f8>,
#   <carla.libcarla.Waypoint at 0x7f57471c1920>,
#   <carla.libcarla.Waypoint at 0x7f57471c1ea0>,
#   <carla.libcarla.Waypoint at 0x7f57471c2500>,
#   <carla.libcarla.Waypoint at 0x7f57471c2240>,
#   <carla.libcarla.Waypoint at 0x7f57471c2768>,
#   <carla.libcarla.Waypoint at 0x7f57471c2ce8>,
#   <carla.libcarla.Waypoint at 0x7f57471c3870>,
#   <carla.libcarla.Waypoint at 0x7f57471c38c8>,
#   <carla.libcarla.Waypoint at 0x7f57471c33f8>,
#   <carla.libcarla.Waypoint at 0x7f57471c3a28>,
#   <carla.libcarla.Waypoint at 0x7f57471c3ef8>,
#   <carla.libcarla.Waypoint at 0x7f57471c4ea0>,
#   <carla.libcarla.Waypoint at 0x7f57471c41e8>,
#   <carla.libcarla.Waypoint at 0x7f57471c4710>,
#   <carla.libcarla.Waypoint at 0x7f57471c4ce8>,
#   <carla.libcarla.Waypoint at 0x7f57471c57c0>,
#   <carla.libcarla.Waypoint at 0x7f57471c5fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471c5500>,
#   <carla.libcarla.Waypoint at 0x7f57471c59d0>,
#   <carla.libcarla.Waypoint at 0x7f57471c5ef8>,
#   <carla.libcarla.Waypoint at 0x7f57471c6a80>,
#   <carla.libcarla.Waypoint at 0x7f57471c6190>,
#   <carla.libcarla.Waypoint at 0x7f57471c66b8>,
#   <carla.libcarla.Waypoint at 0x7f57471c6ce8>,
#   <carla.libcarla.Waypoint at 0x7f57471c7ef8>,
#   <carla.libcarla.Waypoint at 0x7f57471c7e48>,
#   <carla.libcarla.Waypoint at 0x7f57471c74a8>,
#   <carla.libcarla.Waypoint at 0x7f57471c79d0>,
#   <carla.libcarla.Waypoint at 0x7f57471c7fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471c89d0>,
#   <carla.libcarla.Waypoint at 0x7f57471c82f0>,
#   <carla.libcarla.Waypoint at 0x7f57471c87c0>,
#   <carla.libcarla.Waypoint at 0x7f57471c8ce8>,
#   <carla.libcarla.Waypoint at 0x7f57471c9df0>,
#   <carla.libcarla.Waypoint at 0x7f57471c9fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471c9450>,
#   <carla.libcarla.Waypoint at 0x7f57471c9a80>,
#   <carla.libcarla.Waypoint at 0x7f57471cac90>,
#   <carla.libcarla.Waypoint at 0x7f57471ca298>,
#   <carla.libcarla.Waypoint at 0x7f57471ca348>,
#   <carla.libcarla.Waypoint at 0x7f57471ca7c0>,
#   <carla.libcarla.Waypoint at 0x7f57471cad40>,
#   <carla.libcarla.Waypoint at 0x7f574714bce8>,
#   <carla.libcarla.Waypoint at 0x7f574714be48>,
#   <carla.libcarla.Waypoint at 0x7f574714b660>,
#   <carla.libcarla.Waypoint at 0x7f574714bad8>,
#   <carla.libcarla.Waypoint at 0x7f574714c660>,
#   <carla.libcarla.Waypoint at 0x7f574714c138>,
#   <carla.libcarla.Waypoint at 0x7f574714c298>,
#   <carla.libcarla.Waypoint at 0x7f574714c7c0>,
#   <carla.libcarla.Waypoint at 0x7f574714cd40>,
#   <carla.libcarla.Waypoint at 0x7f574714da28>,
#   <carla.libcarla.Waypoint at 0x7f574714d088>,
#   <carla.libcarla.Waypoint at 0x7f574714d5b0>,
#   <carla.libcarla.Waypoint at 0x7f574714dad8>,
#   <carla.libcarla.Waypoint at 0x7f574714e298>,
#   <carla.libcarla.Waypoint at 0x7f574714ece8>,
#   <carla.libcarla.Waypoint at 0x7f574714e348>,
#   <carla.libcarla.Waypoint at 0x7f574714e8c8>,
#   <carla.libcarla.Waypoint at 0x7f574714edf0>,
#   <carla.libcarla.Waypoint at 0x7f574714f348>,
#   <carla.libcarla.Waypoint at 0x7f574714f030>,
#   <carla.libcarla.Waypoint at 0x7f574714f660>,
#   <carla.libcarla.Waypoint at 0x7f574714fad8>,
#   <carla.libcarla.Waypoint at 0x7f5747150920>,
#   <carla.libcarla.Waypoint at 0x7f57471503f8>,
#   <carla.libcarla.Waypoint at 0x7f57471503a0>,
#   <carla.libcarla.Waypoint at 0x7f5747150870>,
#   <carla.libcarla.Waypoint at 0x7f5747150ce8>,
#   <carla.libcarla.Waypoint at 0x7f57471544a8>,
#   <carla.libcarla.Waypoint at 0x7f5747154a80>,
#   <carla.libcarla.Waypoint at 0x7f5747154348>,
#   <carla.libcarla.Waypoint at 0x7f5747154768>,
#   <carla.libcarla.Waypoint at 0x7f5747154c38>,
#   <carla.libcarla.Waypoint at 0x7f57471553f8>,
#   <carla.libcarla.Waypoint at 0x7f57471552f0>,
#   <carla.libcarla.Waypoint at 0x7f5747155240>,
#   <carla.libcarla.Waypoint at 0x7f5747155710>,
#   <carla.libcarla.Waypoint at 0x7f5747155be0>,
#   <carla.libcarla.Waypoint at 0x7f5747156088>,
#   <carla.libcarla.Waypoint at 0x7f5747156660>,
#   <carla.libcarla.Waypoint at 0x7f5747156298>,
#   <carla.libcarla.Waypoint at 0x7f57471567c0>,
#   <carla.libcarla.Waypoint at 0x7f5747156b88>,
#   <carla.libcarla.Waypoint at 0x7f5747157190>,
#   <carla.libcarla.Waypoint at 0x7f57471579d0>,
#   <carla.libcarla.Waypoint at 0x7f5747157298>,
#   <carla.libcarla.Waypoint at 0x7f57471576b8>],
#  36: [<carla.libcarla.Waypoint at 0x7f5747157ad8>,
#   <carla.libcarla.Waypoint at 0x7f5747157ea0>,
#   <carla.libcarla.Waypoint at 0x7f5747158ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747158138>,
#   <carla.libcarla.Waypoint at 0x7f5747158660>,
#   <carla.libcarla.Waypoint at 0x7f5747158ad8>,
#   <carla.libcarla.Waypoint at 0x7f5747158ef8>,
#   <carla.libcarla.Waypoint at 0x7f57471595b0>,
#   <carla.libcarla.Waypoint at 0x7f5747159240>,
#   <carla.libcarla.Waypoint at 0x7f57471596b8>,
#   <carla.libcarla.Waypoint at 0x7f5747159a80>,
#   <carla.libcarla.Waypoint at 0x7f5747159ea0>,
#   <carla.libcarla.Waypoint at 0x7f574715a138>,
#   <carla.libcarla.Waypoint at 0x7f574715abe0>,
#   <carla.libcarla.Waypoint at 0x7f574715a3f8>,
#   <carla.libcarla.Waypoint at 0x7f574715a870>,
#   <carla.libcarla.Waypoint at 0x7f574715ad40>,
#   <carla.libcarla.Waypoint at 0x7f574715bdf0>,
#   <carla.libcarla.Waypoint at 0x7f574715b9d0>,
#   <carla.libcarla.Waypoint at 0x7f574715b348>,
#   <carla.libcarla.Waypoint at 0x7f574715b818>,
#   <carla.libcarla.Waypoint at 0x7f574715bce8>,
#   <carla.libcarla.Waypoint at 0x7f574715cad8>,
#   <carla.libcarla.Waypoint at 0x7f574715c0e0>,
#   <carla.libcarla.Waypoint at 0x7f574715c4a8>,
#   <carla.libcarla.Waypoint at 0x7f574715c920>,
#   <carla.libcarla.Waypoint at 0x7f574715cce8>,
#   <carla.libcarla.Waypoint at 0x7f574715d6b8>,
#   <carla.libcarla.Waypoint at 0x7f574715d088>,
#   <carla.libcarla.Waypoint at 0x7f574715d450>,
#   <carla.libcarla.Waypoint at 0x7f574715d818>,
#   <carla.libcarla.Waypoint at 0x7f574715dc90>,
#   <carla.libcarla.Waypoint at 0x7f574715e298>,
#   <carla.libcarla.Waypoint at 0x7f574715e138>,
#   <carla.libcarla.Waypoint at 0x7f574715e500>,
#   <carla.libcarla.Waypoint at 0x7f574715e8c8>,
#   <carla.libcarla.Waypoint at 0x7f574715ec90>,
#   <carla.libcarla.Waypoint at 0x7f574715f190>,
#   <carla.libcarla.Waypoint at 0x7f574715f0e0>,
#   <carla.libcarla.Waypoint at 0x7f574715f4a8>,
#   <carla.libcarla.Waypoint at 0x7f574715f818>],
#  37: [<carla.libcarla.Waypoint at 0x7f5747161030>,
#   <carla.libcarla.Waypoint at 0x7f5747161138>,
#   <carla.libcarla.Waypoint at 0x7f5747161500>,
#   <carla.libcarla.Waypoint at 0x7f57471618c8>,
#   <carla.libcarla.Waypoint at 0x7f5747161c90>,
#   <carla.libcarla.Waypoint at 0x7f5747162348>,
#   <carla.libcarla.Waypoint at 0x7f5747162be0>,
#   <carla.libcarla.Waypoint at 0x7f57471623f8>,
#   <carla.libcarla.Waypoint at 0x7f5747162818>,
#   <carla.libcarla.Waypoint at 0x7f5747162c38>,
#   <carla.libcarla.Waypoint at 0x7f5747163c38>,
#   <carla.libcarla.Waypoint at 0x7f5747163710>,
#   <carla.libcarla.Waypoint at 0x7f5747163298>,
#   <carla.libcarla.Waypoint at 0x7f57471636b8>,
#   <carla.libcarla.Waypoint at 0x7f5747163b30>,
#   <carla.libcarla.Waypoint at 0x7f5747163fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471649d0>,
#   <carla.libcarla.Waypoint at 0x7f5747164190>,
#   <carla.libcarla.Waypoint at 0x7f5747164608>,
#   <carla.libcarla.Waypoint at 0x7f5747164b30>,
#   <carla.libcarla.Waypoint at 0x7f5747164f50>],
#  38: [<carla.libcarla.Waypoint at 0x7f574716a298>,
#   <carla.libcarla.Waypoint at 0x7f574716a768>,
#   <carla.libcarla.Waypoint at 0x7f574716abe0>,
#   <carla.libcarla.Waypoint at 0x7f574716bad8>,
#   <carla.libcarla.Waypoint at 0x7f574716be48>,
#   <carla.libcarla.Waypoint at 0x7f574716b190>,
#   <carla.libcarla.Waypoint at 0x7f574716b660>,
#   <carla.libcarla.Waypoint at 0x7f574716bb30>,
#   <carla.libcarla.Waypoint at 0x7f574716bfa8>,
#   <carla.libcarla.Waypoint at 0x7f574716ca28>,
#   <carla.libcarla.Waypoint at 0x7f574716c138>,
#   <carla.libcarla.Waypoint at 0x7f574716c558>,
#   <carla.libcarla.Waypoint at 0x7f574716ca80>,
#   <carla.libcarla.Waypoint at 0x7f574716cef8>,
#   <carla.libcarla.Waypoint at 0x7f574716d608>,
#   <carla.libcarla.Waypoint at 0x7f574716d088>,
#   <carla.libcarla.Waypoint at 0x7f574716d500>,
#   <carla.libcarla.Waypoint at 0x7f574716da28>,
#   <carla.libcarla.Waypoint at 0x7f574716de48>,
#   <carla.libcarla.Waypoint at 0x7f574716efa8>,
#   <carla.libcarla.Waypoint at 0x7f574716ef50>,
#   <carla.libcarla.Waypoint at 0x7f574716e3f8>,
#   <carla.libcarla.Waypoint at 0x7f574716e870>,
#   <carla.libcarla.Waypoint at 0x7f574716ed98>,
#   <carla.libcarla.Waypoint at 0x7f574716ff50>,
#   <carla.libcarla.Waypoint at 0x7f574716fd40>,
#   <carla.libcarla.Waypoint at 0x7f574716f3f8>,
#   <carla.libcarla.Waypoint at 0x7f574716f870>,
#   <carla.libcarla.Waypoint at 0x7f574716fd98>,
#   <carla.libcarla.Waypoint at 0x7f5747170ad8>,
#   <carla.libcarla.Waypoint at 0x7f57471705b0>,
#   <carla.libcarla.Waypoint at 0x7f57471703f8>,
#   <carla.libcarla.Waypoint at 0x7f5747170818>,
#   <carla.libcarla.Waypoint at 0x7f5747170ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747171608>,
#   <carla.libcarla.Waypoint at 0x7f5747171b88>,
#   <carla.libcarla.Waypoint at 0x7f5747171348>,
#   <carla.libcarla.Waypoint at 0x7f5747171768>,
#   <carla.libcarla.Waypoint at 0x7f5747171c38>,
#   <carla.libcarla.Waypoint at 0x7f5747172190>,
#   <carla.libcarla.Waypoint at 0x7f5747172138>,
#   <carla.libcarla.Waypoint at 0x7f5747172240>,
#   <carla.libcarla.Waypoint at 0x7f5747172660>,
#   <carla.libcarla.Waypoint at 0x7f5747172ad8>,
#   <carla.libcarla.Waypoint at 0x7f5747172ea0>,
#   <carla.libcarla.Waypoint at 0x7f5747174df0>,
#   <carla.libcarla.Waypoint at 0x7f5747174d98>,
#   <carla.libcarla.Waypoint at 0x7f57471743a0>,
#   <carla.libcarla.Waypoint at 0x7f5747174768>,
#   <carla.libcarla.Waypoint at 0x7f5747174c38>,
#   <carla.libcarla.Waypoint at 0x7f5747175138>,
#   <carla.libcarla.Waypoint at 0x7f5747175348>,
#   <carla.libcarla.Waypoint at 0x7f5747175240>,
#   <carla.libcarla.Waypoint at 0x7f57471756b8>,
#   <carla.libcarla.Waypoint at 0x7f5747175be0>,
#   <carla.libcarla.Waypoint at 0x7f5747176a80>,
#   <carla.libcarla.Waypoint at 0x7f5747176e48>,
#   <carla.libcarla.Waypoint at 0x7f57471761e8>,
#   <carla.libcarla.Waypoint at 0x7f5747176608>,
#   <carla.libcarla.Waypoint at 0x7f5747176b30>,
#   <carla.libcarla.Waypoint at 0x7f5747176fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471779d0>,
#   <carla.libcarla.Waypoint at 0x7f57471770e0>,
#   <carla.libcarla.Waypoint at 0x7f57471775b0>,
#   <carla.libcarla.Waypoint at 0x7f5747177a80>,
#   <carla.libcarla.Waypoint at 0x7f5747177ef8>,
#   <carla.libcarla.Waypoint at 0x7f574717e608>,
#   <carla.libcarla.Waypoint at 0x7f574717e088>,
#   <carla.libcarla.Waypoint at 0x7f574717e558>,
#   <carla.libcarla.Waypoint at 0x7f574717ea28>,
#   <carla.libcarla.Waypoint at 0x7f574717eea0>,
#   <carla.libcarla.Waypoint at 0x7f574717ff50>,
#   <carla.libcarla.Waypoint at 0x7f574717ffa8>,
#   <carla.libcarla.Waypoint at 0x7f574717f3f8>,
#   <carla.libcarla.Waypoint at 0x7f574717f8c8>,
#   <carla.libcarla.Waypoint at 0x7f574717fd98>,
#   <carla.libcarla.Waypoint at 0x7f5747180f50>,
#   <carla.libcarla.Waypoint at 0x7f5747180d98>,
#   <carla.libcarla.Waypoint at 0x7f57471803f8>,
#   <carla.libcarla.Waypoint at 0x7f57471808c8>,
#   <carla.libcarla.Waypoint at 0x7f5747180ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747181a28>,
#   <carla.libcarla.Waypoint at 0x7f5747181608>,
#   <carla.libcarla.Waypoint at 0x7f57471812f0>,
#   <carla.libcarla.Waypoint at 0x7f5747181818>,
#   <carla.libcarla.Waypoint at 0x7f5747181c90>,
#   <carla.libcarla.Waypoint at 0x7f57471821e8>,
#   <carla.libcarla.Waypoint at 0x7f57471826b8>,
#   <carla.libcarla.Waypoint at 0x7f5747182348>,
#   <carla.libcarla.Waypoint at 0x7f5747182818>,
#   <carla.libcarla.Waypoint at 0x7f5747182be0>,
#   <carla.libcarla.Waypoint at 0x7f5747183fa8>,
#   <carla.libcarla.Waypoint at 0x7f57471831e8>,
#   <carla.libcarla.Waypoint at 0x7f5747183240>,
#   <carla.libcarla.Waypoint at 0x7f57471836b8>,
#   <carla.libcarla.Waypoint at 0x7f5747183b88>,
#   <carla.libcarla.Waypoint at 0x7f5747184818>,
#   <carla.libcarla.Waypoint at 0x7f5747184d98>,
#   <carla.libcarla.Waypoint at 0x7f57471842f0>,
#   <carla.libcarla.Waypoint at 0x7f57471847c0>,
#   <carla.libcarla.Waypoint at 0x7f5747184be0>,
#   <carla.libcarla.Waypoint at 0x7f575003d088>,
#   <carla.libcarla.Waypoint at 0x7f575003d5b0>,
#   <carla.libcarla.Waypoint at 0x7f575003d0e0>,
#   <carla.libcarla.Waypoint at 0x7f575003dea0>,
#   <carla.libcarla.Waypoint at 0x7f57471db608>,
#   <carla.libcarla.Waypoint at 0x7f57501232f0>,
#   <carla.libcarla.Waypoint at 0x7f5750123190>,
#   <carla.libcarla.Waypoint at 0x7f57501235b0>,
#   <carla.libcarla.Waypoint at 0x7f57501239d0>,
#   <carla.libcarla.Waypoint at 0x7f5750123df0>,
#   <carla.libcarla.Waypoint at 0x7f575011ddf0>,
#   <carla.libcarla.Waypoint at 0x7f575011d190>,
#   <carla.libcarla.Waypoint at 0x7f575011d558>,
#   <carla.libcarla.Waypoint at 0x7f575011d9d0>,
#   <carla.libcarla.Waypoint at 0x7f575011dd98>,
#   <carla.libcarla.Waypoint at 0x7f5750122df0>,
#   <carla.libcarla.Waypoint at 0x7f5750122190>,
#   <carla.libcarla.Waypoint at 0x7f5750122558>,
#   <carla.libcarla.Waypoint at 0x7f57501229d0>,
#   <carla.libcarla.Waypoint at 0x7f5750122d98>,
#   <carla.libcarla.Waypoint at 0x7f5747194df0>,
#   <carla.libcarla.Waypoint at 0x7f5747194138>],
#  39: [<carla.libcarla.Waypoint at 0x7f5747194558>,
#   <carla.libcarla.Waypoint at 0x7f5747194978>,
#   <carla.libcarla.Waypoint at 0x7f5747194d98>,
#   <carla.libcarla.Waypoint at 0x7f5747199df0>,
#   <carla.libcarla.Waypoint at 0x7f5747199138>,
#   <carla.libcarla.Waypoint at 0x7f5747199500>,
#   <carla.libcarla.Waypoint at 0x7f5747199978>,
#   <carla.libcarla.Waypoint at 0x7f5747199d40>,
#   <carla.libcarla.Waypoint at 0x7f574719aa28>,
#   <carla.libcarla.Waypoint at 0x7f574719a138>,
#   <carla.libcarla.Waypoint at 0x7f574719a500>,
#   <carla.libcarla.Waypoint at 0x7f574719a978>,
#   <carla.libcarla.Waypoint at 0x7f574719ad40>,
#   <carla.libcarla.Waypoint at 0x7f574719ba28>,
#   <carla.libcarla.Waypoint at 0x7f574719b0e0>,
#   <carla.libcarla.Waypoint at 0x7f574719b500>,
#   <carla.libcarla.Waypoint at 0x7f574719b920>,
#   <carla.libcarla.Waypoint at 0x7f574719bd40>,
#   <carla.libcarla.Waypoint at 0x7f574719c9d0>,
#   <carla.libcarla.Waypoint at 0x7f574719c0e0>,
#   <carla.libcarla.Waypoint at 0x7f574719c500>,
#   <carla.libcarla.Waypoint at 0x7f574719c920>,
#   <carla.libcarla.Waypoint at 0x7f574719cd40>,
#   <carla.libcarla.Waypoint at 0x7f57446429d0>,
#   <carla.libcarla.Waypoint at 0x7f5744642190>,
#   <carla.libcarla.Waypoint at 0x7f5744642500>,
#   <carla.libcarla.Waypoint at 0x7f5744642920>,
#   <carla.libcarla.Waypoint at 0x7f5744642ce8>,
#   <carla.libcarla.Waypoint at 0x7f5744641660>,
#   <carla.libcarla.Waypoint at 0x7f57446410e0>,
#   <carla.libcarla.Waypoint at 0x7f5744641500>,
#   <carla.libcarla.Waypoint at 0x7f5744641920>,
#   <carla.libcarla.Waypoint at 0x7f5744641ce8>,
#   <carla.libcarla.Waypoint at 0x7f57446347c0>,
#   <carla.libcarla.Waypoint at 0x7f57446341e8>,
#   <carla.libcarla.Waypoint at 0x7f5744634558>,
#   <carla.libcarla.Waypoint at 0x7f57446348c8>,
#   <carla.libcarla.Waypoint at 0x7f5744634d40>,
#   <carla.libcarla.Waypoint at 0x7f57446435b0>,
#   <carla.libcarla.Waypoint at 0x7f5744643088>,
#   <carla.libcarla.Waypoint at 0x7f5744643500>,
#   <carla.libcarla.Waypoint at 0x7f57446438c8>,
#   <carla.libcarla.Waypoint at 0x7f5744643d40>,
#   <carla.libcarla.Waypoint at 0x7f574463b5b0>,
#   <carla.libcarla.Waypoint at 0x7f574463b088>,
#   <carla.libcarla.Waypoint at 0x7f574463b4a8>,
#   <carla.libcarla.Waypoint at 0x7f574463b8c8>,
#   <carla.libcarla.Waypoint at 0x7f574463bce8>,
#   <carla.libcarla.Waypoint at 0x7f57446401e8>,
#   <carla.libcarla.Waypoint at 0x7f5744640030>,
#   <carla.libcarla.Waypoint at 0x7f57446404a8>,
#   <carla.libcarla.Waypoint at 0x7f5744640870>,
#   <carla.libcarla.Waypoint at 0x7f5744640ce8>,
#   <carla.libcarla.Waypoint at 0x7f574463f1e8>,
#   <carla.libcarla.Waypoint at 0x7f574463f030>,
#   <carla.libcarla.Waypoint at 0x7f574463f4a8>,
#   <carla.libcarla.Waypoint at 0x7f574463f870>,
#   <carla.libcarla.Waypoint at 0x7f574463fce8>,
#   <carla.libcarla.Waypoint at 0x7f5744636190>,
#   <carla.libcarla.Waypoint at 0x7f5744636030>,
#   <carla.libcarla.Waypoint at 0x7f5744636450>,
#   <carla.libcarla.Waypoint at 0x7f5744636870>,
#   <carla.libcarla.Waypoint at 0x7f5744636c90>,
#   <carla.libcarla.Waypoint at 0x7f574463c190>,
#   <carla.libcarla.Waypoint at 0x7f574463cd40>,
#   <carla.libcarla.Waypoint at 0x7f574463c3a0>,
#   <carla.libcarla.Waypoint at 0x7f574463c7c0>],
#  40: [<carla.libcarla.Waypoint at 0x7f5747151870>,
#   <carla.libcarla.Waypoint at 0x7f5747151030>,
#   <carla.libcarla.Waypoint at 0x7f57471514a8>,
#   <carla.libcarla.Waypoint at 0x7f5747151920>,
#   <carla.libcarla.Waypoint at 0x7f5747151ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747152870>,
#   <carla.libcarla.Waypoint at 0x7f5747152030>,
#   <carla.libcarla.Waypoint at 0x7f57471524a8>,
#   <carla.libcarla.Waypoint at 0x7f57471528c8>,
#   <carla.libcarla.Waypoint at 0x7f5747152ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747153870>,
#   <carla.libcarla.Waypoint at 0x7f5747153030>,
#   <carla.libcarla.Waypoint at 0x7f5747153450>,
#   <carla.libcarla.Waypoint at 0x7f57471538c8>,
#   <carla.libcarla.Waypoint at 0x7f5747153c90>,
#   <carla.libcarla.Waypoint at 0x7f5747185870>,
#   <carla.libcarla.Waypoint at 0x7f5747185030>,
#   <carla.libcarla.Waypoint at 0x7f5747185450>,
#   <carla.libcarla.Waypoint at 0x7f57471858c8>,
#   <carla.libcarla.Waypoint at 0x7f5747185c90>,
#   <carla.libcarla.Waypoint at 0x7f57471864a8>,
#   <carla.libcarla.Waypoint at 0x7f5747186ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747186450>,
#   <carla.libcarla.Waypoint at 0x7f5747186870>,
#   <carla.libcarla.Waypoint at 0x7f5747186c90>,
#   <carla.libcarla.Waypoint at 0x7f57471874a8>,
#   <carla.libcarla.Waypoint at 0x7f5747187ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747187450>,
#   <carla.libcarla.Waypoint at 0x7f5747187870>,
#   <carla.libcarla.Waypoint at 0x7f5747187c90>,
#   <carla.libcarla.Waypoint at 0x7f5747188450>,
#   <carla.libcarla.Waypoint at 0x7f5747188c90>,
#   <carla.libcarla.Waypoint at 0x7f57471883f8>,
#   <carla.libcarla.Waypoint at 0x7f5747188870>,
#   <carla.libcarla.Waypoint at 0x7f5747188c38>,
#   <carla.libcarla.Waypoint at 0x7f57471893f8>,
#   <carla.libcarla.Waypoint at 0x7f5747189c90>,
#   <carla.libcarla.Waypoint at 0x7f57471893a0>,
#   <carla.libcarla.Waypoint at 0x7f57471897c0>,
#   <carla.libcarla.Waypoint at 0x7f5747189be0>,
#   <carla.libcarla.Waypoint at 0x7f574718a030>,
#   <carla.libcarla.Waypoint at 0x7f574718ac90>,
#   <carla.libcarla.Waypoint at 0x7f574718a3a0>,
#   <carla.libcarla.Waypoint at 0x7f574718a7c0>,
#   <carla.libcarla.Waypoint at 0x7f574718abe0>,
#   <carla.libcarla.Waypoint at 0x7f574708d030>,
#   <carla.libcarla.Waypoint at 0x7f574708dc90>,
#   <carla.libcarla.Waypoint at 0x7f574708d348>,
#   <carla.libcarla.Waypoint at 0x7f574708d7c0>,
#   <carla.libcarla.Waypoint at 0x7f574708db88>,
#   <carla.libcarla.Waypoint at 0x7f5747091030>,
#   <carla.libcarla.Waypoint at 0x7f5747091c38>,
#   <carla.libcarla.Waypoint at 0x7f5747091348>,
#   <carla.libcarla.Waypoint at 0x7f57470917c0>,
#   <carla.libcarla.Waypoint at 0x7f5747091b88>,
#   <carla.libcarla.Waypoint at 0x7f574708c030>,
#   <carla.libcarla.Waypoint at 0x7f574708cc38>,
#   <carla.libcarla.Waypoint at 0x7f574708c348>,
#   <carla.libcarla.Waypoint at 0x7f574708c768>,
#   <carla.libcarla.Waypoint at 0x7f574708cb88>,
#   <carla.libcarla.Waypoint at 0x7f574708cfa8>,
#   <carla.libcarla.Waypoint at 0x7f5747092920>,
#   <carla.libcarla.Waypoint at 0x7f57470922f0>,
#   <carla.libcarla.Waypoint at 0x7f5747092768>,
#   <carla.libcarla.Waypoint at 0x7f5747092b30>,
#   <carla.libcarla.Waypoint at 0x7f5747092fa8>,
#   <carla.libcarla.Waypoint at 0x7f574708b8c8>,
#   <carla.libcarla.Waypoint at 0x7f574708b2f0>,
#   <carla.libcarla.Waypoint at 0x7f574708b768>,
#   <carla.libcarla.Waypoint at 0x7f574708bb30>,
#   <carla.libcarla.Waypoint at 0x7f574708bfa8>,
#   <carla.libcarla.Waypoint at 0x7f574708f8c8>,
#   <carla.libcarla.Waypoint at 0x7f574708f2f0>,
#   <carla.libcarla.Waypoint at 0x7f574708f710>,
#   <carla.libcarla.Waypoint at 0x7f574708fb30>,
#   <carla.libcarla.Waypoint at 0x7f574708ff50>,
#   <carla.libcarla.Waypoint at 0x7f5747090a80>,
#   <carla.libcarla.Waypoint at 0x7f57470902f0>,
#   <carla.libcarla.Waypoint at 0x7f5747090710>,
#   <carla.libcarla.Waypoint at 0x7f5747090b88>,
#   <carla.libcarla.Waypoint at 0x7f5747090f50>,
#   <carla.libcarla.Waypoint at 0x7f574708e450>,
#   <carla.libcarla.Waypoint at 0x7f574708e298>,
#   <carla.libcarla.Waypoint at 0x7f574708e710>,
#   <carla.libcarla.Waypoint at 0x7f574708eb30>,
#   <carla.libcarla.Waypoint at 0x7f574708ef50>,
#   <carla.libcarla.Waypoint at 0x7f5747093768>,
#   <carla.libcarla.Waypoint at 0x7f57470932f0>,
#   <carla.libcarla.Waypoint at 0x7f5747093710>,
#   <carla.libcarla.Waypoint at 0x7f5747093b30>,
#   <carla.libcarla.Waypoint at 0x7f5747093f50>,
#   <carla.libcarla.Waypoint at 0x7f5747094710>,
#   <carla.libcarla.Waypoint at 0x7f57470942f0>,
#   <carla.libcarla.Waypoint at 0x7f57470946b8>,
#   <carla.libcarla.Waypoint at 0x7f5747094b30>,
#   <carla.libcarla.Waypoint at 0x7f5747094ef8>,
#   <carla.libcarla.Waypoint at 0x7f57470953f8>,
#   <carla.libcarla.Waypoint at 0x7f5747095240>,
#   <carla.libcarla.Waypoint at 0x7f5747095660>,
#   <carla.libcarla.Waypoint at 0x7f5747095a80>,
#   <carla.libcarla.Waypoint at 0x7f5747095ea0>,
#   <carla.libcarla.Waypoint at 0x7f57470960e0>,
#   <carla.libcarla.Waypoint at 0x7f5747096240>,
#   <carla.libcarla.Waypoint at 0x7f5747096660>,
#   <carla.libcarla.Waypoint at 0x7f5747096a80>,
#   <carla.libcarla.Waypoint at 0x7f5747096ea0>,
#   <carla.libcarla.Waypoint at 0x7f5747097088>,
#   <carla.libcarla.Waypoint at 0x7f5747097240>,
#   <carla.libcarla.Waypoint at 0x7f5747097608>,
#   <carla.libcarla.Waypoint at 0x7f5747097a80>,
#   <carla.libcarla.Waypoint at 0x7f5747097e48>,
#   <carla.libcarla.Waypoint at 0x7f5747098088>,
#   <carla.libcarla.Waypoint at 0x7f5747098240>,
#   <carla.libcarla.Waypoint at 0x7f5747098608>,
#   <carla.libcarla.Waypoint at 0x7f5747098a80>,
#   <carla.libcarla.Waypoint at 0x7f5747098e48>,
#   <carla.libcarla.Waypoint at 0x7f5747099088>,
#   <carla.libcarla.Waypoint at 0x7f57470991e8>,
#   <carla.libcarla.Waypoint at 0x7f5747099608>],
#  41: [<carla.libcarla.Waypoint at 0x7f5747099a28>,
#   <carla.libcarla.Waypoint at 0x7f5747099e48>,
#   <carla.libcarla.Waypoint at 0x7f574709af50>,
#   <carla.libcarla.Waypoint at 0x7f574709a1e8>,
#   <carla.libcarla.Waypoint at 0x7f574709a5b0>,
#   <carla.libcarla.Waypoint at 0x7f574709aa28>,
#   <carla.libcarla.Waypoint at 0x7f574709adf0>,
#   <carla.libcarla.Waypoint at 0x7f574709bf50>,
#   <carla.libcarla.Waypoint at 0x7f574709b1e8>,
#   <carla.libcarla.Waypoint at 0x7f574709b5b0>,
#   <carla.libcarla.Waypoint at 0x7f574709ba28>,
#   <carla.libcarla.Waypoint at 0x7f574709bdf0>,
#   <carla.libcarla.Waypoint at 0x7f574709cea0>,
#   <carla.libcarla.Waypoint at 0x7f574709c138>,
#   <carla.libcarla.Waypoint at 0x7f574709c558>,
#   <carla.libcarla.Waypoint at 0x7f574709c920>,
#   <carla.libcarla.Waypoint at 0x7f574709cd98>,
#   <carla.libcarla.Waypoint at 0x7f5750043768>,
#   <carla.libcarla.Waypoint at 0x7f5750043920>,
#   <carla.libcarla.Waypoint at 0x7f57500430e0>,
#   <carla.libcarla.Waypoint at 0x7f5750043500>,
#   <carla.libcarla.Waypoint at 0x7f5750043a80>,
#   <carla.libcarla.Waypoint at 0x7f5750043fa8>,
#   <carla.libcarla.Waypoint at 0x7f5750044978>,
#   <carla.libcarla.Waypoint at 0x7f5750044b88>,
#   <carla.libcarla.Waypoint at 0x7f57500444a8>,
#   <carla.libcarla.Waypoint at 0x7f5750044a28>,
#   <carla.libcarla.Waypoint at 0x7f5750044fa8>,
#   <carla.libcarla.Waypoint at 0x7f5750045870>,
#   <carla.libcarla.Waypoint at 0x7f5750045978>,
#   <carla.libcarla.Waypoint at 0x7f5750045450>,
#   <carla.libcarla.Waypoint at 0x7f57500459d0>,
#   <carla.libcarla.Waypoint at 0x7f5750045ea0>,
#   <carla.libcarla.Waypoint at 0x7f5750046558>,
#   <carla.libcarla.Waypoint at 0x7f5750046450>,
#   <carla.libcarla.Waypoint at 0x7f5750046710>,
#   <carla.libcarla.Waypoint at 0x7f5750046768>,
#   <carla.libcarla.Waypoint at 0x7f5750046ef8>,
#   <carla.libcarla.Waypoint at 0x7f5750047558>,
#   <carla.libcarla.Waypoint at 0x7f5750047d40>,
#   <carla.libcarla.Waypoint at 0x7f57500474a8>,
#   <carla.libcarla.Waypoint at 0x7f5750047ad8>,
#   <carla.libcarla.Waypoint at 0x7f5750047f50>,
#   <carla.libcarla.Waypoint at 0x7f5750048500>,
#   <carla.libcarla.Waypoint at 0x7f5750048870>,
#   <carla.libcarla.Waypoint at 0x7f57500484a8>,
#   <carla.libcarla.Waypoint at 0x7f5750048a28>,
#   <carla.libcarla.Waypoint at 0x7f5750048f50>,
#   <carla.libcarla.Waypoint at 0x7f5750049500>,
#   <carla.libcarla.Waypoint at 0x7f5750049920>,
#   <carla.libcarla.Waypoint at 0x7f5750049450>,
#   <carla.libcarla.Waypoint at 0x7f5750049a28>,
#   <carla.libcarla.Waypoint at 0x7f5750049ef8>,
#   <carla.libcarla.Waypoint at 0x7f5750053088>,
#   <carla.libcarla.Waypoint at 0x7f57500537c0>,
#   <carla.libcarla.Waypoint at 0x7f57500533a0>,
#   <carla.libcarla.Waypoint at 0x7f5750053978>,
#   <carla.libcarla.Waypoint at 0x7f5750053e48>,
#   <carla.libcarla.Waypoint at 0x7f5750054818>,
#   <carla.libcarla.Waypoint at 0x7f57500542f0>,
#   <carla.libcarla.Waypoint at 0x7f57500543a0>,
#   <carla.libcarla.Waypoint at 0x7f5750054920>,
#   <carla.libcarla.Waypoint at 0x7f5750054e48>,
#   <carla.libcarla.Waypoint at 0x7f5750055660>,
#   <carla.libcarla.Waypoint at 0x7f57500550e0>,
#   <carla.libcarla.Waypoint at 0x7f57500552f0>,
#   <carla.libcarla.Waypoint at 0x7f5750055870>,
#   <carla.libcarla.Waypoint at 0x7f5750055d40>,
#   <carla.libcarla.Waypoint at 0x7f5750056088>,
#   <carla.libcarla.Waypoint at 0x7f57500569d0>,
#   <carla.libcarla.Waypoint at 0x7f5750056710>,
#   <carla.libcarla.Waypoint at 0x7f5750056190>,
#   <carla.libcarla.Waypoint at 0x7f5750056d40>,
#   <carla.libcarla.Waypoint at 0x7f57500572f0>,
#   <carla.libcarla.Waypoint at 0x7f5750057e48>,
#   <carla.libcarla.Waypoint at 0x7f5750057348>,
#   <carla.libcarla.Waypoint at 0x7f5750057870>,
#   <carla.libcarla.Waypoint at 0x7f5750057df0>,
#   <carla.libcarla.Waypoint at 0x7f5750058d40>,
#   <carla.libcarla.Waypoint at 0x7f5750058088>,
#   <carla.libcarla.Waypoint at 0x7f5750058450>,
#   <carla.libcarla.Waypoint at 0x7f5750058920>,
#   <carla.libcarla.Waypoint at 0x7f5750058d98>,
#   <carla.libcarla.Waypoint at 0x7f57500598c8>,
#   <carla.libcarla.Waypoint at 0x7f5750059920>,
#   <carla.libcarla.Waypoint at 0x7f57500593f8>,
#   <carla.libcarla.Waypoint at 0x7f5750059870>,
#   <carla.libcarla.Waypoint at 0x7f5750059d40>,
#   <carla.libcarla.Waypoint at 0x7f5750061ef8>,
#   <carla.libcarla.Waypoint at 0x7f5750061190>,
#   <carla.libcarla.Waypoint at 0x7f5750061660>,
#   <carla.libcarla.Waypoint at 0x7f57500619d0>,
#   <carla.libcarla.Waypoint at 0x7f5750061d40>,
#   <carla.libcarla.Waypoint at 0x7f5750062b30>,
#   <carla.libcarla.Waypoint at 0x7f5750062138>,
#   <carla.libcarla.Waypoint at 0x7f5750062500>,
#   <carla.libcarla.Waypoint at 0x7f5750062920>,
#   <carla.libcarla.Waypoint at 0x7f5750062d40>,
#   <carla.libcarla.Waypoint at 0x7f57500287c0>,
#   <carla.libcarla.Waypoint at 0x7f5750028088>,
#   <carla.libcarla.Waypoint at 0x7f5750028500>,
#   <carla.libcarla.Waypoint at 0x7f57500288c8>,
#   <carla.libcarla.Waypoint at 0x7f5750028ce8>,
#   <carla.libcarla.Waypoint at 0x7f5750064558>,
#   <carla.libcarla.Waypoint at 0x7f57500644a8>],
#  42: [<carla.libcarla.Waypoint at 0x7f57500642f0>,
#   <carla.libcarla.Waypoint at 0x7f57500647c0>,
#   <carla.libcarla.Waypoint at 0x7f5750064c38>,
#   <carla.libcarla.Waypoint at 0x7f5750063f50>,
#   <carla.libcarla.Waypoint at 0x7f57500635b0>,
#   <carla.libcarla.Waypoint at 0x7f5750063b88>,
#   <carla.libcarla.Waypoint at 0x7f5750063b30>,
#   <carla.libcarla.Waypoint at 0x7f5750063190>,
#   <carla.libcarla.Waypoint at 0x7f5750027c38>,
#   <carla.libcarla.Waypoint at 0x7f5750027138>,
#   <carla.libcarla.Waypoint at 0x7f5750027920>,
#   <carla.libcarla.Waypoint at 0x7f5750027240>,
#   <carla.libcarla.Waypoint at 0x7f5750027a28>,
#   <carla.libcarla.Waypoint at 0x7f575005a1e8>,
#   <carla.libcarla.Waypoint at 0x7f575005a0e0>,
#   <carla.libcarla.Waypoint at 0x7f575005a500>,
#   <carla.libcarla.Waypoint at 0x7f575005a870>],
#  43: [<carla.libcarla.Waypoint at 0x7f575005de48>,
#   <carla.libcarla.Waypoint at 0x7f575005dad8>,
#   <carla.libcarla.Waypoint at 0x7f575005db30>,
#   <carla.libcarla.Waypoint at 0x7f575005def8>,
#   <carla.libcarla.Waypoint at 0x7f575005d2f0>,
#   <carla.libcarla.Waypoint at 0x7f575005e138>,
#   <carla.libcarla.Waypoint at 0x7f575005ec90>,
#   <carla.libcarla.Waypoint at 0x7f575005e0e0>,
#   <carla.libcarla.Waypoint at 0x7f575005e500>,
#   <carla.libcarla.Waypoint at 0x7f575005e8c8>,
#   <carla.libcarla.Waypoint at 0x7f575005f870>,
#   <carla.libcarla.Waypoint at 0x7f575005f0e0>,
#   <carla.libcarla.Waypoint at 0x7f575005f558>,
#   <carla.libcarla.Waypoint at 0x7f575005f978>,
#   <carla.libcarla.Waypoint at 0x7f575005fd98>,
#   <carla.libcarla.Waypoint at 0x7f574726e030>,
#   <carla.libcarla.Waypoint at 0x7f574726e138>],
#  45: [<carla.libcarla.Waypoint at 0x7f5747274298>,
#   <carla.libcarla.Waypoint at 0x7f57472746b8>,
#   <carla.libcarla.Waypoint at 0x7f5747274ad8>,
#   <carla.libcarla.Waypoint at 0x7f5747274ef8>,
#   <carla.libcarla.Waypoint at 0x7f57472753a0>,
#   <carla.libcarla.Waypoint at 0x7f5747275298>,
#   <carla.libcarla.Waypoint at 0x7f5747275608>,
#   <carla.libcarla.Waypoint at 0x7f5747275a80>,
#   <carla.libcarla.Waypoint at 0x7f5747275e48>,
#   <carla.libcarla.Waypoint at 0x7f5747276030>,
#   <carla.libcarla.Waypoint at 0x7f5747276240>,
#   <carla.libcarla.Waypoint at 0x7f5747276608>,
#   <carla.libcarla.Waypoint at 0x7f5747276a80>,
#   <carla.libcarla.Waypoint at 0x7f5747276e48>,
#   <carla.libcarla.Waypoint at 0x7f5747277030>,
#   <carla.libcarla.Waypoint at 0x7f5747277190>,
#   <carla.libcarla.Waypoint at 0x7f57472775b0>,
#   <carla.libcarla.Waypoint at 0x7f57472779d0>,
#   <carla.libcarla.Waypoint at 0x7f5747277df0>,
#   <carla.libcarla.Waypoint at 0x7f5747278ea0>,
#   <carla.libcarla.Waypoint at 0x7f5747278190>,
#   <carla.libcarla.Waypoint at 0x7f5747278558>,
#   <carla.libcarla.Waypoint at 0x7f57472789d0>,
#   <carla.libcarla.Waypoint at 0x7f5747278d98>,
#   <carla.libcarla.Waypoint at 0x7f5747279e48>,
#   <carla.libcarla.Waypoint at 0x7f5747279190>,
#   <carla.libcarla.Waypoint at 0x7f5747279558>,
#   <carla.libcarla.Waypoint at 0x7f57472799d0>,
#   <carla.libcarla.Waypoint at 0x7f5747279d98>,
#   <carla.libcarla.Waypoint at 0x7f574727ae48>,
#   <carla.libcarla.Waypoint at 0x7f574727a138>,
#   <carla.libcarla.Waypoint at 0x7f574727a558>,
#   <carla.libcarla.Waypoint at 0x7f574727a978>,
#   <carla.libcarla.Waypoint at 0x7f574727ad98>,
#   <carla.libcarla.Waypoint at 0x7f574727be48>,
#   <carla.libcarla.Waypoint at 0x7f574727b138>,
#   <carla.libcarla.Waypoint at 0x7f574727b500>,
#   <carla.libcarla.Waypoint at 0x7f574727b978>,
#   <carla.libcarla.Waypoint at 0x7f574727bd40>,
#   <carla.libcarla.Waypoint at 0x7f574727ca80>,
#   <carla.libcarla.Waypoint at 0x7f574727c138>,
#   <carla.libcarla.Waypoint at 0x7f574727c500>,
#   <carla.libcarla.Waypoint at 0x7f574727c978>,
#   <carla.libcarla.Waypoint at 0x7f574727cd40>,
#   <carla.libcarla.Waypoint at 0x7f574727da80>,
#   <carla.libcarla.Waypoint at 0x7f574727d0e0>,
#   <carla.libcarla.Waypoint at 0x7f574727d500>,
#   <carla.libcarla.Waypoint at 0x7f574727d920>,
#   <carla.libcarla.Waypoint at 0x7f574727dd40>,
#   <carla.libcarla.Waypoint at 0x7f574727ea80>,
#   <carla.libcarla.Waypoint at 0x7f574727e0e0>,
#   <carla.libcarla.Waypoint at 0x7f574727e500>,
#   <carla.libcarla.Waypoint at 0x7f574727e920>,
#   <carla.libcarla.Waypoint at 0x7f574727ed40>,
#   <carla.libcarla.Waypoint at 0x7f574727fa28>,
#   <carla.libcarla.Waypoint at 0x7f574727f0e0>,
#   <carla.libcarla.Waypoint at 0x7f574727f4a8>,
#   <carla.libcarla.Waypoint at 0x7f574727f920>,
#   <carla.libcarla.Waypoint at 0x7f574727fce8>,
#   <carla.libcarla.Waypoint at 0x7f57472806b8>,
#   <carla.libcarla.Waypoint at 0x7f57472800e0>,
#   <carla.libcarla.Waypoint at 0x7f57472804a8>,
#   <carla.libcarla.Waypoint at 0x7f5747280920>,
#   <carla.libcarla.Waypoint at 0x7f5747280ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747281660>,
#   <carla.libcarla.Waypoint at 0x7f5747281088>,
#   <carla.libcarla.Waypoint at 0x7f57472814a8>,
#   <carla.libcarla.Waypoint at 0x7f57472818c8>,
#   <carla.libcarla.Waypoint at 0x7f5747281ce8>,
#   <carla.libcarla.Waypoint at 0x7f5747282660>,
#   <carla.libcarla.Waypoint at 0x7f5747282088>,
#   <carla.libcarla.Waypoint at 0x7f5747282450>,
#   <carla.libcarla.Waypoint at 0x7f57472828c8>,
#   <carla.libcarla.Waypoint at 0x7f5747282c90>,
#   <carla.libcarla.Waypoint at 0x7f5747283660>,
#   <carla.libcarla.Waypoint at 0x7f5747283088>,
#   <carla.libcarla.Waypoint at 0x7f5747283450>,
#   <carla.libcarla.Waypoint at 0x7f57472838c8>,
#   <carla.libcarla.Waypoint at 0x7f5747283c90>,
#   <carla.libcarla.Waypoint at 0x7f5747284298>,
#   <carla.libcarla.Waypoint at 0x7f5747284030>,
#   <carla.libcarla.Waypoint at 0x7f5747284450>,
#   <carla.libcarla.Waypoint at 0x7f5747284870>,
#   <carla.libcarla.Waypoint at 0x7f5747284c90>,
#   <carla.libcarla.Waypoint at 0x7f575006cea0>,
#   <carla.libcarla.Waypoint at 0x7f575006ddf0>,
#   <carla.libcarla.Waypoint at 0x7f57500f8ce8>,
#   <carla.libcarla.Waypoint at 0x7f57500f8ea0>,
#   <carla.libcarla.Waypoint at 0x7f57471fa450>,
#   <carla.libcarla.Waypoint at 0x7f57471fbef8>,
#   <carla.libcarla.Waypoint at 0x7f57471fdef8>,
#   <carla.libcarla.Waypoint at 0x7f57471fe240>,
#   <carla.libcarla.Waypoint at 0x7f5747200d98>,
#   <carla.libcarla.Waypoint at 0x7f5747202d40>,
#   <carla.libcarla.Waypoint at 0x7f5747203660>,
#   <carla.libcarla.Waypoint at 0x7f57472050e0>,
#   <carla.libcarla.Waypoint at 0x7f5747207d98>,
#   <carla.libcarla.Waypoint at 0x7f5747209ef8>,
#   <carla.libcarla.Waypoint at 0x7f5747248c38>,
#   <carla.libcarla.Waypoint at 0x7f5747249710>,
#   <carla.libcarla.Waypoint at 0x7f57471d6138>,
#   <carla.libcarla.Waypoint at 0x7f57471d3818>,
#   <carla.libcarla.Waypoint at 0x7f57471d46b8>,
#   <carla.libcarla.Waypoint at 0x7f57471d1240>,
#   <carla.libcarla.Waypoint at 0x7f57471d0fa8>,
#   <carla.libcarla.Waypoint at 0x7f5747215608>,
#   <carla.libcarla.Waypoint at 0x7f5747216920>,
#   <carla.libcarla.Waypoint at 0x7f574721f710>,
#   <carla.libcarla.Waypoint at 0x7f5747191190>,
#   <carla.libcarla.Waypoint at 0x7f5747191450>,
#   <carla.libcarla.Waypoint at 0x7f5747191710>,
#   <carla.libcarla.Waypoint at 0x7f57471919d0>,
#   <carla.libcarla.Waypoint at 0x7f5747191c90>,
#   <carla.libcarla.Waypoint at 0x7f5747191f50>,
#   <carla.libcarla.Waypoint at 0x7f574728a240>,
#   <carla.libcarla.Waypoint at 0x7f574728a500>,
#   <carla.libcarla.Waypoint at 0x7f574728a7c0>,
#   <carla.libcarla.Waypoint at 0x7f574728aa80>,
#   <carla.libcarla.Waypoint at 0x7f574728ad40>,
#   <carla.libcarla.Waypoint at 0x7f5747288030>,
#   <carla.libcarla.Waypoint at 0x7f57472882f0>,
#   <carla.libcarla.Waypoint at 0x7f57472885b0>,
#   <carla.libcarla.Waypoint at 0x7f5747288870>,
#   <carla.libcarla.Waypoint at 0x7f5747288b30>,
#   <carla.libcarla.Waypoint at 0x7f5747288df0>,
#   <carla.libcarla.Waypoint at 0x7f57472860e0>,
#   <carla.libcarla.Waypoint at 0x7f57472863a0>,
#   <carla.libcarla.Waypoint at 0x7f5747286660>,
#   <carla.libcarla.Waypoint at 0x7f5747286920>,
#   <carla.libcarla.Waypoint at 0x7f5747286be0>,
#   <carla.libcarla.Waypoint at 0x7f5747286ea0>,
#   <carla.libcarla.Waypoint at 0x7f5747285190>,
#   <carla.libcarla.Waypoint at 0x7f5747285450>,
#   <carla.libcarla.Waypoint at 0x7f5747285710>,
#   <carla.libcarla.Waypoint at 0x7f57472859d0>,
#   <carla.libcarla.Waypoint at 0x7f5747285c90>,
#   <carla.libcarla.Waypoint at 0x7f5747285f50>,
#   <carla.libcarla.Waypoint at 0x7f5747287240>,
#   <carla.libcarla.Waypoint at 0x7f5747287500>,
#   <carla.libcarla.Waypoint at 0x7f57472877c0>,
#   <carla.libcarla.Waypoint at 0x7f5747287a80>,
#   <carla.libcarla.Waypoint at 0x7f5747287d40>,
#   <carla.libcarla.Waypoint at 0x7f5747289030>,
#   <carla.libcarla.Waypoint at 0x7f57472892f0>,
#   <carla.libcarla.Waypoint at 0x7f57472895b0>,
#   <carla.libcarla.Waypoint at 0x7f5747289870>,
#   <carla.libcarla.Waypoint at 0x7f5747289b30>,
#   <carla.libcarla.Waypoint at 0x7f5747289df0>,
#   <carla.libcarla.Waypoint at 0x7f574717c0e0>,
#   <carla.libcarla.Waypoint at 0x7f574717c3a0>,
#   <carla.libcarla.Waypoint at 0x7f574717c660>,
#   <carla.libcarla.Waypoint at 0x7f574717c920>,
#   <carla.libcarla.Waypoint at 0x7f574717cbe0>,
#   <carla.libcarla.Waypoint at 0x7f574717cea0>,
#   <carla.libcarla.Waypoint at 0x7f5747173190>,
#   <carla.libcarla.Waypoint at 0x7f5747173450>,
#   <carla.libcarla.Waypoint at 0x7f5747173710>,
#   <carla.libcarla.Waypoint at 0x7f57471739d0>,
#   <carla.libcarla.Waypoint at 0x7f5747173c90>,
#   <carla.libcarla.Waypoint at 0x7f5747173f50>,
#   <carla.libcarla.Waypoint at 0x7f574717b240>,
#   <carla.libcarla.Waypoint at 0x7f574717b500>,
#   <carla.libcarla.Waypoint at 0x7f574717b7c0>,
#   <carla.libcarla.Waypoint at 0x7f574717ba80>,
#   <carla.libcarla.Waypoint at 0x7f574717bd40>,
#   <carla.libcarla.Waypoint at 0x7f574717d030>,
#   <carla.libcarla.Waypoint at 0x7f574717d2f0>,
#   <carla.libcarla.Waypoint at 0x7f574717d5b0>,
#   <carla.libcarla.Waypoint at 0x7f574717d870>,
#   <carla.libcarla.Waypoint at 0x7f574717db30>,
#   <carla.libcarla.Waypoint at 0x7f574717ddf0>,
#   <carla.libcarla.Waypoint at 0x7f574717a0e0>,
#   <carla.libcarla.Waypoint at 0x7f574717a3a0>,
#   <carla.libcarla.Waypoint at 0x7f574717a660>,
#   <carla.libcarla.Waypoint at 0x7f574717a920>,
#   <carla.libcarla.Waypoint at 0x7f574717abe0>,
#   <carla.libcarla.Waypoint at 0x7f574717aea0>,
#   <carla.libcarla.Waypoint at 0x7f5747179190>,
#   <carla.libcarla.Waypoint at 0x7f5747179450>,
#   <carla.libcarla.Waypoint at 0x7f5747179710>,
#   <carla.libcarla.Waypoint at 0x7f57471799d0>,
#   <carla.libcarla.Waypoint at 0x7f5747179c90>,
#   <carla.libcarla.Waypoint at 0x7f5747179f50>,
#   <carla.libcarla.Waypoint at 0x7f5747178240>,
#   <carla.libcarla.Waypoint at 0x7f5747178500>,
#   <carla.libcarla.Waypoint at 0x7f57471787c0>,
#   <carla.libcarla.Waypoint at 0x7f5747178a80>,
#   <carla.libcarla.Waypoint at 0x7f5747178d40>,
#   <carla.libcarla.Waypoint at 0x7f575004a030>,
#   <carla.libcarla.Waypoint at 0x7f575004a2f0>,
#   <carla.libcarla.Waypoint at 0x7f575004a5b0>,
#   <carla.libcarla.Waypoint at 0x7f575004a870>,
#   <carla.libcarla.Waypoint at 0x7f575004ab30>,
#   <carla.libcarla.Waypoint at 0x7f575004adf0>,
#   <carla.libcarla.Waypoint at 0x7f575004b0e0>,
#   <carla.libcarla.Waypoint at 0x7f575004b3a0>,
#   <carla.libcarla.Waypoint at 0x7f575004b660>,
#   <carla.libcarla.Waypoint at 0x7f575004b920>,
#   <carla.libcarla.Waypoint at 0x7f575004bbe0>,
#   <carla.libcarla.Waypoint at 0x7f575004bea0>,
#   <carla.libcarla.Waypoint at 0x7f575004c4a8>,
#   <carla.libcarla.Waypoint at 0x7f575004cb88>,
#   <carla.libcarla.Waypoint at 0x7f575004c978>,
#   <carla.libcarla.Waypoint at 0x7f575004c5b0>,
#   <carla.libcarla.Waypoint at 0x7f575004c3f8>,
#   <carla.libcarla.Waypoint at 0x7f575004cd98>,
#   <carla.libcarla.Waypoint at 0x7f575004d558>,
#   <carla.libcarla.Waypoint at 0x7f575004d818>,
#   <carla.libcarla.Waypoint at 0x7f575004dea0>,
#   <carla.libcarla.Waypoint at 0x7f575004da80>,
#   <carla.libcarla.Waypoint at 0x7f575004d6b8>,
#   <carla.libcarla.Waypoint at 0x7f57500508c8>,
#   <carla.libcarla.Waypoint at 0x7f57500509d0>,
#   <carla.libcarla.Waypoint at 0x7f5750050be0>,
#   <carla.libcarla.Waypoint at 0x7f5750050b30>,
#   <carla.libcarla.Waypoint at 0x7f5750050450>,
#   <carla.libcarla.Waypoint at 0x7f5750050978>,
#   <carla.libcarla.Waypoint at 0x7f5750051be0>,
#   <carla.libcarla.Waypoint at 0x7f5750051d40>,
#   <carla.libcarla.Waypoint at 0x7f57500510e0>,
#   <carla.libcarla.Waypoint at 0x7f5750051298>,
#   <carla.libcarla.Waypoint at 0x7f57500517c0>,
#   <carla.libcarla.Waypoint at 0x7f5750051ce8>,
#   <carla.libcarla.Waypoint at 0x7f5750052a80>,
#   <carla.libcarla.Waypoint at 0x7f5750052240>,
#   <carla.libcarla.Waypoint at 0x7f5750052348>,
#   <carla.libcarla.Waypoint at 0x7f5750052500>,
#   <carla.libcarla.Waypoint at 0x7f5750052978>,
#   <carla.libcarla.Waypoint at 0x7f5750052df0>,
#   <carla.libcarla.Waypoint at 0x7f5750060450>,
#   <carla.libcarla.Waypoint at 0x7f57500600e0>,
#   <carla.libcarla.Waypoint at 0x7f5750060500>,
#   <carla.libcarla.Waypoint at 0x7f5750060870>,
#   <carla.libcarla.Waypoint at 0x7f5750060be0>,
#   <carla.libcarla.Waypoint at 0x7f5750042030>,
#   <carla.libcarla.Waypoint at 0x7f5750042ce8>,
#   <carla.libcarla.Waypoint at 0x7f57500423a0>,
#   <carla.libcarla.Waypoint at 0x7f5750042b88>,
#   <carla.libcarla.Waypoint at 0x7f5750042348>,
#   <carla.libcarla.Waypoint at 0x7f5750042978>,
#   <carla.libcarla.Waypoint at 0x7f57470f24a8>,
#   <carla.libcarla.Waypoint at 0x7f57470f2c38>,
#   <carla.libcarla.Waypoint at 0x7f57470f2190>,
#   <carla.libcarla.Waypoint at 0x7f57470f25b0>,
#   <carla.libcarla.Waypoint at 0x7f57470f29d0>,
#   <carla.libcarla.Waypoint at 0x7f57470f2df0>,
#   <carla.libcarla.Waypoint at 0x7f57470f1d40>,
#   <carla.libcarla.Waypoint at 0x7f57470f1870>,
#   <carla.libcarla.Waypoint at 0x7f57470f1348>,
#   <carla.libcarla.Waypoint at 0x7f57470f1768>,
#   <carla.libcarla.Waypoint at 0x7f57470f1b88>,
#   <carla.libcarla.Waypoint at 0x7f57470f1f50>,
#   <carla.libcarla.Waypoint at 0x7f57470f00e0>,
#   <carla.libcarla.Waypoint at 0x7f57470f0ea0>,
#   <carla.libcarla.Waypoint at 0x7f57470f03f8>,
#   <carla.libcarla.Waypoint at 0x7f57470f0818>,
#   <carla.libcarla.Waypoint at 0x7f57470f0c38>,
#   <carla.libcarla.Waypoint at 0x7f57470cb818>,
#   <carla.libcarla.Waypoint at 0x7f57470cb500>,
#   <carla.libcarla.Waypoint at 0x7f57470cb0e0>,
#   <carla.libcarla.Waypoint at 0x7f57470cb558>,
#   <carla.libcarla.Waypoint at 0x7f57470cb920>,
#   <carla.libcarla.Waypoint at 0x7f57470cbd40>,
#   <carla.libcarla.Waypoint at 0x7f57470fe660>,
#   <carla.libcarla.Waypoint at 0x7f57470fed40>,
#   <carla.libcarla.Waypoint at 0x7f57470fe3a0>,
#   <carla.libcarla.Waypoint at 0x7f57470fe710>,
#   <carla.libcarla.Waypoint at 0x7f57470fead8>,
#   <carla.libcarla.Waypoint at 0x7f57470fee48>,
#   <carla.libcarla.Waypoint at 0x7f57470fdd40>,
#   <carla.libcarla.Waypoint at 0x7f57470fd138>,
#   <carla.libcarla.Waypoint at 0x7f57470fd4a8>,
#   <carla.libcarla.Waypoint at 0x7f57470fd818>,
#   <carla.libcarla.Waypoint at 0x7f57470fdbe0>,
#   <carla.libcarla.Waypoint at 0x7f57470fdf50>,
#   <carla.libcarla.Waypoint at 0x7f57470fc0e0>,
#   <carla.libcarla.Waypoint at 0x7f57470fc1e8>,
#   <carla.libcarla.Waypoint at 0x7f57470fc558>,
#   <carla.libcarla.Waypoint at 0x7f57470fc8c8>,
#   <carla.libcarla.Waypoint at 0x7f57470fcc90>,
#   <carla.libcarla.Waypoint at 0x7f57470cfad8>,
#   <carla.libcarla.Waypoint at 0x7f57470cf190>,
#   <carla.libcarla.Waypoint at 0x7f57470cf138>,
#   <carla.libcarla.Waypoint at 0x7f57470cf558>,
#   <carla.libcarla.Waypoint at 0x7f57470cf8c8>,
#   <carla.libcarla.Waypoint at 0x7f57470cfce8>,
#   <carla.libcarla.Waypoint at 0x7f57470d04a8>,
#   <carla.libcarla.Waypoint at 0x7f57470d0c38>,
#   <carla.libcarla.Waypoint at 0x7f57470d0190>,
#   <carla.libcarla.Waypoint at 0x7f57470d05b0>,
#   <carla.libcarla.Waypoint at 0x7f57470d09d0>,
#   <carla.libcarla.Waypoint at 0x7f57470d0df0>,
#   <carla.libcarla.Waypoint at 0x7f57470d1d40>],
#  46: [<carla.libcarla.Waypoint at 0x7f57470faef8>,
#   <carla.libcarla.Waypoint at 0x7f57470f96b8>,
#   <carla.libcarla.Waypoint at 0x7f57470f90e0>,
#   <carla.libcarla.Waypoint at 0x7f57470f94a8>,
#   <carla.libcarla.Waypoint at 0x7f57470f98c8>,
#   <carla.libcarla.Waypoint at 0x7f57470f9c90>,
#   <carla.libcarla.Waypoint at 0x7f57470f8be0>,
#   <carla.libcarla.Waypoint at 0x7f57470f8a80>,
#   <carla.libcarla.Waypoint at 0x7f57470f8190>,
#   <carla.libcarla.Waypoint at 0x7f57470f8558>,
#   <carla.libcarla.Waypoint at 0x7f57470f8978>,
#   <carla.libcarla.Waypoint at 0x7f57470f8d40>,
#   <carla.libcarla.Waypoint at 0x7f57470f7768>,
#   <carla.libcarla.Waypoint at 0x7f57470f7190>,
#   <carla.libcarla.Waypoint at 0x7f57470f7240>,
#   <carla.libcarla.Waypoint at 0x7f57470f7608>,
#   <carla.libcarla.Waypoint at 0x7f57470f7a28>,
#   <carla.libcarla.Waypoint at 0x7f57470f7df0>,
#   <carla.libcarla.Waypoint at 0x7f57470f6fa8>,
#   <carla.libcarla.Waypoint at 0x7f57470f67c0>,
#   <carla.libcarla.Waypoint at 0x7f57470f6348>,
#   <carla.libcarla.Waypoint at 0x7f57470f6710>,
#   <carla.libcarla.Waypoint at 0x7f57470f6b30>,
#   <carla.libcarla.Waypoint at 0x7f57470f6ef8>,
#   <carla.libcarla.Waypoint at 0x7f57470f56b8>,
#   <carla.libcarla.Waypoint at 0x7f57470f50e0>,
#   <carla.libcarla.Waypoint at 0x7f57470f54a8>,
#   <carla.libcarla.Waypoint at 0x7f57470f58c8>,
#   <carla.libcarla.Waypoint at 0x7f57470f5c90>,
#   <carla.libcarla.Waypoint at 0x7f57470f4be0>,
#   <carla.libcarla.Waypoint at 0x7f57470f4a80>,
#   <carla.libcarla.Waypoint at 0x7f57470f4190>,
#   <carla.libcarla.Waypoint at 0x7f57470f4558>,
#   <carla.libcarla.Waypoint at 0x7f57470f4978>,
#   <carla.libcarla.Waypoint at 0x7f57470f4d40>,
#   <carla.libcarla.Waypoint at 0x7f57470f3768>,
#   <carla.libcarla.Waypoint at 0x7f57470f3450>,
#   <carla.libcarla.Waypoint at 0x7f57470f3298>,
#   <carla.libcarla.Waypoint at 0x7f57470f3660>,
#   <carla.libcarla.Waypoint at 0x7f57470f3a80>,
#   <carla.libcarla.Waypoint at 0x7f57470f3ea0>,
#   <carla.libcarla.Waypoint at 0x7f57470ccf50>,
#   <carla.libcarla.Waypoint at 0x7f57470cc138>,
#   <carla.libcarla.Waypoint at 0x7f57470cc4a8>,
#   <carla.libcarla.Waypoint at 0x7f57470cc870>,
#   <carla.libcarla.Waypoint at 0x7f57470ccbe0>,
#   <carla.libcarla.Waypoint at 0x7f57470ccfa8>,
#   <carla.libcarla.Waypoint at 0x7f57470cd5b0>,
#   <carla.libcarla.Waypoint at 0x7f57470cd240>,
#   <carla.libcarla.Waypoint at 0x7f57470cd608>,
#   <carla.libcarla.Waypoint at 0x7f57470cd978>,
#   <carla.libcarla.Waypoint at 0x7f57470cdd40>,
#   <carla.libcarla.Waypoint at 0x7f57470ce138>,
#   <carla.libcarla.Waypoint at 0x7f57470cebe0>,
#   <carla.libcarla.Waypoint at 0x7f57470ce2f0>,
#   <carla.libcarla.Waypoint at 0x7f57470ce6b8>,
#   <carla.libcarla.Waypoint at 0x7f57470cea28>,
#   <carla.libcarla.Waypoint at 0x7f57470cedf0>,
#   <carla.libcarla.Waypoint at 0x7f57501066b8>,
#   <carla.libcarla.Waypoint at 0x7f5750106660>,
#   <carla.libcarla.Waypoint at 0x7f5750106710>,
#   <carla.libcarla.Waypoint at 0x7f57501063f8>,
#   <carla.libcarla.Waypoint at 0x7f5750106920>,
#   <carla.libcarla.Waypoint at 0x7f5750106ea0>,
#   <carla.libcarla.Waypoint at 0x7f5750112ce8>,
#   <carla.libcarla.Waypoint at 0x7f5750112d40>,
#   <carla.libcarla.Waypoint at 0x7f57501121e8>,
#   <carla.libcarla.Waypoint at 0x7f5750112608>,
#   <carla.libcarla.Waypoint at 0x7f5750112b30>,
#   <carla.libcarla.Waypoint at 0x7f5750112fa8>],
#  47: [<carla.libcarla.Waypoint at 0x7f57501137c0>,
#   <carla.libcarla.Waypoint at 0x7f5750113348>,
#   <carla.libcarla.Waypoint at 0x7f5750113870>,
#   <carla.libcarla.Waypoint at 0x7f5750113c90>,
#   <carla.libcarla.Waypoint at 0x7f5750100df0>,
#   <carla.libcarla.Waypoint at 0x7f5750100240>,
#   <carla.libcarla.Waypoint at 0x7f5750100088>,
#   <carla.libcarla.Waypoint at 0x7f5750100450>,
#   <carla.libcarla.Waypoint at 0x7f5750100818>,
#   <carla.libcarla.Waypoint at 0x7f5750100ce8>,
#   <carla.libcarla.Waypoint at 0x7f57501017c0>,
#   <carla.libcarla.Waypoint at 0x7f5750101608>,
#   <carla.libcarla.Waypoint at 0x7f5750101088>,
#   <carla.libcarla.Waypoint at 0x7f5750101500>,
#   <carla.libcarla.Waypoint at 0x7f5750101a28>,
#   <carla.libcarla.Waypoint at 0x7f5750101e48>,
#   <carla.libcarla.Waypoint at 0x7f5750102ce8>,
#   <carla.libcarla.Waypoint at 0x7f5750102d40>,
#   <carla.libcarla.Waypoint at 0x7f57501021e8>,
#   <carla.libcarla.Waypoint at 0x7f5750102608>,
#   <carla.libcarla.Waypoint at 0x7f5750102b30>,
#   <carla.libcarla.Waypoint at 0x7f5750102fa8>,
#   <carla.libcarla.Waypoint at 0x7f5750103088>,
#   <carla.libcarla.Waypoint at 0x7f5750103240>,
#   <carla.libcarla.Waypoint at 0x7f57501032f0>,
#   <carla.libcarla.Waypoint at 0x7f5750103710>,
#   <carla.libcarla.Waypoint at 0x7f5750103c38>,
#   <carla.libcarla.Waypoint at 0x7f57501040e0>,
#   <carla.libcarla.Waypoint at 0x7f5750104558>,
#   <carla.libcarla.Waypoint at 0x7f5750104138>,
#   <carla.libcarla.Waypoint at 0x7f5750104500>,
#   <carla.libcarla.Waypoint at 0x7f5750104978>,
#   <carla.libcarla.Waypoint at 0x7f5750104d40>,
#   <carla.libcarla.Waypoint at 0x7f57500fa818>,
#   <carla.libcarla.Waypoint at 0x7f57500faa28>,
#   <carla.libcarla.Waypoint at 0x7f57500fa0e0>,
#   <carla.libcarla.Waypoint at 0x7f57500fa558>,
#   <carla.libcarla.Waypoint at 0x7f57500fa978>,
#   <carla.libcarla.Waypoint at 0x7f57500faea0>,
#   <carla.libcarla.Waypoint at 0x7f57500fbce8>,
#   <carla.libcarla.Waypoint at 0x7f57500fb818>,
#   <carla.libcarla.Waypoint at 0x7f57500fb1e8>,
#   <carla.libcarla.Waypoint at 0x7f57500fb660>,
#   <carla.libcarla.Waypoint at 0x7f57500fbad8>,
#   <carla.libcarla.Waypoint at 0x7f57500fbfa8>,
#   <carla.libcarla.Waypoint at 0x7f57500fc190>,
#   <carla.libcarla.Waypoint at 0x7f57500fc2f0>,
#   <carla.libcarla.Waypoint at 0x7f57500fc348>,
#   <carla.libcarla.Waypoint at 0x7f57500fc768>,
#   <carla.libcarla.Waypoint at 0x7f57500fcc38>,
#   <carla.libcarla.Waypoint at 0x7f57500fd3a0>,
#   <carla.libcarla.Waypoint at 0x7f57500fd5b0>,
#   <carla.libcarla.Waypoint at 0x7f57500fd920>,
#   <carla.libcarla.Waypoint at 0x7f57500fd3f8>,
#   <carla.libcarla.Waypoint at 0x7f57500fd818>,
#   <carla.libcarla.Waypoint at 0x7f57500fdce8>,
#   <carla.libcarla.Waypoint at 0x7f57500fe818>],
#  48: [<carla.libcarla.Waypoint at 0x7f57500fe608>,
#   <carla.libcarla.Waypoint at 0x7f57500feb30>,
#   <carla.libcarla.Waypoint at 0x7f57500fefa8>,
#   <carla.libcarla.Waypoint at 0x7f57500ff450>,
#   <carla.libcarla.Waypoint at 0x7f57500ff7c0>,
#   <carla.libcarla.Waypoint at 0x7f57500ff348>,
#   <carla.libcarla.Waypoint at 0x7f57500ff768>,
#   <carla.libcarla.Waypoint at 0x7f57500ffc90>,
#   <carla.libcarla.Waypoint at 0x7f57501241e8>,
#   <carla.libcarla.Waypoint at 0x7f5750124be0>,
#   <carla.libcarla.Waypoint at 0x7f57501242f0>,
#   <carla.libcarla.Waypoint at 0x7f57501246b8>,
#   <carla.libcarla.Waypoint at 0x7f5750124a28>,
#   <carla.libcarla.Waypoint at 0x7f5750124d98>,
#   <carla.libcarla.Waypoint at 0x7f57501258c8>,
#   <carla.libcarla.Waypoint at 0x7f5750125088>,
#   <carla.libcarla.Waypoint at 0x7f57501253f8>,
#   <carla.libcarla.Waypoint at 0x7f57501257c0>,
#   <carla.libcarla.Waypoint at 0x7f5750125b30>,
#   <carla.libcarla.Waypoint at 0x7f5750125ea0>,
#   <carla.libcarla.Waypoint at 0x7f575010dce8>,
#   <carla.libcarla.Waypoint at 0x7f575010d660>,
#   <carla.libcarla.Waypoint at 0x7f575010d298>,
#   <carla.libcarla.Waypoint at 0x7f575010d710>,
#   <carla.libcarla.Waypoint at 0x7f575010dad8>,
#   <carla.libcarla.Waypoint at 0x7f575010df50>,
#   <carla.libcarla.Waypoint at 0x7f575010e2f0>,
#   <carla.libcarla.Waypoint at 0x7f575010e450>,
#   <carla.libcarla.Waypoint at 0x7f575010e298>,
#   <carla.libcarla.Waypoint at 0x7f575010e7c0>,
#   <carla.libcarla.Waypoint at 0x7f575010ebe0>,
#   <carla.libcarla.Waypoint at 0x7f575010fe48>],
#  49: [<carla.libcarla.Waypoint at 0x7f5750110298>,
#   <carla.libcarla.Waypoint at 0x7f5750110fa8>,
#   <carla.libcarla.Waypoint at 0x7f5750110b30>,
#   <carla.libcarla.Waypoint at 0x7f57501103f8>,
#   <carla.libcarla.Waypoint at 0x7f5750110920>,
#   <carla.libcarla.Waypoint at 0x7f5750110d40>,
#   <carla.libcarla.Waypoint at 0x7f57501118c8>,
#   <carla.libcarla.Waypoint at 0x7f5750111660>,
#   <carla.libcarla.Waypoint at 0x7f5750111298>,
#   <carla.libcarla.Waypoint at 0x7f5750111710>,
#   <carla.libcarla.Waypoint at 0x7f5750111ad8>,
#   <carla.libcarla.Waypoint at 0x7f5750111ef8>,
#   <carla.libcarla.Waypoint at 0x7f57501073f8>,
#   <carla.libcarla.Waypoint at 0x7f5750107e48>,
#   <carla.libcarla.Waypoint at 0x7f57501071e8>,
#   <carla.libcarla.Waypoint at 0x7f57501076b8>,
#   <carla.libcarla.Waypoint at 0x7f5750107be0>,
#   <carla.libcarla.Waypoint at 0x7f5750108fa8>,
#   <carla.libcarla.Waypoint at 0x7f57501084a8>,
#   <carla.libcarla.Waypoint at 0x7f5750108030>],
#  50: [<carla.libcarla.Waypoint at 0x7f5750108768>,
#   <carla.libcarla.Waypoint at 0x7f5750108c90>,
#   <carla.libcarla.Waypoint at 0x7f5750109450>,
#   <carla.libcarla.Waypoint at 0x7f5750109ea0>,
#   <carla.libcarla.Waypoint at 0x7f5750109be0>,
#   <carla.libcarla.Waypoint at 0x7f57501094a8>,
#   <carla.libcarla.Waypoint at 0x7f57501099d0>,
#   <carla.libcarla.Waypoint at 0x7f5750109df0>,
#   <carla.libcarla.Waypoint at 0x7f575010a920>,
#   <carla.libcarla.Waypoint at 0x7f575010a6b8>,
#   <carla.libcarla.Waypoint at 0x7f575010a0e0>,
#   <carla.libcarla.Waypoint at 0x7f575010a5b0>,
#   <carla.libcarla.Waypoint at 0x7f575010aad8>,
#   <carla.libcarla.Waypoint at 0x7f575010aef8>,
#   <carla.libcarla.Waypoint at 0x7f575010b818>,
#   <carla.libcarla.Waypoint at 0x7f575010bb30>,
#   <carla.libcarla.Waypoint at 0x7f575010b1e8>,
#   <carla.libcarla.Waypoint at 0x7f575010b6b8>,
#   <carla.libcarla.Waypoint at 0x7f575010bbe0>,
#   <carla.libcarla.Waypoint at 0x7f575010cfa8>,
#   <carla.libcarla.Waypoint at 0x7f575010c818>,
#   <carla.libcarla.Waypoint at 0x7f575010c2f0>,
#   <carla.libcarla.Waypoint at 0x7f575010c3a0>,
#   <carla.libcarla.Waypoint at 0x7f575010c7c0>,
#   <carla.libcarla.Waypoint at 0x7f575010cce8>,
#   <carla.libcarla.Waypoint at 0x7f57500f9240>,
#   <carla.libcarla.Waypoint at 0x7f57500f9348>,
#   <carla.libcarla.Waypoint at 0x7f57500f9fa8>,
#   <carla.libcarla.Waypoint at 0x7f57500f93f8>,
#   <carla.libcarla.Waypoint at 0x7f57500f98c8>,
#   <carla.libcarla.Waypoint at 0x7f57500f9d98>,
#   <carla.libcarla.Waypoint at 0x7f5750105b30>,
#   <carla.libcarla.Waypoint at 0x7f5750105608>,
#   <carla.libcarla.Waypoint at 0x7f5750105088>,
#   <carla.libcarla.Waypoint at 0x7f5750105500>,
#   <carla.libcarla.Waypoint at 0x7f5750105a28>,
#   <carla.libcarla.Waypoint at 0x7f5750105e48>,
#   <carla.libcarla.Waypoint at 0x7f5750114030>,
#   <carla.libcarla.Waypoint at 0x7f5750114348>,
#   <carla.libcarla.Waypoint at 0x7f5750114660>,
#   <carla.libcarla.Waypoint at 0x7f57501149d0>,
#   <carla.libcarla.Waypoint at 0x7f5750114ce8>,
#   <carla.libcarla.Waypoint at 0x7f57501150e0>,
#   <carla.libcarla.Waypoint at 0x7f5750115d40>,
#   <carla.libcarla.Waypoint at 0x7f57501152f0>,
#   <carla.libcarla.Waypoint at 0x7f5750115608>,
#   <carla.libcarla.Waypoint at 0x7f57501159d0>,
#   <carla.libcarla.Waypoint at 0x7f5750115d98>,
#   <carla.libcarla.Waypoint at 0x7f5750116710>,
#   <carla.libcarla.Waypoint at 0x7f5750116df0>,
#   <carla.libcarla.Waypoint at 0x7f57501163a0>,
#   <carla.libcarla.Waypoint at 0x7f5750116768>,
#   <carla.libcarla.Waypoint at 0x7f5750116ad8>,
#   <carla.libcarla.Waypoint at 0x7f5750116ea0>,
#   <carla.libcarla.Waypoint at 0x7f5750117ad8>,
#   <carla.libcarla.Waypoint at 0x7f5750117088>,
#   <carla.libcarla.Waypoint at 0x7f5750117450>,
#   <carla.libcarla.Waypoint at 0x7f5750117818>,
#   <carla.libcarla.Waypoint at 0x7f5750117b88>,
#   <carla.libcarla.Waypoint at 0x7f5750117f50>,
#   <carla.libcarla.Waypoint at 0x7f5750118450>,
#   <carla.libcarla.Waypoint at 0x7f57501181e8>,
#   <carla.libcarla.Waypoint at 0x7f57501185b0>,
#   <carla.libcarla.Waypoint at 0x7f5750118920>,
#   <carla.libcarla.Waypoint at 0x7f5750118ce8>,
#   <carla.libcarla.Waypoint at 0x7f575011ead8>,
#   <carla.libcarla.Waypoint at 0x7f575011e818>,
#   <carla.libcarla.Waypoint at 0x7f575011e2f0>,
#   <carla.libcarla.Waypoint at 0x7f575011e660>,
#   <carla.libcarla.Waypoint at 0x7f575011e9d0>,
#   <carla.libcarla.Waypoint at 0x7f575011ed40>,
#   <carla.libcarla.Waypoint at 0x7f575011f660>,
#   <carla.libcarla.Waypoint at 0x7f575011fb88>,
#   <carla.libcarla.Waypoint at 0x7f575011f3a0>,
#   <carla.libcarla.Waypoint at 0x7f575011f710>,
#   <carla.libcarla.Waypoint at 0x7f575011fa80>,
#   <carla.libcarla.Waypoint at 0x7f575011fdf0>,
#   <carla.libcarla.Waypoint at 0x7f5750120d40>,
#   <carla.libcarla.Waypoint at 0x7f57501200e0>,
#   <carla.libcarla.Waypoint at 0x7f57501204a8>,
#   <carla.libcarla.Waypoint at 0x7f5750120818>,
#   <carla.libcarla.Waypoint at 0x7f5750120b88>,
#   <carla.libcarla.Waypoint at 0x7f5750120f50>,
#   <carla.libcarla.Waypoint at 0x7f574710b240>,
#   <carla.libcarla.Waypoint at 0x7f574710b500>,
#   <carla.libcarla.Waypoint at 0x7f574710b7c0>,
#   <carla.libcarla.Waypoint at 0x7f574710ba80>,
#   <carla.libcarla.Waypoint at 0x7f574710bd40>,
#   <carla.libcarla.Waypoint at 0x7f574710c030>]}

# %% [markdown]
# ## road waypoints

# %%
def drive_figure_eight(world, vehicle):
    """Drive vehicle around Town04's figure-eight."""
    road_waypoints = validate_figure8_waypoints(world)
    road_sequence = [6, 35, 36, 37, 38, 39, 40, 41, 42, 43, 45, 46, 47, 48, 49, 50]
    target_speed = 30  # km/h
    
    try:
        while True:
            for road_id in road_sequence:
                for wp in road_waypoints[road_id]:
                    control = compute_control(vehicle, wp, target_speed)
                    vehicle.apply_control(control)
                    
                    if world.get_settings().synchronous_mode:
                        world.tick()
                    else:
                        time.sleep(0.1)  # Adjust timing as needed
                        
    except KeyboardInterrupt:
        control = carla.VehicleControl(throttle=0, brake=1)
        vehicle.apply_control(control)

def compute_control(vehicle, target_wp, target_speed):
    """Compute vehicle control to reach waypoint."""
    control = carla.VehicleControl()
    
    # Get current state
    current_transform = vehicle.get_transform()
    current_velocity = vehicle.get_velocity()
    speed = 3.6 * math.sqrt(current_velocity.x**2 + current_velocity.y**2)  # km/h
    
    # Steering based on angle difference
    forward = current_transform.get_forward_vector()
    right = current_transform.get_right_vector()
    up = current_transform.get_up_vector()
    target_vector = target_wp.transform.location - current_transform.location
    
    forward_dot = (forward.x * target_vector.x + forward.y * target_vector.y) 
    right_dot = (right.x * target_vector.x + right.y * target_vector.y)
    
    steering = math.atan2(right_dot, forward_dot) / math.pi
    control.steer = max(-1.0, min(1.0, steering))
    
    # Speed control
    if speed < target_speed:
        control.throttle = 0.7
        control.brake = 0.0
    else:
        control.throttle = 0.0
        control.brake = 0.3
        
    return control
# Out:
# dict
